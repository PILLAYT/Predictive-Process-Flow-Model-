# %%
# imports

import simpy
import random 
import pandas as pd 
from collections import defaultdict

env = simpy.Environment()

# %%
# DICTIONARIES IN PROGRESS 

# Note that OEE was taken as the OEE percentage of the rating of each machine (0.85)
process_data = {
    'OP10A' : {'capacity':2, 'cycle_time':11.38, 'OEE':0.8313}, # saw billet to length SAW
    'OP20A' : {'capacity':2, 'cycle_time':3.78, 'OEE':0.4259},  # induction heater press 1 
    'OP30A' : {'capacity':1, 'cycle_time':6.32, 'OEE':0.4259},  # Press 1 
    
    'OP10B' : {'capacity':2, 'cycle_time':6.55, 'OEE':0.8313},  # saw billet to length BC
    'OP20B' : {'capacity':1, 'cycle_time':3.78, 'OEE':0.4259},  # induction heater press 2 
    'OP30B' : {'capacity':1, 'cycle_time':3.67, 'OEE':0.4259},  # Press 2
    
    # shared sequence 
    'OP40'  : {'capacity':3, 'cycle_time':8.21, 'OEE':0.8050},  # saw cavity to length
    'OP50'  : {'capacity':2, 'cycle_time':2.46, 'OEE':0.8330},  # clean cavity 
    'OP60'  : {'capacity':5, 'cycle_time':11.33, 'OEE':0.4242}, # machine pre-nose external
    'OP65'  : {'capacity':3, 'cycle_time':10.63, 'OEE':0.7251}, # machine pre-nose internal 
    'OP66'  : {'capacity':3, 'cycle_time':10.28, 'OEE':0.8},    # machine base recess groove for heat treatment 
}



# Define distinct operation sequences for each line
lineA_sequence = ['OP10A', 'OP20A', 'OP30A']  # Upstream ops for line A
lineB_sequence = ['OP10B', 'OP20B', 'OP30B']  # Upstream ops for line B

# Shared sequence after both lines
shared_sequence = ['OP40', 'OP50', 'OP60', 'OP65', 'OP66']

# batch sequence routing 
next_station = {
    'OP10A': 'OP20A',
    'OP20A': 'OP30A',
    'OP30A': 'OP40',
    'OP10B': 'OP20B',
    'OP20B': 'OP30B',
    'OP30B': 'OP40',
    'OP40':  'OP50',
    'OP50':  'OP60',
    'OP60':  'OP65',
    'OP65':  'OP66',
    'OP66':  None  # final
}

transport_times = {
    ('OP10A','OP20A'): 1.0488,
    ('OP10B','OP20B'): 1.0813,
    ('OP20A','OP30A'): 3,
    ('OP20B','OP30B'): 3,
    ('OP30A','OP40') : 1.2114,
    ('OP30B','OP40') : 1.2114,
    ('OP40','OP50')  : 1.1301,
    ('OP50','OP60')  : 1.8130,
    ('OP60','OP65')  : 1.0488,
    ('OP65','OP66')  : 1.1301,
}

# %%
# Simulation time
SIM_TIME = 1150

# ---------------------------------------------------------------------
# 6) Downtime process
# ---------------------------------------------------------------------
def downtime_process(env, op_name, resource, data, machine_status):
    """
    Continuously cycles machine up->down->up, controlling machine_status[op_name].
    """
    capacity = data['capacity']
    oee = data['OEE']

    mean_time_to_fail = 50.0
    mean_time_to_repair = mean_time_to_fail * (1 - oee) / oee

    while True:
        # Machine is up
        machine_status[op_name] = True
        ttf = random.expovariate(1.0 / mean_time_to_fail)
        yield env.timeout(ttf)

        # Machine goes down (seize full capacity)
        requests = []
        for _ in range(capacity):
            r = resource.request(priority=-999)
            yield r
            requests.append(r)

        machine_status[op_name] = False
        print(f"*** [{env.now:.2f}] {op_name} is DOWN ***")

        # Repair
        ttr = random.expovariate(1.0 / mean_time_to_repair)
        yield env.timeout(ttr)

        # Machine is back up
        for r in requests:
            resource.release(r)
        print(f"*** [{env.now:.2f}] {op_name} is UP ***")




def run_simulation():
    """
    Run a pull-based simulation where no new part is created on line A (or B)
    unless:
      - OP30A (or OP30B) is up,
      - WIP < 50 in front of OP20A (or OP20B),
      - OP10 is truly idle (seized in the generator).
    The arrival rate is effectively OP10's cycle time.
    """
    # 1) Seed & environment
    random.seed(42)
    env = simpy.Environment()

    # 2) Data collector
    results = []

    # 3) Create resources & track machine status (up/down)
    resources = {}
    machine_status = {}
    for op_name, data in process_data.items():
        cap = data['capacity']
        resources[op_name] = simpy.PriorityResource(env, capacity=cap)
        machine_status[op_name] = True  # machine starts up

    # 4) Start downtime processes
    for op_name, data in process_data.items():
        env.process(downtime_process(env, op_name, resources[op_name], data, machine_status))

    # ---------------------------------------------------------------------
    # 4.1) Pull generators (now defined INSIDE run_simulation)
    # ---------------------------------------------------------------------
    def line_A_generator(env):
        """
        Continuously tries to produce new parts for line A from the yard,
        but only if:
          - OP30A is up (machine_status['OP30A'] == True)
          - WIP < 50 in front of OP20A
        Once conditions are met, it *seizes* OP10A, waits OP10A's cycle time,
        then spawns a new part for OP20A->OP30A->shared.
        """
        part_id = 0
        res_10A = resources['OP10A']

        while True:
            # Wait until line A conditions
            yield env.process(wait_for_line_A_conditions(env, resources, machine_status))

            # Seize OP10A so we're sure it's idle
            with res_10A.request(priority=0) as req:
                yield req
                cycle_time = process_data['OP10A']['cycle_time']
                yield env.timeout(cycle_time)

            # Now create a new part & run it through part_flow
            part_id += 1
            env.process(part_flow(env, f"A-{part_id}", lineA_sequence,
                                  shared_sequence, resources, results))

    def line_B_generator(env):
        """
        Same logic for line B, checking OP30B and WIP < 50 in front of OP20B.
        Seize OP10B, wait cycle_time, then spawn part for OP20B->OP30B->shared.
        """
        part_id = 0
        res_10B = resources['OP10B']

        while True:
            yield env.process(wait_for_line_B_conditions(env, resources, machine_status))

            with res_10B.request(priority=0) as req:
                yield req
                cycle_time = process_data['OP10B']['cycle_time']
                yield env.timeout(cycle_time)

            part_id += 1
            env.process(part_flow(env, f"B-{part_id}", lineB_sequence,
                                  shared_sequence, resources, results))

    # ---------------------------------------------------------------------
    # 4.2) Condition checks
    # ---------------------------------------------------------------------
    def wait_for_line_A_conditions(env, resources, machine_status):
        """Yield until OP30A is up AND the WIP before OP20A < 50."""
        while True:
            if not machine_status['OP30A']:
                yield env.timeout(1.0)
                continue

            wip_op20A = resources['OP20A'].count + len(resources['OP20A'].queue)
            if wip_op20A >= 50:
                yield env.timeout(1.0)
                continue

            return  # conditions satisfied

    def wait_for_line_B_conditions(env, resources, machine_status):
        """Yield until OP30B is up AND the WIP before OP20B < 50."""
        while True:
            if not machine_status['OP30B']:
                yield env.timeout(1.0)
                continue

            wip_op20B = resources['OP20B'].count + len(resources['OP20B'].queue)
            if wip_op20B >= 50:
                yield env.timeout(1.0)
                continue

            return  # conditions satisfied

    # ---------------------------------------------------------------------
    # 5) Part flow & operation
    # ---------------------------------------------------------------------
#     def part_flow(env, part_id, line_sequence, shared_sequence, resources, results):
#         arrival_time = env.now
#         print(f"[{arrival_time:.2f}] Part {part_id} enters system.")

#         # Upstream line (OP20->OP30 for line A or B)
#         for op_name in line_sequence:
#             yield from run_one_operation(env, part_id, op_name, resources)

#         # Shared ops (OP40->OP50->OP60->OP65->OP66)
#         for op_name in shared_sequence:
#             yield from run_one_operation(env, part_id, op_name, resources)

#         departure_time = env.now
#         TIS = departure_time - arrival_time
#         print(f"[{departure_time:.2f}] Part {part_id} COMPLETED; TIS={TIS:.2f}\n")

#         results.append({
#             'PartID': part_id,
#             'ArrivalTime': arrival_time,
#             'DepartureTime': departure_time,
#             'TimeInSystem': TIS
#         })
    def part_flow(env, part_id, line_sequence, shared_sequence, resources, results):
        arrival_time = env.now

        # Combine line + shared into one route
        full_routing = list(line_sequence) + list(shared_sequence)

        for i, op_name in enumerate(full_routing):
            yield from run_one_operation(env, part_id, op_name, resources)

            # If there's a next operation, wait transport time if any
            if i < len(full_routing) - 1:
                next_op = full_routing[i + 1]
                t_time = transport_times.get((op_name, next_op), 0.0)
                yield env.timeout(t_time)

        departure_time = env.now
        TIS = departure_time - arrival_time
        results.append({'PartID': part_id,
                        'ArrivalTime': arrival_time,
                        'DepartureTime': departure_time,
                        'TimeInSystem': TIS})

    def run_one_operation(env, part_id, op_name, resources):
        """Seize station resource, process for cycle_time."""
        with resources[op_name].request(priority=0) as req:
            yield req
            start_op = env.now
            cycle_time = process_data[op_name]['cycle_time']
            print(f"  [{start_op:.2f}] Part {part_id} starts {op_name} (ct={cycle_time:.2f})")

            yield env.timeout(cycle_time)
            finish_op = env.now
            print(f"  [{finish_op:.2f}] Part {part_id} finishes {op_name}, "
                  f"duration={finish_op - start_op:.2f}")

                # 7) Start line generators
    env.process(line_A_generator(env))
    env.process(line_B_generator(env))

    # 8) Run simulation
    env.run(until=SIM_TIME)
    print("\nSimulation complete.\n")

    # Convert list of dicts -> DataFrame
    return pd.DataFrame(results)

# -------------------------------------------------------------------------
# 7) Run the simulation
# -------------------------------------------------------------------------
if __name__ == '__main__':
    df = run_simulation()
# Out:
# *** [1.27] OP20A is DOWN ***
# *** [1.51] OP65 is DOWN ***
# *** [2.02] OP65 is UP ***
# *** [4.55] OP50 is DOWN ***
#   [6.55] Part B-1 starts OP10B (ct=6.55)
#   [11.38] Part A-1 starts OP10A (ct=11.38)
# *** [12.34] OP66 is DOWN ***
#   [13.10] Part B-1 finishes OP10B, duration=6.55
#   [13.10] Part B-2 starts OP10B (ct=6.55)
# *** [13.11] OP65 is DOWN ***
#   [14.18] Part B-1 starts OP20B (ct=3.78)
# *** [15.07] OP50 is UP ***
# *** [16.08] OP30A is DOWN ***
# *** [17.83] OP65 is UP ***
#   [17.96] Part B-1 finishes OP20B, duration=3.78
# *** [18.15] OP65 is DOWN ***
#   [19.65] Part B-2 finishes OP10B, duration=6.55
# *** [19.65] OP10B is DOWN ***
#   [20.73] Part B-2 starts OP20B (ct=3.78)
#   [20.96] Part B-1 starts OP30B (ct=3.67)
# *** [22.18] OP66 is UP ***
#   [22.76] Part A-1 finishes OP10A, duration=11.38
#   [22.76] Part A-2 starts OP10A (ct=11.38)
#   [24.51] Part B-2 finishes OP20B, duration=3.78
#   [24.63] Part B-1 finishes OP30B, duration=3.67
#   [25.84] Part B-1 starts OP40 (ct=8.21)
# *** [27.40] OP60 is DOWN ***
#   [27.51] Part B-2 starts OP30B (ct=3.67)
#   [31.18] Part B-2 finishes OP30B, duration=3.67
# *** [31.80] OP10B is UP ***
#   [32.39] Part B-2 starts OP40 (ct=8.21)
#   [34.05] Part B-1 finishes OP40, duration=8.21
#   [34.14] Part A-2 finishes OP10A, duration=11.38
#   [35.18] Part B-1 starts OP50 (ct=2.46)
#   [37.64] Part B-1 finishes OP50, duration=2.46
#   [38.35] Part B-3 starts OP10B (ct=6.55)
# *** [38.87] OP60 is UP ***
#   [39.46] Part B-1 starts OP60 (ct=11.33)
#   [40.60] Part B-2 finishes OP40, duration=8.21
#   [41.73] Part B-2 starts OP50 (ct=2.46)
# *** [42.97] OP66 is DOWN ***
# *** [44.19] OP66 is UP ***
#   [44.19] Part B-2 finishes OP50, duration=2.46
#   [44.90] Part B-3 finishes OP10B, duration=6.55
#   [44.90] Part B-4 starts OP10B (ct=6.55)
#   [45.98] Part B-3 starts OP20B (ct=3.78)
#   [46.01] Part B-2 starts OP60 (ct=11.33)
# *** [48.71] OP20A is UP ***
#   [48.71] Part A-1 starts OP20A (ct=3.78)
#   [48.71] Part A-2 starts OP20A (ct=3.78)
# *** [49.22] OP65 is UP ***
# *** [49.27] OP66 is DOWN ***
#   [49.76] Part B-3 finishes OP20B, duration=3.78
#   [50.79] Part B-1 finishes OP60, duration=11.33
# *** [51.00] OP10A is DOWN ***
#   [51.45] Part B-4 finishes OP10B, duration=6.55
#   [51.45] Part B-5 starts OP10B (ct=6.55)
#   [51.83] Part B-1 starts OP65 (ct=10.63)
#   [52.49] Part A-1 finishes OP20A, duration=3.78
#   [52.49] Part A-2 finishes OP20A, duration=3.78
#   [52.53] Part B-4 starts OP20B (ct=3.78)
#   [52.76] Part B-3 starts OP30B (ct=3.67)
#   [56.31] Part B-4 finishes OP20B, duration=3.78
#   [56.43] Part B-3 finishes OP30B, duration=3.67
# *** [56.46] OP30B is DOWN ***
#   [57.34] Part B-2 finishes OP60, duration=11.33
#   [57.65] Part B-3 starts OP40 (ct=8.21)
#   [58.00] Part B-5 finishes OP10B, duration=6.55
#   [58.00] Part B-6 starts OP10B (ct=6.55)
#   [58.38] Part B-2 starts OP65 (ct=10.63)
#   [59.08] Part B-5 starts OP20B (ct=3.78)
# *** [59.39] OP60 is DOWN ***
# *** [59.56] OP50 is DOWN ***
#   [62.46] Part B-1 finishes OP65, duration=10.63
#   [62.86] Part B-5 finishes OP20B, duration=3.78
# *** [64.28] OP10A is UP ***
# *** [64.33] OP50 is UP ***
#   [64.55] Part B-6 finishes OP10B, duration=6.55
#   [65.63] Part B-6 starts OP20B (ct=3.78)
#   [65.86] Part B-3 finishes OP40, duration=8.21
#   [66.99] Part B-3 starts OP50 (ct=2.46)
#   [69.01] Part B-2 finishes OP65, duration=10.63
#   [69.41] Part B-6 finishes OP20B, duration=3.78
# *** [69.41] OP20B is DOWN ***
#   [69.45] Part B-3 finishes OP50, duration=2.46
# *** [69.85] OP66 is UP ***
#   [69.85] Part B-1 starts OP66 (ct=10.28)
#   [70.14] Part B-2 starts OP66 (ct=10.28)
#   [80.13] Part B-1 finishes OP66, duration=10.28
#   [80.42] Part B-2 finishes OP66, duration=10.28
# *** [95.50] OP65 is DOWN ***
# *** [104.43] OP10A is DOWN ***
# *** [108.25] OP30B is UP ***
#   [108.25] Part B-4 starts OP30B (ct=3.67)
# *** [111.36] OP40 is DOWN ***
# *** [111.83] OP65 is UP ***
#   [111.92] Part B-4 finishes OP30B, duration=3.67
# *** [111.92] OP30B is DOWN ***
# *** [114.50] OP40 is UP ***
#   [114.50] Part B-4 starts OP40 (ct=8.21)
#   [115.55] Part B-7 starts OP10B (ct=6.55)
# *** [116.80] OP10A is UP ***
# *** [117.52] OP30B is UP ***
#   [117.52] Part B-5 starts OP30B (ct=3.67)
#   [121.19] Part B-5 finishes OP30B, duration=3.67
#   [121.19] Part B-6 starts OP30B (ct=3.67)
#   [122.10] Part B-7 finishes OP10B, duration=6.55
# *** [122.13] OP10A is DOWN ***
#   [122.40] Part B-5 starts OP40 (ct=8.21)
#   [122.71] Part B-4 finishes OP40, duration=8.21
#   [123.84] Part B-4 starts OP50 (ct=2.46)
#   [124.10] Part B-8 starts OP10B (ct=6.55)
#   [124.86] Part B-6 finishes OP30B, duration=3.67
#   [126.07] Part B-6 starts OP40 (ct=8.21)
#   [126.30] Part B-4 finishes OP50, duration=2.46
# *** [127.81] OP30A is UP ***
#   [127.81] Part A-1 starts OP30A (ct=6.32)
# *** [128.91] OP65 is DOWN ***
#   [130.61] Part B-5 finishes OP40, duration=8.21
#   [130.65] Part B-8 finishes OP10B, duration=6.55
#   [130.65] Part B-9 starts OP10B (ct=6.55)
#   [131.74] Part B-5 starts OP50 (ct=2.46)
# *** [132.37] OP10A is UP ***
# *** [133.80] OP30B is DOWN ***
#   [134.13] Part A-1 finishes OP30A, duration=6.32
#   [134.13] Part A-2 starts OP30A (ct=6.32)
#   [134.20] Part B-5 finishes OP50, duration=2.46
#   [134.28] Part B-6 finishes OP40, duration=8.21
# *** [134.28] OP40 is DOWN ***
# *** [134.37] OP20B is UP ***
#   [134.37] Part B-7 starts OP20B (ct=3.78)
#   [135.41] Part B-6 starts OP50 (ct=2.46)
#   [137.20] Part B-9 finishes OP10B, duration=6.55
#   [137.20] Part B-10 starts OP10B (ct=6.55)
# *** [137.67] OP65 is UP ***
#   [137.87] Part B-6 finishes OP50, duration=2.46
#   [138.15] Part B-7 finishes OP20B, duration=3.78
#   [138.15] Part B-8 starts OP20B (ct=3.78)
#   [140.45] Part A-2 finishes OP30A, duration=6.32
#   [141.93] Part B-8 finishes OP20B, duration=3.78
#   [141.93] Part B-9 starts OP20B (ct=3.78)
# *** [142.74] OP20A is DOWN ***
#   [143.75] Part A-3 starts OP10A (ct=11.38)
#   [143.75] Part B-10 finishes OP10B, duration=6.55
#   [145.71] Part B-9 finishes OP20B, duration=3.78
#   [145.71] Part B-10 starts OP20B (ct=3.78)
#   [149.49] Part B-10 finishes OP20B, duration=3.78
# *** [150.50] OP30A is DOWN ***
# *** [152.75] OP50 is DOWN ***
# *** [154.54] OP50 is UP ***
# *** [154.74] OP30B is UP ***
#   [154.74] Part B-7 starts OP30B (ct=3.67)
#   [155.13] Part A-3 finishes OP10A, duration=11.38
#   [155.13] Part A-4 starts OP10A (ct=11.38)
# *** [155.39] OP20A is UP ***
#   [156.18] Part A-3 starts OP20A (ct=3.78)
#   [158.41] Part B-7 finishes OP30B, duration=3.67
#   [158.41] Part B-8 starts OP30B (ct=3.67)
#   [159.96] Part A-3 finishes OP20A, duration=3.78
#   [161.75] Part B-11 starts OP10B (ct=6.55)
#   [162.08] Part B-8 finishes OP30B, duration=3.67
#   [162.08] Part B-9 starts OP30B (ct=3.67)
#   [165.75] Part B-9 finishes OP30B, duration=3.67
#   [165.75] Part B-10 starts OP30B (ct=3.67)
#   [166.51] Part A-4 finishes OP10A, duration=11.38
# *** [166.51] OP10A is DOWN ***
#   [167.56] Part A-4 starts OP20A (ct=3.78)
# *** [167.70] OP40 is UP ***
#   [167.70] Part A-1 starts OP40 (ct=8.21)
#   [167.70] Part A-2 starts OP40 (ct=8.21)
#   [167.70] Part B-7 starts OP40 (ct=8.21)
#   [168.30] Part B-11 finishes OP10B, duration=6.55
#   [168.30] Part B-12 starts OP10B (ct=6.55)
# *** [168.77] OP66 is DOWN ***
#   [169.38] Part B-11 starts OP20B (ct=3.78)
#   [169.42] Part B-10 finishes OP30B, duration=3.67
#   [171.34] Part A-4 finishes OP20A, duration=3.78
#   [173.16] Part B-11 finishes OP20B, duration=3.78
# *** [174.77] OP10A is UP ***
#   [174.85] Part B-12 finishes OP10B, duration=6.55
#   [174.85] Part B-13 starts OP10B (ct=6.55)
#   [175.91] Part A-1 finishes OP40, duration=8.21
#   [175.91] Part A-2 finishes OP40, duration=8.21
#   [175.91] Part B-7 finishes OP40, duration=8.21
#   [175.91] Part B-8 starts OP40 (ct=8.21)
#   [175.91] Part B-9 starts OP40 (ct=8.21)
#   [175.91] Part B-10 starts OP40 (ct=8.21)
#   [175.93] Part B-12 starts OP20B (ct=3.78)
#   [176.16] Part B-11 starts OP30B (ct=3.67)
#   [177.04] Part A-1 starts OP50 (ct=2.46)
#   [177.04] Part A-2 starts OP50 (ct=2.46)
#   [179.50] Part A-1 finishes OP50, duration=2.46
#   [179.50] Part A-2 finishes OP50, duration=2.46
#   [179.50] Part B-7 starts OP50 (ct=2.46)
#   [179.71] Part B-12 finishes OP20B, duration=3.78
#   [179.83] Part B-11 finishes OP30B, duration=3.67
#   [181.40] Part B-13 finishes OP10B, duration=6.55
#   [181.40] Part B-14 starts OP10B (ct=6.55)
#   [181.96] Part B-7 finishes OP50, duration=2.46
# *** [181.96] OP50 is DOWN ***
#   [182.48] Part B-13 starts OP20B (ct=3.78)
#   [182.71] Part B-12 starts OP30B (ct=3.67)
#   [184.12] Part B-8 finishes OP40, duration=8.21
#   [184.12] Part B-9 finishes OP40, duration=8.21
#   [184.12] Part B-10 finishes OP40, duration=8.21
#   [184.12] Part B-11 starts OP40 (ct=8.21)
# *** [184.57] OP50 is UP ***
# *** [184.64] OP65 is DOWN ***
#   [185.25] Part B-8 starts OP50 (ct=2.46)
#   [185.25] Part B-9 starts OP50 (ct=2.46)
#   [186.26] Part B-13 finishes OP20B, duration=3.78
#   [186.38] Part B-12 finishes OP30B, duration=3.67
# *** [186.58] OP20B is DOWN ***
#   [187.60] Part B-12 starts OP40 (ct=8.21)
#   [187.71] Part B-8 finishes OP50, duration=2.46
#   [187.71] Part B-9 finishes OP50, duration=2.46
#   [187.71] Part B-10 starts OP50 (ct=2.46)
#   [187.95] Part B-14 finishes OP10B, duration=6.55
#   [187.95] Part B-15 starts OP10B (ct=6.55)
#   [189.26] Part B-13 starts OP30B (ct=3.67)
#   [190.17] Part B-10 finishes OP50, duration=2.46
# *** [190.17] OP50 is DOWN ***
# *** [191.83] OP65 is UP ***
# *** [191.90] OP66 is UP ***
#   [192.33] Part B-11 finishes OP40, duration=8.21
# *** [192.54] OP50 is UP ***
#   [192.93] Part B-13 finishes OP30B, duration=3.67
#   [193.46] Part B-11 starts OP50 (ct=2.46)
#   [194.15] Part B-13 starts OP40 (ct=8.21)
#   [194.50] Part B-15 finishes OP10B, duration=6.55
#   [194.50] Part B-16 starts OP10B (ct=6.55)
#   [195.81] Part B-12 finishes OP40, duration=8.21
#   [195.92] Part B-11 finishes OP50, duration=2.46
#   [196.94] Part B-12 starts OP50 (ct=2.46)
#   [199.40] Part B-12 finishes OP50, duration=2.46
#   [201.05] Part B-16 finishes OP10B, duration=6.55
# *** [201.05] OP10B is DOWN ***
#   [202.36] Part B-13 finishes OP40, duration=8.21
#   [203.49] Part B-13 starts OP50 (ct=2.46)
#   [205.95] Part B-13 finishes OP50, duration=2.46
# *** [206.47] OP20A is DOWN ***
# *** [207.58] OP20B is UP ***
#   [207.58] Part B-14 starts OP20B (ct=3.78)
#   [211.36] Part B-14 finishes OP20B, duration=3.78
#   [211.36] Part B-15 starts OP20B (ct=3.78)
# *** [211.44] OP50 is DOWN ***
# *** [211.86] OP10B is UP ***
#   [214.36] Part B-14 starts OP30B (ct=3.67)
#   [215.14] Part B-15 finishes OP20B, duration=3.78
#   [215.14] Part B-16 starts OP20B (ct=3.78)
# *** [217.59] OP50 is UP ***
#   [218.03] Part B-14 finishes OP30B, duration=3.67
#   [218.14] Part B-15 starts OP30B (ct=3.67)
#   [218.41] Part B-17 starts OP10B (ct=6.55)
#   [218.92] Part B-16 finishes OP20B, duration=3.78
#   [219.24] Part B-14 starts OP40 (ct=8.21)
#   [259.02] Part B-19 finishes OP40, duration=8.21
# *** [259.21] OP20A is UP ***
#   [260.15] Part B-19 starts OP50 (ct=2.46)
#   [260.68] Part A-4 finishes OP40, duration=8.21
# *** [261.21] OP10B is UP ***
#   [261.22] Part A-3 finishes OP50, duration=2.46
#   [261.81] Part A-4 starts OP50 (ct=2.46)
#   [262.61] Part B-19 finishes OP50, duration=2.46
# *** [264.02] OP30A is DOWN ***
#   [264.27] Part A-4 finishes OP50, duration=2.46
# *** [265.02] OP20A is DOWN ***
#   [267.76] Part B-20 starts OP10B (ct=6.55)
#   [269.12] Part A-5 finishes OP10A, duration=11.38
#   [269.12] Part A-6 starts OP10A (ct=11.38)
#   [274.31] Part B-20 finishes OP10B, duration=6.55
#   [274.31] Part B-21 starts OP10B (ct=6.55)
#   [275.39] Part B-20 starts OP20B (ct=3.78)
# *** [278.73] OP50 is DOWN ***
#   [279.17] Part B-20 finishes OP20B, duration=3.78
# *** [279.39] OP50 is UP ***
#   [280.50] Part A-6 finishes OP10A, duration=11.38
# *** [280.50] OP10A is DOWN ***
#   [280.86] Part B-21 finishes OP10B, duration=6.55
#   [280.86] Part B-22 starts OP10B (ct=6.55)
#   [281.94] Part B-21 starts OP20B (ct=3.78)
#   [282.17] Part B-20 starts OP30B (ct=3.67)
#   [285.72] Part B-21 finishes OP20B, duration=3.78
#   [285.84] Part B-20 finishes OP30B, duration=3.67
#   [287.05] Part B-20 starts OP40 (ct=8.21)
#   [287.41] Part B-22 finishes OP10B, duration=6.55
#   [287.41] Part B-23 starts OP10B (ct=6.55)
#   [288.49] Part B-22 starts OP20B (ct=3.78)
#   [288.72] Part B-21 starts OP30B (ct=3.67)
#   [292.27] Part B-22 finishes OP20B, duration=3.78
#   [292.39] Part B-21 finishes OP30B, duration=3.67
#   [293.60] Part B-21 starts OP40 (ct=8.21)
#   [293.96] Part B-23 finishes OP10B, duration=6.55
#   [293.96] Part B-24 starts OP10B (ct=6.55)
#   [295.04] Part B-23 starts OP20B (ct=3.78)
#   [295.26] Part B-20 finishes OP40, duration=8.21
#   [295.27] Part B-22 starts OP30B (ct=3.67)
#   [296.39] Part B-20 starts OP50 (ct=2.46)
# *** [296.42] OP66 is DOWN ***
#   [298.82] Part B-23 finishes OP20B, duration=3.78
#   [298.85] Part B-20 finishes OP50, duration=2.46
#   [298.94] Part B-22 finishes OP30B, duration=3.67
#   [300.15] Part B-22 starts OP40 (ct=8.21)
#   [300.51] Part B-24 finishes OP10B, duration=6.55
#   [300.51] Part B-25 starts OP10B (ct=6.55)
#   [301.59] Part B-24 starts OP20B (ct=3.78)
#   [301.81] Part B-21 finishes OP40, duration=8.21
#   [301.82] Part B-23 starts OP30B (ct=3.67)
# *** [301.99] OP20A is UP ***
#   [301.99] Part A-5 starts OP20A (ct=3.78)
#   [301.99] Part A-6 starts OP20A (ct=3.78)
#   [302.94] Part B-21 starts OP50 (ct=2.46)
# *** [304.82] OP60 is UP ***
#   [304.82] Part B-3 starts OP60 (ct=11.33)
#   [304.82] Part B-4 starts OP60 (ct=11.33)
#   [304.82] Part B-5 starts OP60 (ct=11.33)
#   [304.82] Part B-6 starts OP60 (ct=11.33)
#   [304.82] Part A-1 starts OP60 (ct=11.33)
#   [305.37] Part B-24 finishes OP20B, duration=3.78
#   [305.40] Part B-21 finishes OP50, duration=2.46
# *** [305.40] OP50 is DOWN ***
#   [305.49] Part B-23 finishes OP30B, duration=3.67
# *** [305.52] OP50 is UP ***
#   [305.77] Part A-5 finishes OP20A, duration=3.78
#   [305.77] Part A-6 finishes OP20A, duration=3.78
# *** [305.83] OP66 is UP ***
#   [306.70] Part B-23 starts OP40 (ct=8.21)
#   [307.06] Part B-25 finishes OP10B, duration=6.55
#   [307.06] Part B-26 starts OP10B (ct=6.55)
#   [308.14] Part B-25 starts OP20B (ct=3.78)
#   [308.36] Part B-22 finishes OP40, duration=8.21
#   [308.37] Part B-24 starts OP30B (ct=3.67)
#   [309.49] Part B-22 starts OP50 (ct=2.46)
#   [311.92] Part B-25 finishes OP20B, duration=3.78
#   [311.95] Part B-22 finishes OP50, duration=2.46
#   [312.04] Part B-24 finishes OP30B, duration=3.67
#   [313.25] Part B-24 starts OP40 (ct=8.21)
#   [313.61] Part B-26 finishes OP10B, duration=6.55
#   [313.61] Part B-27 starts OP10B (ct=6.55)
#   [314.69] Part B-26 starts OP20B (ct=3.78)
#   [314.91] Part B-23 finishes OP40, duration=8.21
#   [314.92] Part B-25 starts OP30B (ct=3.67)
#   [316.04] Part B-23 starts OP50 (ct=2.46)
#   [316.15] Part B-3 finishes OP60, duration=11.33
#   [316.15] Part B-4 finishes OP60, duration=11.33
#   [316.15] Part B-5 finishes OP60, duration=11.33
#   [316.15] Part B-6 finishes OP60, duration=11.33
#   [316.15] Part A-1 finishes OP60, duration=11.33
#   [316.15] Part A-2 starts OP60 (ct=11.33)
#   [316.15] Part B-7 starts OP60 (ct=11.33)
#   [316.15] Part B-8 starts OP60 (ct=11.33)
#   [316.15] Part B-9 starts OP60 (ct=11.33)
#   [316.15] Part B-10 starts OP60 (ct=11.33)
#   [317.20] Part B-3 starts OP65 (ct=10.63)
#   [317.20] Part B-4 starts OP65 (ct=10.63)
#   [317.20] Part B-5 starts OP65 (ct=10.63)
#   [318.47] Part B-26 finishes OP20B, duration=3.78
#   [318.50] Part B-23 finishes OP50, duration=2.46
#   [318.59] Part B-25 finishes OP30B, duration=3.67
#   [319.80] Part B-25 starts OP40 (ct=8.21)
#   [320.16] Part B-27 finishes OP10B, duration=6.55
# *** [320.16] OP10B is DOWN ***
#   [321.24] Part B-27 starts OP20B (ct=3.78)
#   [321.46] Part B-24 finishes OP40, duration=8.21
#   [321.47] Part B-26 starts OP30B (ct=3.67)
#   [322.59] Part B-24 starts OP50 (ct=2.46)
#   [325.02] Part B-27 finishes OP20B, duration=3.78
#   [325.05] Part B-24 finishes OP50, duration=2.46
#   [325.14] Part B-26 finishes OP30B, duration=3.67
#   [326.35] Part B-26 starts OP40 (ct=8.21)
#   [327.48] Part A-2 finishes OP60, duration=11.33
#   [327.48] Part B-7 finishes OP60, duration=11.33
#   [327.48] Part B-8 finishes OP60, duration=11.33
#   [327.48] Part B-9 finishes OP60, duration=11.33
#   [327.48] Part B-10 finishes OP60, duration=11.33
#   [327.48] Part B-11 starts OP60 (ct=11.33)
#   [327.48] Part B-12 starts OP60 (ct=11.33)
#   [327.48] Part B-13 starts OP60 (ct=11.33)
#   [327.48] Part B-14 starts OP60 (ct=11.33)
#   [327.48] Part B-15 starts OP60 (ct=11.33)
#   [327.83] Part B-3 finishes OP65, duration=10.63
#   [327.83] Part B-4 finishes OP65, duration=10.63
#   [327.83] Part B-5 finishes OP65, duration=10.63
#   [327.83] Part B-6 starts OP65 (ct=10.63)
#   [327.83] Part A-1 starts OP65 (ct=10.63)
# *** [327.97] OP10B is UP ***
#   [328.01] Part B-25 finishes OP40, duration=8.21
#   [328.02] Part B-27 starts OP30B (ct=3.67)
#   [328.53] Part A-2 starts OP65 (ct=10.63)
#   [328.96] Part B-3 starts OP66 (ct=10.28)
#   [328.96] Part B-4 starts OP66 (ct=10.28)
#   [328.96] Part B-5 starts OP66 (ct=10.28)
#   [329.14] Part B-25 starts OP50 (ct=2.46)
# *** [330.57] OP20B is DOWN ***
#   [331.60] Part B-25 finishes OP50, duration=2.46
#   [331.69] Part B-27 finishes OP30B, duration=3.67
#   [332.90] Part B-27 starts OP40 (ct=8.21)
#   [334.52] Part B-28 starts OP10B (ct=6.55)
#   [334.56] Part B-26 finishes OP40, duration=8.21
#   [335.69] Part B-26 starts OP50 (ct=2.46)
# *** [336.84] OP10A is UP ***
#   [338.15] Part B-26 finishes OP50, duration=2.46
#   [338.46] Part B-6 finishes OP65, duration=10.63
#   [338.46] Part A-1 finishes OP65, duration=10.63
#   [338.46] Part B-7 starts OP65 (ct=10.63)
#   [338.81] Part B-11 finishes OP60, duration=11.33
#   [338.81] Part B-12 finishes OP60, duration=11.33
#   [338.81] Part B-13 finishes OP60, duration=11.33
#   [338.81] Part B-14 finishes OP60, duration=11.33
#   [338.81] Part B-15 finishes OP60, duration=11.33
#   [338.81] Part B-16 starts OP60 (ct=11.33)
#   [338.81] Part B-17 starts OP60 (ct=11.33)
#   [338.81] Part B-18 starts OP60 (ct=11.33)
#   [338.81] Part A-3 starts OP60 (ct=11.33)
#   [338.81] Part B-19 starts OP60 (ct=11.33)
#   [339.16] Part A-2 finishes OP65, duration=10.63
#   [339.24] Part B-3 finishes OP66, duration=10.28
#   [339.24] Part B-4 finishes OP66, duration=10.28
#   [339.24] Part B-5 finishes OP66, duration=10.28
#   [339.59] Part B-6 starts OP66 (ct=10.28)
#   [339.59] Part A-1 starts OP66 (ct=10.28)
#   [340.29] Part A-2 starts OP66 (ct=10.28)
#   [341.07] Part B-28 finishes OP10B, duration=6.55
#   [341.07] Part B-29 starts OP10B (ct=6.55)
#   [341.11] Part B-27 finishes OP40, duration=8.21
#   [342.24] Part B-27 starts OP50 (ct=2.46)
# *** [342.75] OP10A is DOWN ***
#   [344.70] Part B-27 finishes OP50, duration=2.46
#   [347.62] Part B-29 finishes OP10B, duration=6.55
#   [347.62] Part B-30 starts OP10B (ct=6.55)
# *** [348.54] OP10A is UP ***
#   [349.09] Part B-7 finishes OP65, duration=10.63
# *** [349.09] OP65 is DOWN ***
#   [349.87] Part B-6 finishes OP66, duration=10.28
#   [349.87] Part A-1 finishes OP66, duration=10.28
#   [350.14] Part B-16 finishes OP60, duration=11.33
#   [350.14] Part B-17 finishes OP60, duration=11.33
#   [350.14] Part B-18 finishes OP60, duration=11.33
#   [350.14] Part A-3 finishes OP60, duration=11.33
#   [350.14] Part B-19 finishes OP60, duration=11.33
#   [350.14] Part A-4 starts OP60 (ct=11.33)
#   [350.14] Part B-20 starts OP60 (ct=11.33)
#   [350.14] Part B-21 starts OP60 (ct=11.33)
#   [350.14] Part B-22 starts OP60 (ct=11.33)
#   [350.14] Part B-23 starts OP60 (ct=11.33)
#   [350.22] Part B-7 starts OP66 (ct=10.28)
#   [350.57] Part A-2 finishes OP66, duration=10.28
#   [354.17] Part B-30 finishes OP10B, duration=6.55
# *** [354.17] OP10B is DOWN ***
#   [360.50] Part B-7 finishes OP66, duration=10.28
#   [361.47] Part A-4 finishes OP60, duration=11.33
#   [361.47] Part B-20 finishes OP60, duration=11.33
#   [361.47] Part B-21 finishes OP60, duration=11.33
#   [361.47] Part B-22 finishes OP60, duration=11.33
#   [361.47] Part B-23 finishes OP60, duration=11.33
#   [361.47] Part B-24 starts OP60 (ct=11.33)
#   [361.47] Part B-25 starts OP60 (ct=11.33)
#   [361.47] Part B-26 starts OP60 (ct=11.33)
#   [361.47] Part B-27 starts OP60 (ct=11.33)
# *** [363.07] OP66 is DOWN ***
# *** [366.89] OP66 is UP ***
# *** [369.30] OP50 is DOWN ***
# *** [369.88] OP30A is UP ***
#   [369.88] Part A-5 starts OP30A (ct=6.32)
# *** [371.27] OP50 is UP ***
#   [372.80] Part B-24 finishes OP60, duration=11.33
#   [372.80] Part B-25 finishes OP60, duration=11.33
#   [372.80] Part B-26 finishes OP60, duration=11.33
#   [372.80] Part B-27 finishes OP60, duration=11.33
# *** [375.34] OP10B is UP ***
#   [376.20] Part A-5 finishes OP30A, duration=6.32
#   [376.20] Part A-6 starts OP30A (ct=6.32)
#   [377.41] Part A-5 starts OP40 (ct=8.21)
# *** [381.50] OP10A is DOWN ***
#   [381.89] Part B-31 starts OP10B (ct=6.55)
#   [382.52] Part A-6 finishes OP30A, duration=6.32
# *** [382.67] OP30B is DOWN ***
#   [383.73] Part A-6 starts OP40 (ct=8.21)
#   [385.62] Part A-5 finishes OP40, duration=8.21
#   [386.75] Part A-5 starts OP50 (ct=2.46)
#   [388.44] Part B-31 finishes OP10B, duration=6.55
#   [388.44] Part B-32 starts OP10B (ct=6.55)
#   [389.21] Part A-5 finishes OP50, duration=2.46
#   [391.02] Part A-5 starts OP60 (ct=11.33)
# *** [391.84] OP10A is UP ***
#   [391.84] Part A-7 starts OP10A (ct=11.38)
#   [391.94] Part A-6 finishes OP40, duration=8.21
#   [393.07] Part A-6 starts OP50 (ct=2.46)
#   [394.99] Part B-32 finishes OP10B, duration=6.55
# *** [394.99] OP10B is DOWN ***
#   [395.53] Part A-6 finishes OP50, duration=2.46
#   [397.34] Part A-6 starts OP60 (ct=11.33)
# *** [399.61] OP20B is UP ***
#   [399.61] Part B-28 starts OP20B (ct=3.78)
# *** [401.61] OP66 is DOWN ***
#   [402.35] Part A-5 finishes OP60, duration=11.33
#   [403.22] Part A-7 finishes OP10A, duration=11.38
#   [403.22] Part A-8 starts OP10A (ct=11.38)
#   [403.39] Part B-28 finishes OP20B, duration=3.78
#   [403.39] Part B-29 starts OP20B (ct=3.78)
#   [404.27] Part A-7 starts OP20A (ct=3.78)
#   [407.17] Part B-29 finishes OP20B, duration=3.78
#   [407.17] Part B-30 starts OP20B (ct=3.78)
# *** [407.38] OP65 is UP ***
#   [407.38] Part B-8 starts OP65 (ct=10.63)
#   [407.38] Part B-9 starts OP65 (ct=10.63)
#   [407.38] Part B-10 starts OP65 (ct=10.63)
#   [408.05] Part A-7 finishes OP20A, duration=3.78
#   [408.67] Part A-6 finishes OP60, duration=11.33
# *** [408.67] OP60 is DOWN ***
# *** [408.71] OP60 is UP ***
# *** [409.58] OP10B is UP ***
# *** [410.56] OP10B is DOWN ***
#   [410.95] Part B-30 finishes OP20B, duration=3.78
#   [410.95] Part B-31 starts OP20B (ct=3.78)
#   [411.05] Part A-7 starts OP30A (ct=6.32)
#   [414.60] Part A-8 finishes OP10A, duration=11.38
# *** [414.60] OP10A is DOWN ***
#   [414.73] Part B-31 finishes OP20B, duration=3.78
#   [414.73] Part B-32 starts OP20B (ct=3.78)
#   [415.65] Part A-8 starts OP20A (ct=3.78)
#   [417.37] Part A-7 finishes OP30A, duration=6.32
#   [418.01] Part B-8 finishes OP65, duration=10.63
#   [418.01] Part B-9 finishes OP65, duration=10.63
#   [418.01] Part B-10 finishes OP65, duration=10.63
#   [418.01] Part B-11 starts OP65 (ct=10.63)
#   [418.01] Part B-12 starts OP65 (ct=10.63)
#   [418.01] Part B-13 starts OP65 (ct=10.63)
#   [418.51] Part B-32 finishes OP20B, duration=3.78
#   [418.58] Part A-7 starts OP40 (ct=8.21)
#   [419.43] Part A-8 finishes OP20A, duration=3.78
# *** [420.46] OP66 is UP ***
#   [420.46] Part B-8 starts OP66 (ct=10.28)
#   [420.46] Part B-9 starts OP66 (ct=10.28)
#   [420.46] Part B-10 starts OP66 (ct=10.28)
#   [422.43] Part A-8 starts OP30A (ct=6.32)
#   [426.79] Part A-7 finishes OP40, duration=8.21
#   [427.92] Part A-7 starts OP50 (ct=2.46)
# *** [428.30] OP60 is DOWN ***
#   [428.64] Part B-11 finishes OP65, duration=10.63
#   [428.64] Part B-12 finishes OP65, duration=10.63
#   [428.64] Part B-13 finishes OP65, duration=10.63
#   [428.64] Part B-14 starts OP65 (ct=10.63)
#   [428.64] Part B-15 starts OP65 (ct=10.63)
#   [428.64] Part B-16 starts OP65 (ct=10.63)
#   [460.53] Part B-20 starts OP65 (ct=10.63)
#   [461.58] Part B-17 finishes OP66, duration=10.28
#   [461.58] Part B-18 finishes OP66, duration=10.28
#   [461.58] Part A-3 finishes OP66, duration=10.28
#   [461.66] Part B-19 starts OP66 (ct=10.28)
#   [461.66] Part A-4 starts OP66 (ct=10.28)
#   [462.63] Part B-28 finishes OP50, duration=2.46
#   [462.71] Part B-29 finishes OP40, duration=8.21
#   [463.84] Part B-29 starts OP50 (ct=2.46)
#   [464.57] Part A-7 finishes OP60, duration=11.33
#   [464.57] Part A-8 finishes OP60, duration=11.33
#   [464.57] Part B-28 starts OP60 (ct=11.33)
#   [465.52] Part A-9 finishes OP10A, duration=11.38
#   [465.52] Part A-10 starts OP10A (ct=11.38)
#   [466.09] Part B-34 finishes OP10B, duration=6.55
#   [466.30] Part B-29 finishes OP50, duration=2.46
#   [466.57] Part A-9 starts OP20A (ct=3.78)
#   [470.35] Part A-9 finishes OP20A, duration=3.78
#   [471.16] Part B-20 finishes OP65, duration=10.63
# *** [471.16] OP65 is DOWN ***
#   [471.94] Part B-19 finishes OP66, duration=10.28
#   [471.94] Part A-4 finishes OP66, duration=10.28
#   [472.29] Part B-20 starts OP66 (ct=10.28)
#   [473.35] Part A-9 starts OP30A (ct=6.32)
# *** [473.48] OP50 is DOWN ***
# *** [473.76] OP65 is UP ***
#   [473.76] Part B-21 starts OP65 (ct=10.63)
#   [473.76] Part B-22 starts OP65 (ct=10.63)
#   [473.76] Part B-23 starts OP65 (ct=10.63)
#   [475.90] Part B-28 finishes OP60, duration=11.33
# *** [475.90] OP60 is DOWN ***
#   [476.90] Part A-10 finishes OP10A, duration=11.38
#   [476.90] Part A-11 starts OP10A (ct=11.38)
#   [477.95] Part A-10 starts OP20A (ct=3.78)
#   [479.67] Part A-9 finishes OP30A, duration=6.32
# *** [479.94] OP50 is UP ***
#   [480.88] Part A-9 starts OP40 (ct=8.21)
#   [481.73] Part A-10 finishes OP20A, duration=3.78
# *** [481.73] OP20A is DOWN ***
#   [482.57] Part B-20 finishes OP66, duration=10.28
#   [484.39] Part B-21 finishes OP65, duration=10.63
#   [484.39] Part B-22 finishes OP65, duration=10.63
#   [484.39] Part B-23 finishes OP65, duration=10.63
#   [484.39] Part B-24 starts OP65 (ct=10.63)
#   [484.39] Part B-25 starts OP65 (ct=10.63)
#   [484.39] Part B-26 starts OP65 (ct=10.63)
#   [484.73] Part A-10 starts OP30A (ct=6.32)
#   [485.52] Part B-21 starts OP66 (ct=10.28)
#   [485.52] Part B-22 starts OP66 (ct=10.28)
#   [485.52] Part B-23 starts OP66 (ct=10.28)
#   [488.28] Part A-11 finishes OP10A, duration=11.38
#   [488.28] Part A-12 starts OP10A (ct=11.38)
#   [489.09] Part A-9 finishes OP40, duration=8.21
#   [490.22] Part A-9 starts OP50 (ct=2.46)
#   [491.05] Part A-10 finishes OP30A, duration=6.32
# *** [491.76] OP30A is DOWN ***
#   [492.26] Part A-10 starts OP40 (ct=8.21)
#   [492.68] Part A-9 finishes OP50, duration=2.46
#   [495.02] Part B-24 finishes OP65, duration=10.63
#   [495.02] Part B-25 finishes OP65, duration=10.63
#   [495.02] Part B-26 finishes OP65, duration=10.63
#   [495.02] Part B-27 starts OP65 (ct=10.63)
#   [495.02] Part A-5 starts OP65 (ct=10.63)
#   [495.02] Part A-6 starts OP65 (ct=10.63)
#   [495.80] Part B-21 finishes OP66, duration=10.28
#   [495.80] Part B-22 finishes OP66, duration=10.28
#   [495.80] Part B-23 finishes OP66, duration=10.28
#   [496.15] Part B-24 starts OP66 (ct=10.28)
#   [496.15] Part B-25 starts OP66 (ct=10.28)
#   [496.15] Part B-26 starts OP66 (ct=10.28)
# *** [496.80] OP60 is UP ***
#   [496.80] Part B-29 starts OP60 (ct=11.33)
#   [496.80] Part A-9 starts OP60 (ct=11.33)
#   [499.66] Part A-12 finishes OP10A, duration=11.38
#   [499.66] Part A-13 starts OP10A (ct=11.38)
#   [500.47] Part A-10 finishes OP40, duration=8.21
#   [501.60] Part A-10 starts OP50 (ct=2.46)
#   [504.06] Part A-10 finishes OP50, duration=2.46
#   [505.65] Part B-27 finishes OP65, duration=10.63
#   [505.65] Part A-5 finishes OP65, duration=10.63
#   [505.65] Part A-6 finishes OP65, duration=10.63
#   [505.65] Part A-7 starts OP65 (ct=10.63)
#   [505.65] Part A-8 starts OP65 (ct=10.63)
#   [505.65] Part B-28 starts OP65 (ct=10.63)
#   [505.87] Part A-10 starts OP60 (ct=11.33)
#   [506.43] Part B-24 finishes OP66, duration=10.28
#   [506.43] Part B-25 finishes OP66, duration=10.28
#   [506.43] Part B-26 finishes OP66, duration=10.28
#   [506.78] Part B-27 starts OP66 (ct=10.28)
#   [506.78] Part A-5 starts OP66 (ct=10.28)
#   [506.78] Part A-6 starts OP66 (ct=10.28)
# *** [507.80] OP30A is UP ***
#   [508.13] Part B-29 finishes OP60, duration=11.33
#   [508.13] Part A-9 finishes OP60, duration=11.33
#   [511.04] Part A-13 finishes OP10A, duration=11.38
#   [516.28] Part A-7 finishes OP65, duration=10.63
#   [516.28] Part A-8 finishes OP65, duration=10.63
#   [516.28] Part B-28 finishes OP65, duration=10.63
#   [516.28] Part B-29 starts OP65 (ct=10.63)
#   [516.28] Part A-9 starts OP65 (ct=10.63)
#   [517.06] Part B-27 finishes OP66, duration=10.28
#   [517.06] Part A-5 finishes OP66, duration=10.28
#   [517.06] Part A-6 finishes OP66, duration=10.28
# *** [517.06] OP66 is DOWN ***
#   [517.20] Part A-10 finishes OP60, duration=11.33
# *** [518.81] OP20A is UP ***
#   [518.81] Part A-11 starts OP20A (ct=3.78)
#   [518.81] Part A-12 starts OP20A (ct=3.78)
# *** [519.87] OP66 is UP ***
#   [519.87] Part A-7 starts OP66 (ct=10.28)
#   [519.87] Part A-8 starts OP66 (ct=10.28)
#   [519.87] Part B-28 starts OP66 (ct=10.28)
#   [520.04] Part A-14 starts OP10A (ct=11.38)
#   [522.59] Part A-11 finishes OP20A, duration=3.78
#   [522.59] Part A-12 finishes OP20A, duration=3.78
#   [522.59] Part A-13 starts OP20A (ct=3.78)
#   [525.59] Part A-11 starts OP30A (ct=6.32)
#   [526.37] Part A-13 finishes OP20A, duration=3.78
#   [526.91] Part B-29 finishes OP65, duration=10.63
#   [526.91] Part A-9 finishes OP65, duration=10.63
#   [526.91] Part A-10 starts OP65 (ct=10.63)
#   [530.15] Part A-7 finishes OP66, duration=10.28
#   [530.15] Part A-8 finishes OP66, duration=10.28
#   [530.15] Part B-28 finishes OP66, duration=10.28
#   [530.15] Part B-29 starts OP66 (ct=10.28)
#   [530.15] Part A-9 starts OP66 (ct=10.28)
#   [531.42] Part A-14 finishes OP10A, duration=11.38
#   [531.42] Part A-15 starts OP10A (ct=11.38)
#   [531.91] Part A-11 finishes OP30A, duration=6.32
#   [531.91] Part A-12 starts OP30A (ct=6.32)
#   [532.47] Part A-14 starts OP20A (ct=3.78)
#   [533.12] Part A-11 starts OP40 (ct=8.21)
# *** [535.55] OP60 is DOWN ***
#   [536.25] Part A-14 finishes OP20A, duration=3.78
# *** [537.48] OP20A is DOWN ***
#   [537.54] Part A-10 finishes OP65, duration=10.63
# *** [537.54] OP65 is DOWN ***
#   [538.23] Part A-12 finishes OP30A, duration=6.32
#   [538.23] Part A-13 starts OP30A (ct=6.32)
#   [538.67] Part A-10 starts OP66 (ct=10.28)
#   [539.44] Part A-12 starts OP40 (ct=8.21)
#   [540.43] Part B-29 finishes OP66, duration=10.28
#   [540.43] Part A-9 finishes OP66, duration=10.28
#   [541.33] Part A-11 finishes OP40, duration=8.21
#   [542.46] Part A-11 starts OP50 (ct=2.46)
# *** [542.61] OP10B is DOWN ***
#   [542.80] Part A-15 finishes OP10A, duration=11.38
# *** [542.80] OP10A is DOWN ***
# *** [543.91] OP10B is UP ***
#   [544.55] Part A-13 finishes OP30A, duration=6.32
#   [544.55] Part A-14 starts OP30A (ct=6.32)
#   [544.92] Part A-11 finishes OP50, duration=2.46
# *** [545.38] OP10A is UP ***
#   [547.65] Part A-12 finishes OP40, duration=8.21
# *** [547.65] OP40 is DOWN ***
#   [548.78] Part A-12 starts OP50 (ct=2.46)
#   [548.95] Part A-10 finishes OP66, duration=10.28
# *** [549.65] OP30B is UP ***
#   [549.65] Part B-30 starts OP30B (ct=3.67)
# *** [550.81] OP40 is UP ***
#   [550.81] Part A-13 starts OP40 (ct=8.21)
#   [550.87] Part A-14 finishes OP30A, duration=6.32
#   [551.24] Part A-12 finishes OP50, duration=2.46
# *** [551.36] OP65 is UP ***
#   [552.08] Part A-14 starts OP40 (ct=8.21)
#   [553.32] Part B-30 finishes OP30B, duration=3.67
#   [553.32] Part B-31 starts OP30B (ct=3.67)
#   [556.76] Part A-16 starts OP10A (ct=11.38)
#   [556.99] Part B-31 finishes OP30B, duration=3.67
#   [556.99] Part B-32 starts OP30B (ct=3.67)
#   [557.09] Part B-35 starts OP10B (ct=6.55)
#   [559.02] Part A-13 finishes OP40, duration=8.21
#   [560.15] Part A-13 starts OP50 (ct=2.46)
#   [560.29] Part A-14 finishes OP40, duration=8.21
# *** [560.29] OP40 is DOWN ***
#   [560.66] Part B-32 finishes OP30B, duration=3.67
#   [561.42] Part A-14 starts OP50 (ct=2.46)
# *** [562.08] OP30B is DOWN ***
#   [562.61] Part A-13 finishes OP50, duration=2.46
# *** [563.44] OP40 is UP ***
#   [563.44] Part B-30 starts OP40 (ct=8.21)
#   [563.44] Part B-31 starts OP40 (ct=8.21)
#   [563.44] Part B-32 starts OP40 (ct=8.21)
#   [563.64] Part B-35 finishes OP10B, duration=6.55
#   [563.64] Part B-36 starts OP10B (ct=6.55)
#   [563.88] Part A-14 finishes OP50, duration=2.46
#   [568.14] Part A-16 finishes OP10A, duration=11.38
#   [568.14] Part A-17 starts OP10A (ct=11.38)
#   [570.19] Part B-36 finishes OP10B, duration=6.55
# *** [570.19] OP10B is DOWN ***
# *** [570.94] OP10B is UP ***
#   [571.65] Part B-30 finishes OP40, duration=8.21
#   [571.65] Part B-31 finishes OP40, duration=8.21
#   [571.65] Part B-32 finishes OP40, duration=8.21
#   [572.78] Part B-30 starts OP50 (ct=2.46)
#   [572.78] Part B-31 starts OP50 (ct=2.46)
# *** [573.25] OP30A is DOWN ***
#   [575.24] Part B-30 finishes OP50, duration=2.46
#   [575.24] Part B-31 finishes OP50, duration=2.46
#   [575.24] Part B-32 starts OP50 (ct=2.46)
# *** [576.33] OP20A is UP ***
#   [576.33] Part A-15 starts OP20A (ct=3.78)
#   [576.33] Part A-16 starts OP20A (ct=3.78)
#   [577.70] Part B-32 finishes OP50, duration=2.46
#   [579.52] Part A-17 finishes OP10A, duration=11.38
#   [579.52] Part A-18 starts OP10A (ct=11.38)
#   [580.11] Part A-15 finishes OP20A, duration=3.78
#   [580.11] Part A-16 finishes OP20A, duration=3.78
#   [580.57] Part A-17 starts OP20A (ct=3.78)
# *** [582.90] OP50 is DOWN ***
# *** [584.32] OP50 is UP ***
#   [584.35] Part A-17 finishes OP20A, duration=3.78
# *** [584.53] OP10B is DOWN ***
# *** [588.39] OP20A is DOWN ***
#   [590.90] Part A-18 finishes OP10A, duration=11.38
# *** [590.90] OP10A is DOWN ***
# *** [593.12] OP10B is UP ***
# *** [601.22] OP65 is DOWN ***
# *** [605.23] OP65 is UP ***
# *** [606.48] OP10A is UP ***
# *** [606.78] OP60 is UP ***
#   [606.78] Part A-11 starts OP60 (ct=11.33)
#   [606.78] Part A-12 starts OP60 (ct=11.33)
#   [606.78] Part A-13 starts OP60 (ct=11.33)
#   [606.78] Part A-14 starts OP60 (ct=11.33)
#   [606.78] Part B-30 starts OP60 (ct=11.33)
# *** [610.33] OP65 is DOWN ***
#   [618.11] Part A-11 finishes OP60, duration=11.33
#   [618.11] Part A-12 finishes OP60, duration=11.33
#   [618.11] Part A-13 finishes OP60, duration=11.33
#   [618.11] Part A-14 finishes OP60, duration=11.33
#   [618.11] Part B-30 finishes OP60, duration=11.33
#   [618.11] Part B-31 starts OP60 (ct=11.33)
#   [618.11] Part B-32 starts OP60 (ct=11.33)
# *** [622.25] OP65 is UP ***
#   [622.25] Part A-11 starts OP65 (ct=10.63)
#   [622.25] Part A-12 starts OP65 (ct=10.63)
#   [622.25] Part A-13 starts OP65 (ct=10.63)
#   [629.44] Part B-31 finishes OP60, duration=11.33
#   [629.44] Part B-32 finishes OP60, duration=11.33
# *** [631.52] OP20A is UP ***
#   [631.52] Part A-18 starts OP20A (ct=3.78)
#   [632.88] Part A-11 finishes OP65, duration=10.63
#   [632.88] Part A-12 finishes OP65, duration=10.63
#   [632.88] Part A-13 finishes OP65, duration=10.63
#   [632.88] Part A-14 starts OP65 (ct=10.63)
#   [632.88] Part B-30 starts OP65 (ct=10.63)
#   [632.88] Part B-31 starts OP65 (ct=10.63)
#   [634.01] Part A-11 starts OP66 (ct=10.28)
#   [634.01] Part A-12 starts OP66 (ct=10.28)
#   [634.01] Part A-13 starts OP66 (ct=10.28)
# *** [634.33] OP60 is DOWN ***
# *** [634.68] OP10A is DOWN ***
#   [635.30] Part A-18 finishes OP20A, duration=3.78
# *** [635.73] OP10A is UP ***
# *** [636.28] OP20B is UP ***
#   [636.28] Part B-33 starts OP20B (ct=3.78)
#   [640.06] Part B-33 finishes OP20B, duration=3.78
#   [640.06] Part B-34 starts OP20B (ct=3.78)
#   [643.51] Part A-14 finishes OP65, duration=10.63
#   [643.51] Part B-30 finishes OP65, duration=10.63
#   [643.51] Part B-31 finishes OP65, duration=10.63
#   [643.51] Part B-32 starts OP65 (ct=10.63)
#   [643.84] Part B-34 finishes OP20B, duration=3.78
#   [643.84] Part B-35 starts OP20B (ct=3.78)
#   [644.29] Part A-11 finishes OP66, duration=10.28
#   [644.29] Part A-12 finishes OP66, duration=10.28
#   [644.29] Part A-13 finishes OP66, duration=10.28
#   [644.64] Part A-14 starts OP66 (ct=10.28)
#   [644.64] Part B-30 starts OP66 (ct=10.28)
#   [644.64] Part B-31 starts OP66 (ct=10.28)
#   [647.62] Part B-35 finishes OP20B, duration=3.78
#   [647.62] Part B-36 starts OP20B (ct=3.78)
# *** [647.77] OP30A is UP ***
#   [647.77] Part A-15 starts OP30A (ct=6.32)
#   [651.40] Part B-36 finishes OP20B, duration=3.78
#   [654.09] Part A-15 finishes OP30A, duration=6.32
#   [654.09] Part A-16 starts OP30A (ct=6.32)
#   [654.14] Part B-32 finishes OP65, duration=10.63
#   [654.92] Part A-14 finishes OP66, duration=10.28
#   [654.92] Part B-30 finishes OP66, duration=10.28
#   [654.92] Part B-31 finishes OP66, duration=10.28
#   [655.27] Part B-32 starts OP66 (ct=10.28)
#   [655.30] Part A-15 starts OP40 (ct=8.21)
# *** [657.01] OP20B is DOWN ***
#   [659.90] Part A-19 starts OP10A (ct=11.38)
#   [660.41] Part A-16 finishes OP30A, duration=6.32
#   [660.41] Part A-17 starts OP30A (ct=6.32)
#   [663.51] Part A-15 finishes OP40, duration=8.21
# *** [663.51] OP40 is DOWN ***
#   [664.64] Part A-15 starts OP50 (ct=2.46)
#   [665.55] Part B-32 finishes OP66, duration=10.28
# *** [666.06] OP40 is UP ***
#   [666.06] Part A-16 starts OP40 (ct=8.21)
#   [666.73] Part A-17 finishes OP30A, duration=6.32
#   [666.73] Part A-18 starts OP30A (ct=6.32)
#   [667.10] Part A-15 finishes OP50, duration=2.46
#   [667.94] Part A-17 starts OP40 (ct=8.21)
#   [671.28] Part A-19 finishes OP10A, duration=11.38
#   [671.28] Part A-20 starts OP10A (ct=11.38)
#   [672.33] Part A-19 starts OP20A (ct=3.78)
#   [673.05] Part A-18 finishes OP30A, duration=6.32
#   [674.26] Part A-18 starts OP40 (ct=8.21)
#   [674.27] Part A-16 finishes OP40, duration=8.21
#   [675.40] Part A-16 starts OP50 (ct=2.46)
# *** [675.50] OP10B is DOWN ***
#   [676.11] Part A-19 finishes OP20A, duration=3.78
#   [676.15] Part A-17 finishes OP40, duration=8.21
# *** [676.28] OP20B is UP ***
#   [677.28] Part A-17 starts OP50 (ct=2.46)
#   [677.86] Part A-16 finishes OP50, duration=2.46
#   [679.11] Part A-19 starts OP30A (ct=6.32)
#   [679.74] Part A-17 finishes OP50, duration=2.46
# *** [681.06] OP10B is UP ***
#   [682.47] Part A-18 finishes OP40, duration=8.21
#   [682.66] Part A-20 finishes OP10A, duration=11.38
# *** [682.66] OP10A is DOWN ***
#   [683.60] Part A-18 starts OP50 (ct=2.46)
#   [683.71] Part A-20 starts OP20A (ct=3.78)
#   [685.43] Part A-19 finishes OP30A, duration=6.32
#   [686.06] Part A-18 finishes OP50, duration=2.46
#   [686.64] Part A-19 starts OP40 (ct=8.21)
#   [687.49] Part A-20 finishes OP20A, duration=3.78
# *** [687.49] OP20A is DOWN ***
# *** [687.55] OP65 is DOWN ***
#   [690.49] Part A-20 starts OP30A (ct=6.32)
# *** [692.60] OP20B is DOWN ***
#   [694.85] Part A-19 finishes OP40, duration=8.21
# *** [695.43] OP10B is DOWN ***
# *** [695.83] OP40 is DOWN ***
# *** [695.96] OP10B is UP ***
#   [695.98] Part A-19 starts OP50 (ct=2.46)
#   [696.81] Part A-20 finishes OP30A, duration=6.32
#   [698.44] Part A-19 finishes OP50, duration=2.46
# *** [708.71] OP10A is UP ***
#   [720.09] Part A-21 starts OP10A (ct=11.38)
# *** [721.03] OP30B is UP ***
#   [721.03] Part B-33 starts OP30B (ct=3.67)
# *** [721.39] OP50 is DOWN ***
#   [724.70] Part B-33 finishes OP30B, duration=3.67
#   [724.70] Part B-34 starts OP30B (ct=3.67)
# *** [725.00] OP65 is UP ***
# *** [726.94] OP20A is UP ***
#   [728.19] Part B-37 starts OP10B (ct=6.55)
#   [728.37] Part B-34 finishes OP30B, duration=3.67
#   [728.37] Part B-35 starts OP30B (ct=3.67)
#   [731.47] Part A-21 finishes OP10A, duration=11.38
#   [731.47] Part A-22 starts OP10A (ct=11.38)
#   [732.04] Part B-35 finishes OP30B, duration=3.67
#   [732.04] Part B-36 starts OP30B (ct=3.67)
#   [732.52] Part A-21 starts OP20A (ct=3.78)
# *** [734.10] OP65 is DOWN ***
#   [734.74] Part B-37 finishes OP10B, duration=6.55
#   [734.74] Part B-38 starts OP10B (ct=6.55)
#   [735.71] Part B-36 finishes OP30B, duration=3.67
#   [736.30] Part A-21 finishes OP20A, duration=3.78
# *** [738.66] OP65 is UP ***
#   [739.30] Part A-21 starts OP30A (ct=6.32)
# *** [740.32] OP50 is UP ***
#   [741.29] Part B-38 finishes OP10B, duration=6.55
#   [741.29] Part B-39 starts OP10B (ct=6.55)
#   [742.85] Part A-22 finishes OP10A, duration=11.38
#   [742.85] Part A-23 starts OP10A (ct=11.38)
# *** [743.34] OP50 is DOWN ***
#   [743.90] Part A-22 starts OP20A (ct=3.78)
#   [745.62] Part A-21 finishes OP30A, duration=6.32
# *** [746.47] OP20B is UP ***
#   [746.47] Part B-37 starts OP20B (ct=3.78)
# *** [746.67] OP30A is DOWN ***
#   [747.68] Part A-22 finishes OP20A, duration=3.78
#   [747.84] Part B-39 finishes OP10B, duration=6.55
#   [747.84] Part B-40 starts OP10B (ct=6.55)
# *** [748.11] OP50 is UP ***
#   [750.25] Part B-37 finishes OP20B, duration=3.78
#   [750.25] Part B-38 starts OP20B (ct=3.78)
#   [753.25] Part B-37 starts OP30B (ct=3.67)
#   [754.03] Part B-38 finishes OP20B, duration=3.78
#   [754.03] Part B-39 starts OP20B (ct=3.78)
#   [754.23] Part A-23 finishes OP10A, duration=11.38
#   [754.23] Part A-24 starts OP10A (ct=11.38)
#   [754.39] Part B-40 finishes OP10B, duration=6.55
#   [754.39] Part B-41 starts OP10B (ct=6.55)
#   [755.28] Part A-23 starts OP20A (ct=3.78)
#   [756.92] Part B-37 finishes OP30B, duration=3.67
#   [757.03] Part B-38 starts OP30B (ct=3.67)
#   [757.81] Part B-39 finishes OP20B, duration=3.78
#   [757.81] Part B-40 starts OP20B (ct=3.78)
#   [759.06] Part A-23 finishes OP20A, duration=3.78
# *** [760.19] OP20A is DOWN ***
#   [760.70] Part B-38 finishes OP30B, duration=3.67
#   [760.81] Part B-39 starts OP30B (ct=3.67)
#   [760.94] Part B-41 finishes OP10B, duration=6.55
#   [760.94] Part B-42 starts OP10B (ct=6.55)
#   [761.59] Part B-40 finishes OP20B, duration=3.78
#   [762.02] Part B-41 starts OP20B (ct=3.78)
# *** [764.28] OP65 is DOWN ***
#   [764.48] Part B-39 finishes OP30B, duration=3.67
#   [764.59] Part B-40 starts OP30B (ct=3.67)
#   [765.61] Part A-24 finishes OP10A, duration=11.38
#   [765.80] Part B-41 finishes OP20B, duration=3.78
# *** [767.44] OP30A is UP ***
#   [767.44] Part A-22 starts OP30A (ct=6.32)
#   [767.49] Part B-42 finishes OP10B, duration=6.55
#   [767.49] Part B-43 starts OP10B (ct=6.55)
#   [768.26] Part B-40 finishes OP30B, duration=3.67
#   [768.57] Part B-42 starts OP20B (ct=3.78)
#   [768.80] Part B-41 starts OP30B (ct=3.67)
#   [772.35] Part B-42 finishes OP20B, duration=3.78
#   [772.47] Part B-41 finishes OP30B, duration=3.67
#   [773.76] Part A-22 finishes OP30A, duration=6.32
#   [773.76] Part A-23 starts OP30A (ct=6.32)
#   [928.97] Part B-53 starts OP30B (ct=3.67)
#   [929.49] Part A-35 starts OP50 (ct=2.46)
# *** [931.66] OP40 is UP ***
#   [931.95] Part A-35 finishes OP50, duration=2.46
# *** [932.48] OP10A is UP ***
#   [932.64] Part B-53 finishes OP30B, duration=3.67
#   [932.64] Part B-54 starts OP30B (ct=3.67)
# *** [932.65] OP50 is DOWN ***
#   [933.86] Part B-53 starts OP40 (ct=8.21)
# *** [934.20] OP66 is DOWN ***
#   [935.61] Part B-55 starts OP10B (ct=6.55)
#   [936.31] Part B-54 finishes OP30B, duration=3.67
# *** [936.46] OP50 is UP ***
#   [937.53] Part B-54 starts OP40 (ct=8.21)
#   [938.34] Part A-20 finishes OP60, duration=11.33
#   [938.34] Part B-33 finishes OP60, duration=11.33
#   [938.34] Part B-34 finishes OP60, duration=11.33
#   [938.34] Part B-35 finishes OP60, duration=11.33
#   [938.34] Part B-36 finishes OP60, duration=11.33
#   [938.34] Part A-21 starts OP60 (ct=11.33)
#   [938.34] Part B-37 starts OP60 (ct=11.33)
#   [938.34] Part B-38 starts OP60 (ct=11.33)
#   [938.34] Part B-39 starts OP60 (ct=11.33)
#   [938.69] Part A-15 finishes OP65, duration=10.63
#   [938.69] Part A-16 finishes OP65, duration=10.63
#   [938.69] Part A-17 finishes OP65, duration=10.63
#   [938.69] Part A-18 starts OP65 (ct=10.63)
#   [938.69] Part A-19 starts OP65 (ct=10.63)
#   [939.39] Part A-20 starts OP65 (ct=10.63)
# *** [940.23] OP50 is DOWN ***
#   [942.07] Part B-53 finishes OP40, duration=8.21
#   [942.16] Part B-55 finishes OP10B, duration=6.55
#   [942.16] Part B-56 starts OP10B (ct=6.55)
#   [943.24] Part B-55 starts OP20B (ct=3.78)
#   [943.86] Part A-36 starts OP10A (ct=11.38)
#   [945.74] Part B-54 finishes OP40, duration=8.21
# *** [946.37] OP50 is UP ***
#   [946.37] Part B-53 starts OP50 (ct=2.46)
#   [946.87] Part B-54 starts OP50 (ct=2.46)
#   [947.02] Part B-55 finishes OP20B, duration=3.78
#   [948.71] Part B-56 finishes OP10B, duration=6.55
# *** [948.71] OP10B is DOWN ***
#   [948.83] Part B-53 finishes OP50, duration=2.46
#   [949.32] Part A-18 finishes OP65, duration=10.63
#   [949.32] Part A-19 finishes OP65, duration=10.63
#   [949.32] Part B-33 starts OP65 (ct=10.63)
#   [949.32] Part B-34 starts OP65 (ct=10.63)
#   [949.33] Part B-54 finishes OP50, duration=2.46
#   [949.67] Part A-21 finishes OP60, duration=11.33
#   [949.67] Part B-37 finishes OP60, duration=11.33
#   [949.67] Part B-38 finishes OP60, duration=11.33
#   [949.67] Part B-39 finishes OP60, duration=11.33
#   [949.67] Part B-40 starts OP60 (ct=11.33)
#   [949.67] Part B-41 starts OP60 (ct=11.33)
#   [949.67] Part A-22 starts OP60 (ct=11.33)
#   [949.79] Part B-56 starts OP20B (ct=3.78)
#   [950.02] Part A-20 finishes OP65, duration=10.63
#   [950.02] Part B-35 starts OP65 (ct=10.63)
#   [1139.42] Part B-52 starts OP60 (ct=11.33)
#   [1139.42] Part A-33 starts OP60 (ct=11.33)
#   [1139.72] Part A-38 finishes OP30A, duration=6.32
#   [1139.72] Part A-39 starts OP30A (ct=6.32)
#   [1139.77] Part A-25 finishes OP65, duration=10.63
#   [1139.77] Part B-49 starts OP65 (ct=10.63)
#   [1139.85] Part B-44 finishes OP66, duration=10.28
#   [1139.85] Part B-45 finishes OP66, duration=10.28
#   [1139.85] Part B-46 finishes OP66, duration=10.28
# *** [1139.94] OP20B is UP ***
#   [1139.94] Part B-57 starts OP20B (ct=3.78)
#   [1140.20] Part A-24 starts OP66 (ct=10.28)
#   [1140.20] Part B-47 starts OP66 (ct=10.28)
#   [1140.59] Part A-40 finishes OP20A, duration=3.78
#   [1140.90] Part A-25 starts OP66 (ct=10.28)
#   [1140.93] Part A-38 starts OP40 (ct=8.21)
#   [1142.82] Part A-37 finishes OP40, duration=8.21
#   [1143.72] Part B-57 finishes OP20B, duration=3.78
#   [1143.72] Part B-58 starts OP20B (ct=3.78)
# *** [1143.72] OP30B is DOWN ***
#   [1143.95] Part A-37 starts OP50 (ct=2.46)
# *** [1144.20] OP10B is UP ***
#   [1144.20] Part B-70 starts OP10B (ct=6.55)
# *** [1144.37] OP30B is UP ***
#   [1146.04] Part A-39 finishes OP30A, duration=6.32
#   [1146.04] Part A-40 starts OP30A (ct=6.32)
#   [1146.41] Part A-37 finishes OP50, duration=2.46
#   [1146.72] Part B-57 starts OP30B (ct=3.67)
#   [1147.25] Part A-39 starts OP40 (ct=8.21)
#   [1147.50] Part B-58 finishes OP20B, duration=3.78
#   [1147.50] Part B-59 starts OP20B (ct=3.78)
#   [1149.14] Part A-38 finishes OP40, duration=8.21
# *** [1149.48] OP10A is UP ***
#   [1149.70] Part B-48 finishes OP65, duration=10.63
#   [1149.70] Part A-26 finishes OP65, duration=10.63
#   [1149.70] Part A-27 starts OP65 (ct=10.63)
#   [1149.70] Part A-28 starts OP65 (ct=10.63)
#
# Simulation complete.

# %%
df
df.to_csv('SimResults', index=False)

# %%
df
# Out:
#    PartID  ArrivalTime  DepartureTime  TimeInSystem
# 0     B-1     6.550000      80.126421     73.576421
# 1     B-2    13.100000      80.424700     67.324700
# 2     B-3    38.353685     339.237226    300.883541
# 3     B-4    44.903685     339.237226    294.333541
# 4     B-5    51.453685     339.237226    287.783541
# ..    ...          ...            ...           ...
# 64   A-23   742.850112    1036.010134    293.160022
# 65   B-43   767.491826    1036.010134    268.518307
# 66   B-44   774.041826    1139.851570    365.809743
# 67   B-45   780.591826    1139.851570    359.259743
# 68   B-46   787.141826    1139.851570    352.709743
#
# [69 rows x 4 columns]

# %%
# 1) BATCH SIZE & TRANSPORT TIMES
BATCH_SIZE = 42

# For reference, you have a dictionary like this:
# transport_times = {
#     ('OP10A','OP20A'): 1.0488,
#     ('OP10B','OP20B'): 1.0813,
#     ('OP20A','OP30A'): 3,
#     ('OP20B','OP30B'): 3,
#     ('OP30A','OP40') : 1.2114,
#     ('OP30B','OP40') : 1.2114,
#     ('OP40','OP50')  : 1.1301,
#     ('OP50','OP60')  : 1.8130,
#     ('OP60','OP65')  : 1.0488,
#     ('OP65','OP66')  : 1.1301,
# }
transport_times = {}  # We'll assume it's filled in above

# 3) Keep track of WIP
#    received_wip[op_name]: items waiting to be processed
#    finished_wip[op_name]: items processed but not yet transported
received_wip = defaultdict(int)
finished_wip = defaultdict(int)

# 4) Example process_data: capacity, cycle_time, OEE (passed from your dictionary)
process_data = {
    # e.g. 'OP10A': {'capacity':2, 'cycle_time':11.38, 'OEE':0.8313},
    # ...
}
machine_status = {}

def downtime_process(env, op_name, resource, data, machine_status):
    """
    Exactly as in your existing code: toggles station up/down using OEE-based MTTF/MTTR.
    """
    capacity = data['capacity']
    oee = data['OEE']

    mean_time_to_fail = 50.0
    mean_time_to_repair = mean_time_to_fail * (1 - oee) / oee

    while True:
        # Machine is up
        machine_status[op_name] = True
        ttf = random.expovariate(1.0 / mean_time_to_fail)
        yield env.timeout(ttf)

        # Machine goes down (seize full capacity)
        requests = []
        for _ in range(capacity):
            r = resource.request(priority=-999)
            yield r
            requests.append(r)

        machine_status[op_name] = False
        print(f"*** [{env.now:.2f}] {op_name} is DOWN ***")

        # Repair
        ttr = random.expovariate(1.0 / mean_time_to_repair)
        yield env.timeout(ttr)

        # Machine is back up
        for r in requests:
            resource.release(r)
        print(f"*** [{env.now:.2f}] {op_name} is UP ***")

def station_process(env, op_name, resource, forklift, results):
    """
    Core logic for each station:
     1) Continuously pull items from received_wip[op_name].
     2) If machine_status[op_name] is up, process items one-by-one (up to capacity).
     3) Each item processed increments finished_wip[op_name].
     4) Once finished_wip[op_name] >= 42, request forklift, do ONE transport
        to next_station (if any), subtract 42 from finished_wip, add 42 to next_station's received_wip.
    """
    data = process_data[op_name]
    capacity = data['capacity']
    cycle_time = data['cycle_time']

    while True:
        # 1) If station is down, wait a bit
        if not machine_status[op_name]:
            yield env.timeout(0.5)
            continue

        # 2) If no items in received_wip, wait
        if received_wip[op_name] <= 0:
            yield env.timeout(0.5)
            continue

        # 3) Station can process one item if resource capacity is free
        with resource.request(priority=0) as req:
            yield req  # wait until we get the machine
            # "consume" 1 item from the input buffer
            received_wip[op_name] -= 1

            start_op = env.now
            yield env.timeout(cycle_time)  # processing time
            finish_op = env.now
            print(f"[{finish_op:.2f}] One item processed at {op_name}, duration={finish_op-start_op:.2f}")

            # 4) Add to finished WIP
            finished_wip[op_name] += 1

        # 5) Check if we can do a forklift batch transport
        nxt = next_station[op_name]
        if nxt is not None:  # if there's a next station
            if finished_wip[op_name] >= BATCH_SIZE:
                # We have 42 items to transport
                # Seize forklift resource
                with forklift.request() as fk_req:
                    yield fk_req
                    # transport time
                    t_time = transport_times.get((op_name, nxt), 0.0)
                    print(f"[{env.now:.2f}] Transporting 42 from {op_name} -> {nxt}, time={t_time}")
                    yield env.timeout(t_time)

                # Now the next station has 42 more items
                finished_wip[op_name] -= BATCH_SIZE
                received_wip[nxt] += BATCH_SIZE
                print(f"[{env.now:.2f}] {nxt} received 42 from {op_name}, WIP={received_wip[nxt]}")

        else:
            # This is the last station (no next station)
            # If you want to track final "finished" items, do so here
            pass

        # End loop => station tries to process next item

def run_simulation():
    random.seed(42)
    env = simpy.Environment()

    # 1) Create resources
    resources = {}
    for op_name, data in process_data.items():
        cap = data['capacity']
        resources[op_name] = simpy.PriorityResource(env, capacity=cap)
        machine_status[op_name] = True  # start up

    # 2) Forklift (capacity=5 => only one forklift in the plant)
    forklift = simpy.Resource(env, capacity=5)

    # 3) Start downtime for each station
    for op_name, data in process_data.items():
        env.process(downtime_process(env, op_name, resources[op_name], data, machine_status))

    # 4) Start a station_process for each station
    #    We'll store final stats in 'results' if needed
    results = []
    for op_name in process_data.keys():
        env.process(station_process(env, op_name, resources[op_name], forklift, results))

    # 5) Seed lines A & B with some initial WIP (or infinite yard)
    #    e.g., feed 100 items to OP10A, 100 to OP10B
    #    Or continuously feed them if you want. For illustration:
    received_wip['OP10A'] = 100
    received_wip['OP10B'] = 100

    # 6) Run
    SIM_TIME = 1150
    env.run(until=SIM_TIME)

    print("\nSimulation complete.\n")

    # 'results' might be empty if we didn't store item-level stats
    return results

if __name__ == '__main__':
    run_simulation()
# Out:
# Simulation complete.

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-100f62972f2f> in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
import simpy
import random
import pandas as pd
from collections import defaultdict

# -------------------------------------------------------------------------
# User-Supplied Dictionaries (you said you have these defined somewhere else)
# -------------------------------------------------------------------------
process_data = {
    # e.g. 'OP10A': {'capacity':2, 'cycle_time':11.38, 'OEE':0.8313},
    # ...
}
transport_times = {
    # e.g. ('OP10A','OP20A'): 1.0488,
    # ...
}
# e.g. line A: OP10A->OP20A->OP30A->OP40->OP50->OP60->OP65->OP66
# e.g. line B: OP10B->OP20B->OP30B->OP40->OP50->OP60->OP65->OP66
next_station = {
    'OP10A': 'OP20A',
    'OP20A': 'OP30A',
    'OP30A': 'OP40',
    'OP10B': 'OP20B',
    'OP20B': 'OP30B',
    'OP30B': 'OP40',
    'OP40':  'OP50',
    'OP50':  'OP60',
    'OP60':  'OP65',
    'OP65':  'OP66',
    'OP66':  None  # final
}

BATCH_SIZE = 42
SIM_TIME   = 90000

# -------------------------------------------------------------------------
# 1) Data Structures for Tracking Items, WIP, and Results
# -------------------------------------------------------------------------
machine_status = {}  # same as before
arrival_time   = {}  # arrival_time[item_id] = time the item was created
results        = []  # each row: {ItemID, ArrivalTime, DepartureTime, TIS}
wip_history    = []  # logs changes in station WIP over time

# For each station, we store two queues:
# - received_queue[op_name]: item IDs waiting to be processed
# - finished_queue[op_name]: item IDs processed but not yet transported
received_queue = defaultdict(list)
finished_queue = defaultdict(list)

# -------------------------------------------------------------------------
# 2) Helper Function to Log WIP Changes
# -------------------------------------------------------------------------
def log_wip(now, station):
    """Record the current received & finished WIP for station at time=now."""
    r_count = len(received_queue[station])
    f_count = len(finished_queue[station])
    wip_history.append({
        'time': now,
        'station': station,
        'received_wip': r_count,
        'finished_wip': f_count
    })

# -------------------------------------------------------------------------
# 3) Downtime Process (Same as Before)
# -------------------------------------------------------------------------
def downtime_process(env, op_name, resource, data):
    capacity = data['capacity']
    oee = data['OEE']

    mean_time_to_fail = 50.0
    mean_time_to_repair = mean_time_to_fail * (1 - oee) / oee

    while True:
        # Machine is up
        machine_status[op_name] = True
        ttf = random.expovariate(1.0 / mean_time_to_fail)
        yield env.timeout(ttf)

        # Machine goes DOWN
        requests = []
        for _ in range(capacity):
            r = resource.request(priority=-999)
            yield r
            requests.append(r)

        machine_status[op_name] = False
        print(f"*** [{env.now:.2f}] {op_name} is DOWN ***")

        ttr = random.expovariate(1.0 / mean_time_to_repair)
        yield env.timeout(ttr)

        for r in requests:
            resource.release(r)
        print(f"*** [{env.now:.2f}] {op_name} is UP ***")

# -------------------------------------------------------------------------
# 4) Station Process
# -------------------------------------------------------------------------
def station_process(env, op_name, resource, forklift):
    """
    Continuously:
      - If machine_status[op_name] == False, station is down.
      - If there's an item in received_queue[op_name], process it
        (respecting capacity).
      - After processing, item goes to finished_queue[op_name].
      - If finished_queue[op_name] >= BATCH_SIZE, forklift does a single
        transport event to next station.
      - If next_station is None, item is "done" => record departure time.
    """
    data = process_data[op_name]
    cycle_time = data['cycle_time']

    while True:
        # If station is down or no items to process, wait briefly
        if not machine_status[op_name] or len(received_queue[op_name]) == 0:
            yield env.timeout(0.2)
            continue

        # Seize resource to process 1 item
        with resource.request(priority=0) as req:
            yield req  # wait for station capacity

            # Pop an item from received_queue
            item_id = received_queue[op_name].pop(0)
            log_wip(env.now, op_name)  # we changed the queue, log WIP

            start_t = env.now
            yield env.timeout(cycle_time)
            finish_t = env.now
            print(f"[{finish_t:.2f}] Item {item_id} processed at {op_name}, duration={finish_t-start_t:.2f}")

            # Add item to finished_queue
            finished_queue[op_name].append(item_id)
            log_wip(env.now, op_name)  # log WIP again

        # Check if we can do forklift transport
        nxt = next_station[op_name]
        if nxt is not None:
            if len(finished_queue[op_name]) >= BATCH_SIZE:
                # Transport exactly 42 items
                with forklift.request() as fk_req:
                    yield fk_req
                    t_time = transport_times.get((op_name, nxt), 0.0)
                    print(f"[{env.now:.2f}] Transporting {BATCH_SIZE} items from {op_name} -> {nxt}, time={t_time}")
                    yield env.timeout(t_time)

                # Move exactly 42 items from finished-> next station's received
                batch_to_move = finished_queue[op_name][:BATCH_SIZE]
                del finished_queue[op_name][:BATCH_SIZE]
                log_wip(env.now, op_name)  # updated finished WIP

                # If next station is not final, add them to next station's queue
                for item_id in batch_to_move:
                    received_queue[nxt].append(item_id)
                    log_wip(env.now, nxt)

        else:
            # No next station => final station. This item is completed.
            # So we remove it from finished_queue (which we did).
            # Let's finalize item => record departure time in results
            # But we handle that in forklift logic if there's a batch approach
            pass

# -------------------------------------------------------------------------
# 5) Utility Process: Generate Items in the Yard
# -------------------------------------------------------------------------
def yard_generator(env, line_op_name, item_counter):
    """
    Continuously creates new items with a unique ID, logs arrival_time,
    and appends them to 'received_queue[line_op_name]' for OP10A or OP10B.

    'item_counter' is a mutable list with one element that we can increment
    to get unique IDs.
    """
    while True:
        # Create a new item
        item_counter[0] += 1
        new_id = item_counter[0]
        arrival_time[new_id] = env.now
        received_queue[line_op_name].append(new_id)
        log_wip(env.now, line_op_name)  # new item in queue

        # Suppose we introduce an item every 1 time unit (or some rate)
        # Or just do 0 if we want them all instantly
        yield env.timeout(1.0)

# -------------------------------------------------------------------------
# 6) Main Simulation
# -------------------------------------------------------------------------
def run_simulation():
    random.seed(42)
    env = simpy.Environment()

    # 6.1) Create resources for stations
    resources = {}
    for op_name, data in process_data.items():
        capacity = data['capacity']
        resources[op_name] = simpy.PriorityResource(env, capacity=capacity)
        machine_status[op_name] = True

    # 6.2) Forklift resource (capacity=1 => single forklift)
    forklift = simpy.Resource(env, capacity=10)

    # 6.3) Start downtime processes
    for op_name, data in process_data.items():
        env.process(downtime_process(env, op_name, resources[op_name], data))

    # 6.4) Start station processes
    for op_name in process_data.keys():
        env.process(station_process(env, op_name, resources[op_name], forklift))

    # 6.5) Start yard generators for lineA -> OP10A and lineB -> OP10B
    # Here we assume an infinite yard feeding OP10A, OP10B
    item_counter = [0]  # single-element list as mutable counter
    env.process(yard_generator(env, 'OP10A', item_counter))
    env.process(yard_generator(env, 'OP10B', item_counter))

    # 6.6) Run simulation
    env.run(until=SIM_TIME)
    print("\nSimulation complete.\n")

    # 6.7) Build the item-level results DataFrame
    # Items only truly "finish" if they reach OP66's finished_queue or the last station
    # We'll check 'finished_queue' of the last station for final items.
    # Then TIS = env.now - arrival_time[that_item].
    # Alternatively, we can track departure individually when forklift moves them out,
    # but let's do a final pass:
    final_op = 'OP66'
    for item_id in finished_queue[final_op]:
        dep_time = SIM_TIME  # we ended the simulation with these items
        arr_time = arrival_time[item_id]
        TIS = dep_time - arr_time
        results.append({
            'ItemID': item_id,
            'ArrivalTime': arr_time,
            'DepartureTime': dep_time,
            'TimeInSystem': TIS
        })

    # If you want partial "exited" logs from earlier stations if they have no next station, 
    # you'd do a similar pass for each station whose next_station is None.

    # 6.8) Convert 'results' to a DataFrame
    df_results = pd.DataFrame(results)

    # 6.9) Convert 'wip_history' to another DataFrame
    df_wip = pd.DataFrame(wip_history)

    return df_results, df_wip

# -------------------------------------------------------------------------
# 7) Run
# -------------------------------------------------------------------------
if __name__ == '__main__':
    df_results, df_wip = run_simulation()
    print("\n--- Results DataFrame ---")
    print(df_results.head(20))
    print("\n--- WIP DataFrame ---")
    print(df_wip.head(20))

# %%
import simpy
import random
import pandas as pd
from collections import defaultdict

###############################################################################
# 1) Define User-Supplied Dictionaries & Constants
###############################################################################

process_data = {
    'OP10A': {'capacity': 2, 'cycle_time': 11.38, 'OEE': 0.8313},
    'OP20A': {'capacity': 2, 'cycle_time':  3.78, 'OEE': 0.4259},
    'OP30A': {'capacity': 1, 'cycle_time':  6.32, 'OEE': 0.4259},
    
    'OP10B': {'capacity': 2, 'cycle_time':  6.55, 'OEE': 0.8313},
    'OP20B': {'capacity': 1, 'cycle_time':  3.78, 'OEE': 0.4259},
    'OP30B': {'capacity': 1, 'cycle_time':  3.67, 'OEE': 0.4259},

    'OP40':  {'capacity': 3, 'cycle_time':  8.21, 'OEE': 0.8050},
    'OP50':  {'capacity': 2, 'cycle_time':  2.46, 'OEE': 0.8330},
    'OP60':  {'capacity': 5, 'cycle_time': 11.33, 'OEE': 0.4242},
    'OP65':  {'capacity': 3, 'cycle_time': 10.63, 'OEE': 0.7251},
    'OP66':  {'capacity': 3, 'cycle_time': 10.28, 'OEE': 0.8000},
}

next_station = {
    'OP10A': 'OP20A',
    'OP20A': 'OP30A',
    'OP30A': 'OP40',
    'OP10B': 'OP20B',
    'OP20B': 'OP30B',
    'OP30B': 'OP40',
    'OP40':  'OP50',
    'OP50':  'OP60',
    'OP60':  'OP65',
    'OP65':  'OP66',
    'OP66':  None,
}

transport_times = {
    ('OP10A','OP20A'): 1.0488,
    ('OP10B','OP20B'): 1.0813,
    ('OP20A','OP30A'): 3.0,
    ('OP20B','OP30B'): 3.0,
    ('OP30A','OP40'):  1.2114,
    ('OP30B','OP40'):  1.2114,
    ('OP40','OP50'):   1.1301,
    ('OP50','OP60'):   1.8130,
    ('OP60','OP65'):   1.0488,
    ('OP65','OP66'):   1.1301,
}

BATCH_SIZE = 5
SIM_TIME   = 6300

###############################################################################
# 2) Data Structures for Tracking
###############################################################################
machine_status = {}
arrival_time   = {}
results        = []
wip_history    = []

from collections import defaultdict
received_queue = defaultdict(list)
finished_queue = defaultdict(list)

###############################################################################
# 3) Logging WIP Changes
###############################################################################
def log_wip(now, station):
    r_count = len(received_queue[station])
    f_count = len(finished_queue[station])
    wip_history.append({
        'time': now,
        'station': station,
        'received_wip': r_count,
        'finished_wip': f_count
    })

###############################################################################
# 4) Downtime Process
###############################################################################
def downtime_process(env, op_name, resource, data):
    capacity = data['capacity']
    oee = data['OEE']

    mean_time_to_fail = 50.0
    mean_time_to_repair = mean_time_to_fail * (1 - oee) / oee

    while True:
        machine_status[op_name] = True
        ttf = random.expovariate(1.0 / mean_time_to_fail)
        yield env.timeout(ttf)

        # Station goes DOWN
        requests = []
        for _ in range(capacity):
            r = resource.request(priority=-999)
            yield r
            requests.append(r)

        machine_status[op_name] = False
        print(f"*** [{env.now:.2f}] {op_name} is DOWN ***")

        ttr = random.expovariate(1.0 / mean_time_to_repair)
        yield env.timeout(ttr)

        for r in requests:
            resource.release(r)
        print(f"*** [{env.now:.2f}] {op_name} is UP ***")

###############################################################################
# 5) Station Process
###############################################################################
def station_process(env, op_name, resource, forklift):
    cycle_time = process_data[op_name]['cycle_time']

    while True:
        if (not machine_status[op_name]) or (len(received_queue[op_name]) == 0):
            yield env.timeout(0.2)
            continue

        with resource.request(priority=0) as req:
            yield req

            # Process one item
            item_id = received_queue[op_name].pop(0)
            log_wip(env.now, op_name)

            start_op = env.now
            yield env.timeout(cycle_time)
            finish_op = env.now

            print(f"[{finish_op:.2f}] {item_id} processed at {op_name}, dur={finish_op - start_op:.2f}")
            finished_queue[op_name].append(item_id)
            log_wip(env.now, op_name)

        nxt = next_station[op_name]
        if nxt is not None:
            if len(finished_queue[op_name]) >= BATCH_SIZE:
                with forklift.request() as fk_req:
                    yield fk_req
                    t_time = transport_times.get((op_name, nxt), 0.0)
                    print(f"[{env.now:.2f}] Transporting {BATCH_SIZE} from {op_name} -> {nxt}, t={t_time}")
                    yield env.timeout(t_time)

                batch_to_move = finished_queue[op_name][:BATCH_SIZE]
                del finished_queue[op_name][:BATCH_SIZE]
                log_wip(env.now, op_name)

                for x in batch_to_move:
                    received_queue[nxt].append(x)
                    log_wip(env.now, nxt)

        else:
            # Last station => item is fully done here
            # We'll handle final results logging at the end
            pass
        
###############################################################################
# Pull-based Yard Generator for Line A
###############################################################################
def wait_for_line_A_conditions(env, resources, machine_status):
    """
    Yield until:
      - OP30A is up (machine_status['OP30A'] == True),
      - WIP before OP20A < 50,
      - (Optional) OP10A is physically idle if you want that condition too.
    This function returns as soon as the conditions are met.
    """
    while True:
        # 1) Check if OP30A is up
        if not machine_status['OP30A']:
            yield env.timeout(1.0)
            continue

        # 2) Check WIP in front of OP20A
        wip_op20A = resources['OP20A'].count + len(received_queue['OP20A'])
        if wip_op20A >= 100:
            yield env.timeout(1.0)
            continue

        # 3) (Optional) If you also require OP10A to be idle:
        #    Check if OP10A resource usage < capacity and queue == 0
        # op10a_resource = resources['OP10A']
        # if op10a_resource.count >= op10a_resource.capacity or len(op10a_resource.queue) > 0:
        #     yield env.timeout(0.5)
        #     continue

        # If we get here, conditions are satisfied
        return

def line_A_generator(env, resources, machine_status, process_data):
    """
    Continuously pulls a new part from the yard for Line A only if:
      - OP30A is up,
      - WIP before OP20A < 50,
      - (Optionally) OP10A is idle if you want that logic.
    Then it seizes OP10A's cycle time or does a short arrival logic,
    and ultimately appends the part to OP10A's received_queue.
    """
    item_counter = 0
    op10a_res = resources['OP10A']
    cycle_time_10A = process_data['OP10A']['cycle_time']

    while True:
        # 1) Wait until conditions are satisfied
        yield env.process(wait_for_line_A_conditions(env, resources, machine_status))

        # 2) Optionally model OP10A's cycle time as the "interarrival" time
        #    to represent that OP10A can't pull from the yard if it's not done
        with op10a_res.request(priority=0) as req:
            yield req
            # Wait the cycle_time if you want a "production" delay
            yield env.timeout(cycle_time_10A)

        # 3) Create a new item from the yard
        item_counter += 1
        new_item_id = f"LineA-YardItem-{item_counter}"
        arrival_time[new_item_id] = env.now

        # 4) Put it into OP10A's received queue
        received_queue['OP10A'].append(new_item_id)
        log_wip(env.now, 'OP10A')
        print(f"[{env.now:.2f}] Created {new_item_id} for OP10A (pull-based).")


###############################################################################
# Pull-based Yard Generator for Line B
###############################################################################
def wait_for_line_B_conditions(env, resources, machine_status):
    """
    Yield until:
      - OP30B is up,
      - WIP before OP20B < 50,
      - (Optionally) OP10B is idle if you want that logic too.
    """
    while True:
        if not machine_status['OP30B']:
            yield env.timeout(1.0)
            continue

        wip_op20B = resources['OP20B'].count + len(received_queue['OP20B'])
        if wip_op20B >= 100:
            yield env.timeout(1.0)
            continue

        # (Optional) Check OP10B resource usage or queue
        # ...

        return

def line_B_generator(env, resources, machine_status, process_data):
    item_counter = 0
    op10b_res = resources['OP10B']
    cycle_time_10B = process_data['OP10B']['cycle_time']

    while True:
        yield env.process(wait_for_line_B_conditions(env, resources, machine_status))

        with op10b_res.request(priority=0) as req:
            yield req
            yield env.timeout(cycle_time_10B)

        item_counter += 1
        new_item_id = f"LineB-YardItem-{item_counter}"
        arrival_time[new_item_id] = env.now

        received_queue['OP10B'].append(new_item_id)
        log_wip(env.now, 'OP10B')
        print(f"[{env.now:.2f}] Created {new_item_id} for OP10B (pull-based).")


###############################################################################
# 7) Main Simulation
###############################################################################
def run_simulation():
    random.seed(42)
    env = simpy.Environment()

    # Create station resources
    resources = {}
    for op_name, data in process_data.items():
        resources[op_name] = simpy.PriorityResource(env, capacity=data['capacity'])
        machine_status[op_name] = True

    # Forklift
    forklift = simpy.Resource(env, capacity=10)

    # Start downtime processes
    for op_name, data in process_data.items():
        env.process(downtime_process(env, op_name, resources[op_name], data))

    # Start station processes
    for op_name in process_data.keys():
        env.process(station_process(env, op_name, resources[op_name], forklift))

    # 7.1) Initialize each station with 42 items
    for op_name in process_data.keys():
        for i in range(5):
            init_item = f"Init-{op_name}-{i}"
            arrival_time[init_item] = 0  # they existed at time=0
            received_queue[op_name].append(init_item)
        log_wip(0, op_name)

    # 7.2) Yard generator for OP10A, OP10B => controlling the interarrival
    env.process(line_A_generator(env, resources, machine_status, process_data))
    env.process(line_B_generator(env, resources, machine_status, process_data))

    # Run simulation
    env.run(until=SIM_TIME)
    print("\nSimulation complete.\n")

    # Build final results:
    # We'll check the last station(s) => OP66 => anything that ended up "finished" there
    final_op = 'OP66'
    for item_id in finished_queue[final_op]:
        dep_time = SIM_TIME
        arr_time = arrival_time[item_id]
        TIS = dep_time - arr_time
        results.append({
            'ItemID': item_id,
            'ArrivalTime': arr_time,
            'DepartureTime': dep_time,
            'TimeInSystem': TIS
        })

    # Convert to DataFrames
    df_results = pd.DataFrame(results)
    df_wip = pd.DataFrame(wip_history)

    # Return two dataframes: (1) TIS results, (2) WIP evolution
    return df_results, df_wip

# -------------------------------------------------------------------------
# 8) Execute
# -------------------------------------------------------------------------
if __name__ == '__main__':
    df_results, df_wip = run_simulation()

    print("\n--- RESULTS DataFrame (TIS) ---")
    print(df_results.head(20))

    print("\n--- WIP DataFrame ---")
    print(df_wip.head(20))
# Out:
# [2.46] Init-OP50-0 processed at OP50, dur=2.46
# [3.67] Init-OP30B-0 processed at OP30B, dur=3.67
# [3.78] Init-OP20A-0 processed at OP20A, dur=3.78
# [3.78] Init-OP20B-0 processed at OP20B, dur=3.78
# *** [3.78] OP20A is DOWN ***
# [4.92] Init-OP50-1 processed at OP50, dur=2.46
# *** [4.92] OP50 is DOWN ***
# *** [5.19] OP50 is UP ***
# [6.32] Init-OP30A-0 processed at OP30A, dur=6.32
# [6.55] Init-OP10B-0 processed at OP10B, dur=6.55
# [6.55] Created LineB-YardItem-1 for OP10B (pull-based).
# [7.34] Init-OP30B-1 processed at OP30B, dur=3.67
# *** [6287.60] OP66 is UP ***
# [6288.24] LineA-YardItem-221 processed at OP20A, dur=3.78
# [6290.48] LineB-YardItem-118 processed at OP65, dur=10.63
# *** [6290.48] OP65 is DOWN ***
# [6290.82] LineA-YardItem-216 processed at OP30A, dur=6.32
# [6291.64] Created LineA-YardItem-229 for OP10A (pull-based).
# [6291.70] LineA-YardItem-228 processed at OP10A, dur=11.38
# [6292.02] LineA-YardItem-222 processed at OP20A, dur=3.78
# [6295.04] LineA-YardItem-205 processed at OP40, dur=8.21
# [6295.04] Transporting 5 from OP40 -> OP50, t=1.1301
# [6295.80] LineA-YardItem-223 processed at OP20A, dur=3.78
# [6297.14] LineA-YardItem-217 processed at OP30A, dur=6.32
# [6297.88] LineA-YardItem-84 processed at OP66, dur=10.28
# [6298.83] LineA-YardItem-201 processed at OP50, dur=2.46
# [6299.58] LineA-YardItem-224 processed at OP20A, dur=3.78
# *** [6299.58] OP20A is DOWN ***
#
# Simulation complete.
#
#
# --- RESULTS DataFrame (TIS) ---
#          ItemID  ArrivalTime  DepartureTime  TimeInSystem
# 0   Init-OP66-0          0.0           6300        6300.0
# 1   Init-OP66-1          0.0           6300        6300.0
# 2   Init-OP66-2          0.0           6300        6300.0
# 3   Init-OP66-3          0.0           6300        6300.0
# 4   Init-OP66-4          0.0           6300        6300.0
# 5   Init-OP65-0          0.0           6300        6300.0
# 6   Init-OP65-1          0.0           6300        6300.0
# 7   Init-OP65-2          0.0           6300        6300.0
# 8   Init-OP65-3          0.0           6300        6300.0
# 9   Init-OP65-4          0.0           6300        6300.0
# 10  Init-OP60-0          0.0           6300        6300.0
# 11  Init-OP60-1          0.0           6300        6300.0
# 12  Init-OP60-2          0.0           6300        6300.0
# 13  Init-OP60-3          0.0           6300        6300.0
# 14  Init-OP60-4          0.0           6300        6300.0
# 15  Init-OP50-0          0.0           6300        6300.0
# 16  Init-OP50-1          0.0           6300        6300.0
# 17  Init-OP50-2          0.0           6300        6300.0
# 18  Init-OP50-3          0.0           6300        6300.0
# 19  Init-OP50-4          0.0           6300        6300.0
#
# --- WIP DataFrame ---
#     time station  received_wip  finished_wip
# 0    0.0   OP10A             5             0
# 1    0.0   OP20A             5             0
# 2    0.0   OP30A             5             0
# 3    0.0   OP10B             5             0
# 4    0.0   OP20B             5             0
# 5    0.0   OP30B             5             0
# 6    0.0    OP40             5             0
# 7    0.0    OP50             5             0
# 8    0.0    OP60             5             0
# 9    0.0    OP65             5             0
# 10   0.0    OP66             5             0
# 11   0.0   OP10A             4             0
# 12   0.0   OP20A             4             0
# 13   0.0   OP30A             4             0
# 14   0.0   OP10B             4             0
# 15   0.0   OP20B             4             0
# 16   0.0   OP30B             4             0
# 17   0.0    OP40             4             0
# 18   0.0    OP50             4             0
# 19   0.0    OP60             4             0

# %%
import simpy
import random
import pandas as pd
from collections import defaultdict

###############################################################################
# 1) Define User-Supplied Dictionaries & Constants
###############################################################################

process_data = {
    'OP10A': {'capacity': 2, 'cycle_time': 11.38, 'OEE': 0.8313},
    'OP20A': {'capacity': 2, 'cycle_time':  3.78, 'OEE': 0.4259},
    'OP30A': {'capacity': 1, 'cycle_time':  6.32, 'OEE': 0.4259},
    
    'OP10B': {'capacity': 2, 'cycle_time':  6.55, 'OEE': 0.8313},
    'OP20B': {'capacity': 1, 'cycle_time':  3.78, 'OEE': 0.4259},
    'OP30B': {'capacity': 1, 'cycle_time':  3.67, 'OEE': 0.4259},
    
    'OP40':  {'capacity': 3, 'cycle_time':  8.21, 'OEE': 0.8050},
    'OP50':  {'capacity': 2, 'cycle_time':  2.46, 'OEE': 0.8330},
    'OP60':  {'capacity': 5, 'cycle_time': 11.33, 'OEE': 0.4242},
    'OP65':  {'capacity': 3, 'cycle_time': 10.63, 'OEE': 0.7251},
    'OP66':  {'capacity': 3, 'cycle_time': 10.28, 'OEE': 0.8000},
}

next_station = {
    'OP10A': 'OP20A',
    'OP20A': 'OP30A',
    'OP30A': 'OP40',
    'OP10B': 'OP20B',
    'OP20B': 'OP30B',
    'OP30B': 'OP40',
    'OP40':  'OP50',
    'OP50':  'OP60',
    'OP60':  'OP65',
    'OP65':  'OP66',
    'OP66':  None,
}

transport_times = {
    ('OP10A','OP20A'): 1.0488,
    ('OP10B','OP20B'): 1.0813,
    ('OP20A','OP30A'): 3.0,
    ('OP20B','OP30B'): 3.0,
    ('OP30A','OP40'):  1.2114,
    ('OP30B','OP40'):  1.2114,
    ('OP40','OP50'):   1.1301,
    ('OP50','OP60'):   1.8130,
    ('OP60','OP65'):   1.0488,
    ('OP65','OP66'):   1.1301,
}

BATCH_SIZE = 5
SIM_TIME   = 6300

###############################################################################
# 2) Data Structures for Tracking
###############################################################################
machine_status = {}    # machine_status[op_name] = True/False (up/down)
arrival_time   = {}    # arrival_time[item_id] = when the item was created
results        = []    # each row: {ItemID, ArrivalTime, DepartureTime, TimeInSystem}
wip_history    = []    # each log: {time, station, received_wip, finished_wip}

# Each station has a "received" queue and a "finished" queue
received_queue = defaultdict(list)
finished_queue = defaultdict(list)

###############################################################################
# 3) Logging WIP Changes
###############################################################################
def log_wip(now, station):
    r_count = len(received_queue[station])
    f_count = len(finished_queue[station])
    wip_history.append({
        'time': now,
        'station': station,
        'received_wip': r_count,
        'finished_wip': f_count
    })

###############################################################################
# 4) Downtime Process (unchanged from before)
###############################################################################
def downtime_process(env, op_name, resource, data):
    capacity = data['capacity']
    oee = data['OEE']
    mean_time_to_fail = 50.0
    mean_time_to_repair = mean_time_to_fail * (1 - oee) / oee

    while True:
        machine_status[op_name] = True
        ttf = random.expovariate(1.0 / mean_time_to_fail)
        yield env.timeout(ttf)

        requests = []
        for _ in range(capacity):
            r = resource.request(priority=-999)
            yield r
            requests.append(r)
        machine_status[op_name] = False
        print(f"*** [{env.now:.2f}] {op_name} is DOWN ***")

        ttr = random.expovariate(1.0 / mean_time_to_repair)
        yield env.timeout(ttr)

        for r in requests:
            resource.release(r)
        print(f"*** [{env.now:.2f}] {op_name} is UP ***")

###############################################################################
# 5) Station Process: Processes items one by one, does batch forklift transport
###############################################################################
def station_process(env, op_name, resource, forklift):
    cycle_time = process_data[op_name]['cycle_time']

    while True:
        if (not machine_status[op_name]) or (len(received_queue[op_name]) == 0):
            yield env.timeout(0.2)
            continue

        with resource.request(priority=0) as req:
            yield req
            item_id = received_queue[op_name].pop(0)
            log_wip(env.now, op_name)
            start_op = env.now
            yield env.timeout(cycle_time)
            finish_op = env.now
            print(f"[{finish_op:.2f}] {item_id} processed at {op_name}, dur={finish_op - start_op:.2f}")
            finished_queue[op_name].append(item_id)
            log_wip(env.now, op_name)

        nxt = next_station[op_name]
        if nxt is not None:
            if len(finished_queue[op_name]) >= BATCH_SIZE:
                with forklift.request() as fk_req:
                    yield fk_req
                    t_time = transport_times.get((op_name, nxt), 0.0)
                    print(f"[{env.now:.2f}] Transporting {BATCH_SIZE} from {op_name} -> {nxt}, t={t_time}")
                    yield env.timeout(t_time)
                batch = finished_queue[op_name][:BATCH_SIZE]
                del finished_queue[op_name][:BATCH_SIZE]
                log_wip(env.now, op_name)
                for x in batch:
                    received_queue[nxt].append(x)
                    log_wip(env.now, nxt)
        else:
            # Last station: item is complete.
            # For item-level tracking, we handle final logging outside.
            pass

###############################################################################
# 6) Pull-based Yard Generators (for interarrival and pull conditions)
###############################################################################
def wait_for_line_A_conditions(env, resources, machine_status):
    while True:
        if not machine_status['OP30A']:
            yield env.timeout(1.0)
            continue
        # Use a relaxed threshold of 100 (as desired)
        wip_op20A = resources['OP20A'].count + len(received_queue['OP20A'])
        if wip_op20A >= 100:
            yield env.timeout(1.0)
            continue
        return

def line_A_generator(env, resources, machine_status, process_data):
    item_counter = 0
    op10a_res = resources['OP10A']
    cycle_time_10A = process_data['OP10A']['cycle_time']

    while True:
        yield env.process(wait_for_line_A_conditions(env, resources, machine_status))
        with op10a_res.request(priority=0) as req:
            yield req
            yield env.timeout(cycle_time_10A)
        item_counter += 1
        new_item_id = f"LineA-YardItem-{item_counter}"
        arrival_time[new_item_id] = env.now
        received_queue['OP10A'].append(new_item_id)
        log_wip(env.now, 'OP10A')
        print(f"[{env.now:.2f}] Created {new_item_id} for OP10A (pull-based).")

def wait_for_line_B_conditions(env, resources, machine_status):
    while True:
        if not machine_status['OP30B']:
            yield env.timeout(1.0)
            continue
        wip_op20B = resources['OP20B'].count + len(received_queue['OP20B'])
        if wip_op20B >= 100:
            yield env.timeout(1.0)
            continue
        return

def line_B_generator(env, resources, machine_status, process_data):
    item_counter = 0
    op10b_res = resources['OP10B']
    cycle_time_10B = process_data['OP10B']['cycle_time']

    while True:
        yield env.process(wait_for_line_B_conditions(env, resources, machine_status))
        with op10b_res.request(priority=0) as req:
            yield req
            yield env.timeout(cycle_time_10B)
        item_counter += 1
        new_item_id = f"LineB-YardItem-{item_counter}"
        arrival_time[new_item_id] = env.now
        received_queue['OP10B'].append(new_item_id)
        log_wip(env.now, 'OP10B')
        print(f"[{env.now:.2f}] Created {new_item_id} for OP10B (pull-based).")

###############################################################################
# 7) Yard Generator (optional alternative if you want continuous arrivals)
#     (In this model, we use the pull generators to bring items into OP10A and OP10B)
###############################################################################
# def yard_generator(env, station_name, interarrival_time):
#     item_counter = 0
#     while True:
#         item_counter += 1
#         new_item_id = f"YardItem-{station_name}-{item_counter}"
#         arrival_time[new_item_id] = env.now
#         received_queue[station_name].append(new_item_id)
#         log_wip(env.now, station_name)
#         yield env.timeout(interarrival_time)

###############################################################################
# 8) Main Simulation
###############################################################################
def run_simulation():
    random.seed(42)
    env = simpy.Environment()

    # Create station resources and set machine status to True
    resources = {}
    for op_name, data in process_data.items():
        resources[op_name] = simpy.PriorityResource(env, capacity=data['capacity'])
        machine_status[op_name] = True

    forklift = simpy.Resource(env, capacity=1)

    # Start downtime processes for each station
    for op_name, data in process_data.items():
        env.process(downtime_process(env, op_name, resources[op_name], data))

    # Start station processes (each station processes items from its received queue)
    for op_name in process_data.keys():
        env.process(station_process(env, op_name, resources[op_name], forklift))

    # 8.1) Initialize only the starting stations (OP10A and OP10B) with a full pallet (42 items)
    for station in ['OP10A', 'OP10B']:
        for i in range(5):
            init_item = f"Init-{station}-{i}"
            arrival_time[init_item] = 0
            received_queue[station].append(init_item)
        log_wip(0, station)

    # 8.2) Start pull-based yard generators for OP10A and OP10B
    env.process(line_A_generator(env, resources, machine_status, process_data))
    env.process(line_B_generator(env, resources, machine_status, process_data))

    # Run simulation for the given time
    env.run(until=SIM_TIME)
    print("\nSimulation complete.\n")

    # Build final results:
    # We assume that the final station is OP66; gather all items left in finished_queue[OP66]
    final_op = 'OP66'
    for item_id in finished_queue[final_op]:
        dep_time = SIM_TIME
        arr_time = arrival_time[item_id]
        TIS = dep_time - arr_time
        results.append({
            'ItemID': item_id,
            'ArrivalTime': arr_time,
            'DepartureTime': dep_time,
            'TimeInSystem': TIS
        })

    df_results = pd.DataFrame(results)
    df_wip = pd.DataFrame(wip_history)

    return df_results, df_wip

###############################################################################
# 9) Execute Simulation and Output DataFrames
###############################################################################
if __name__ == '__main__':
    df_results, df_wip = run_simulation()
    print("\n--- RESULTS DataFrame (TIS) ---")
    print(df_results.head(20))
    print("\n--- WIP DataFrame ---")
    print(df_wip.head(20))
# Out:
# *** [1.27] OP20A is DOWN ***
# *** [1.51] OP65 is DOWN ***
# *** [2.02] OP65 is UP ***
# *** [4.55] OP50 is DOWN ***
# [6.55] Init-OP10B-0 processed at OP10B, dur=6.55
# [6.55] Created LineB-YardItem-1 for OP10B (pull-based).
# [11.38] Init-OP10A-0 processed at OP10A, dur=11.38
# [11.38] Created LineA-YardItem-1 for OP10A (pull-based).
# *** [12.34] OP66 is DOWN ***
# [13.10] Init-OP10B-1 processed at OP10B, dur=6.55
# [13.10] Created LineB-YardItem-2 for OP10B (pull-based).
# *** [13.11] OP65 is DOWN ***
# *** [15.07] OP50 is UP ***
# *** [16.08] OP30A is DOWN ***
# *** [17.83] OP65 is UP ***
# *** [18.15] OP65 is DOWN ***
# [19.65] Init-OP10B-2 processed at OP10B, dur=6.55
# *** [19.65] OP10B is DOWN ***
# *** [22.18] OP66 is UP ***
# *** [6295.36] OP40 is DOWN ***
# *** [6296.84] OP30B is UP ***
# *** [6297.30] OP10B is UP ***
#
# Simulation complete.
#
#
# --- RESULTS DataFrame (TIS) ---
#                ItemID  ArrivalTime  DepartureTime  TimeInSystem
# 0        Init-OP10A-0     0.000000           6300   6300.000000
# 1        Init-OP10A-1     0.000000           6300   6300.000000
# 2        Init-OP10A-2     0.000000           6300   6300.000000
# 3        Init-OP10A-3     0.000000           6300   6300.000000
# 4        Init-OP10A-4     0.000000           6300   6300.000000
# 5        Init-OP10B-0     0.000000           6300   6300.000000
# 6        Init-OP10B-1     0.000000           6300   6300.000000
# 7        Init-OP10B-2     0.000000           6300   6300.000000
# 8        Init-OP10B-3     0.000000           6300   6300.000000
# 9        Init-OP10B-4     0.000000           6300   6300.000000
# 10   LineB-YardItem-1     6.550000           6300   6293.450000
# 11   LineB-YardItem-2    13.100000           6300   6286.900000
# 12   LineB-YardItem-3    38.353685           6300   6261.646315
# 13   LineB-YardItem-4    44.903685           6300   6255.096315
# 14   LineB-YardItem-5    51.453685           6300   6248.546315
# 15   LineB-YardItem-6    58.003685           6300   6241.996315
# 16   LineB-YardItem-7   151.553685           6300   6148.446315
# 17   LineB-YardItem-8   158.103685           6300   6141.896315
# 18   LineB-YardItem-9   164.653685           6300   6135.346315
# 19  LineB-YardItem-10   171.203685           6300   6128.796315
#
# --- WIP DataFrame ---
#          time station  received_wip  finished_wip
# 0    0.000000   OP10A             5             0
# 1    0.000000   OP10B             5             0
# 2    0.000000   OP10A             4             0
# 3    0.000000   OP10B             4             0
# 4    6.550000   OP10B             4             1
# 5    6.550000   OP10B             5             1
# 6    6.550000   OP10B             4             1
# 7   11.380000   OP10A             4             1
# 8   11.380000   OP10A             5             1
# 9   11.380000   OP10A             4             1
# 10  13.100000   OP10B             4             2
# 11  13.100000   OP10B             5             2
# 12  13.100000   OP10B             4             2
# 13  19.650000   OP10B             4             3
# 14  22.760000   OP10A             4             2
# 15  22.760000   OP10A             5             2
# 16  22.760000   OP10A             4             2
# 17  31.803685   OP10B             3             3
# 18  34.140000   OP10A             4             3
# 19  34.140000   OP10A             3             3

# %%
import simpy
import random
import pandas as pd
from collections import defaultdict

###############################################################################
# 1) User-Supplied Data & Constants
###############################################################################

# Process data: each station’s capacity, cycle time, and OEE
process_data = {
    'OP10A': {'capacity': 2, 'cycle_time': 11.38, 'OEE': 0.8313},  # saw billet to length SAW
    'OP20A': {'capacity': 2, 'cycle_time': 3.78,  'OEE': 0.4259},  # induction heater press 1 
    'OP30A': {'capacity': 1, 'cycle_time': 6.32,  'OEE': 0.4259},  # Press 1 
    
    'OP10B': {'capacity': 2, 'cycle_time': 6.55,  'OEE': 0.8313},   # saw billet to length BC
    'OP20B': {'capacity': 1, 'cycle_time': 3.78,  'OEE': 0.4259},   # induction heater press 2 
    'OP30B': {'capacity': 1, 'cycle_time': 3.67,  'OEE': 0.4259},   # Press 2
    
    # Shared sequence
    'OP40':  {'capacity': 3, 'cycle_time': 8.21,  'OEE': 0.8050},   # saw cavity to length
    'OP50':  {'capacity': 2, 'cycle_time': 2.46,  'OEE': 0.8330},   # clean cavity 
    'OP60':  {'capacity': 5, 'cycle_time': 11.33, 'OEE': 0.4242},   # machine pre-nose external
    'OP65':  {'capacity': 3, 'cycle_time': 10.63, 'OEE': 0.7251},   # machine pre-nose internal 
    'OP66':  {'capacity': 3, 'cycle_time': 10.28, 'OEE': 0.8},      # machine base recess groove for heat treatment 
}

# Routing for batch transport: each station sends its finished goods to the next.
next_station = {
    'OP10A': 'OP20A',
    'OP20A': 'OP30A',
    'OP30A': 'OP40',
    'OP10B': 'OP20B',
    'OP20B': 'OP30B',
    'OP30B': 'OP40',
    'OP40':  'OP50',
    'OP50':  'OP60',
    'OP60':  'OP65',
    'OP65':  'OP66',
    'OP66':  None,  # final station
}

# Transport times (time for forklift to move one pallet of items from one station to the next)
transport_times = {
    ('OP10A','OP20A'): 1.0488,
    ('OP10B','OP20B'): 1.0813,
    ('OP20A','OP30A'): 3.0,
    ('OP20B','OP30B'): 3.0,
    ('OP30A','OP40'):  1.2114,
    ('OP30B','OP40'):  1.2114,
    ('OP40','OP50'):   1.1301,
    ('OP50','OP60'):   1.8130,
    ('OP60','OP65'):   1.0488,
    ('OP65','OP66'):   1.1301,
}

BATCH_SIZE = 5  # For example, each pallet holds 5 units
SIM_TIME   = 1150

###############################################################################
# 2) Global Data Structures
###############################################################################
# machine_status: whether each station's machines are "up" (True) or "down" (False)
machine_status = {}

# arrival_time: records the simulation time when an item is created
arrival_time = {}

# results: a list of dictionaries for each finished item (for the final DF)
results = []

# wip_history: a list of dictionaries recording WIP changes over time
wip_history = []

# For each station, maintain two queues:
# received_queue: items waiting to be processed at this station
# finished_queue: items that have been processed at this station, waiting for batch transport
received_queue = defaultdict(list)
finished_queue = defaultdict(list)

###############################################################################
# 3) WIP Logging Function
###############################################################################
def log_wip(now, station):
    r_count = len(received_queue[station])
    f_count = len(finished_queue[station])
    wip_history.append({
        'time': now,
        'station': station,
        'received_wip': r_count,
        'finished_wip': f_count
    })

###############################################################################
# 4) Downtime Process (unchanged from previous versions)
###############################################################################
def downtime_process(env, op_name, resource, data, machine_status):
    capacity = data['capacity']
    oee = data['OEE']
    mean_time_to_fail = 50.0
    mean_time_to_repair = mean_time_to_fail * (1 - oee) / oee

    while True:
        machine_status[op_name] = True
        ttf = random.expovariate(1.0 / mean_time_to_fail)
        yield env.timeout(ttf)

        # Machine goes DOWN: seize full capacity
        requests = []
        for _ in range(capacity):
            r = resource.request(priority=-999)
            yield r
            requests.append(r)
        machine_status[op_name] = False
        print(f"*** [{env.now:.2f}] {op_name} is DOWN ***")
        ttr = random.expovariate(1.0 / mean_time_to_repair)
        yield env.timeout(ttr)
        for r in requests:
            resource.release(r)
        print(f"*** [{env.now:.2f}] {op_name} is UP ***")

###############################################################################
# 5) Station Process
###############################################################################
def station_process(env, op_name, resource, forklift):
    cycle_time = process_data[op_name]['cycle_time']
    
    while True:
        # If station is down or no items in received queue, wait a little.
        if (not machine_status[op_name]) or (len(received_queue[op_name]) == 0):
            yield env.timeout(0.2)
            continue

        # Process one item: remove it from received queue and process for cycle time.
        with resource.request(priority=0) as req:
            yield req
            item_id = received_queue[op_name].pop(0)
            log_wip(env.now, op_name)
            start_time = env.now
            yield env.timeout(cycle_time)
            finish_time = env.now
            print(f"[{finish_time:.2f}] {item_id} processed at {op_name} (dur={finish_time - start_time:.2f})")
            finished_queue[op_name].append(item_id)
            log_wip(env.now, op_name)

        nxt = next_station[op_name]
        if nxt is not None:
            # If enough finished items exist (i.e. batch ready), do forklift transport.
            if len(finished_queue[op_name]) >= BATCH_SIZE:
                with forklift.request() as fk_req:
                    yield fk_req
                    t_time = transport_times.get((op_name, nxt), 0.0)
                    print(f"[{env.now:.2f}] Transporting batch of {BATCH_SIZE} from {op_name} -> {nxt} (t_time={t_time})")
                    yield env.timeout(t_time)
                # Move the batch from this station’s finished to the next station's received.
                batch = finished

# %%
import simpy
import random
import pandas as pd
from collections import defaultdict

###############################################################################
# 1) User-Supplied Dictionaries & Constants
###############################################################################
process_data = {
    'OP10A': {'capacity': 2, 'cycle_time': 11.38, 'OEE': 0.8313},
    'OP20A': {'capacity': 2, 'cycle_time': 3.78,  'OEE': 0.4259},
    'OP30A': {'capacity': 1, 'cycle_time': 6.32,  'OEE': 0.4259},
    
    'OP10B': {'capacity': 2, 'cycle_time': 6.55,  'OEE': 0.8313},
    'OP20B': {'capacity': 1, 'cycle_time': 3.78,  'OEE': 0.4259},
    'OP30B': {'capacity': 1, 'cycle_time': 3.67,  'OEE': 0.4259},
    
    'OP40':  {'capacity': 3, 'cycle_time': 8.21,  'OEE': 0.8050},
    'OP50':  {'capacity': 2, 'cycle_time': 2.46,  'OEE': 0.8330},
    'OP60':  {'capacity': 5, 'cycle_time': 11.33, 'OEE': 0.4242},
    'OP65':  {'capacity': 3, 'cycle_time': 10.63, 'OEE': 0.7251},
    'OP66':  {'capacity': 3, 'cycle_time': 10.28, 'OEE': 0.8000},
}

# Routing: each station’s next process (None indicates final station)
next_station = {
    'OP10A': 'OP20A',
    'OP20A': 'OP30A',
    'OP30A': 'OP40',
    'OP10B': 'OP20B',
    'OP20B': 'OP30B',
    'OP30B': 'OP40',
    'OP40':  'OP50',
    'OP50':  'OP60',
    'OP60':  'OP65',
    'OP65':  'OP66',
    'OP66':  None,
}

transport_times = {
    ('OP10A','OP20A'): 1.0488,
    ('OP10B','OP20B'): 1.0813,
    ('OP20A','OP30A'): 3.0,
    ('OP20B','OP30B'): 3.0,
    ('OP30A','OP40'):  1.2114,
    ('OP30B','OP40'):  1.2114,
    ('OP40','OP50'):   1.1301,
    ('OP50','OP60'):   1.8130,
    ('OP60','OP65'):   1.0488,
    ('OP65','OP66'):   1.1301,
}

BATCH_SIZE = 5      # Number of items in a pallet
SIM_TIME   = 1150   # Total simulation time (time units)

###############################################################################
# 2) Global Data Structures
###############################################################################
# For each item, track arrival times:
arrival_time = {}   # key: ItemID, value: time item arrived from yard
# Results will be recorded for completed items at the final station:
results = []        # list of dicts {ItemID, ArrivalTime, DepartureTime, TimeInSystem}

# For WIP logging: we record a list of snapshots
wip_history = []    # each entry: {time, station, machine, received_wip, finished_wip}

# For each station, we implement per-machine (pallet) queues:
# Each station's received_queue: list (length==capacity) of lists (each representing one machine's pallet).
# Similarly for finished_queue.
received_queue = {}
finished_queue = {}

# We'll track machine up/down status per station (applies to all machines equally)
machine_status = {}

###############################################################################
# 3) WIP Logging Function (per station per machine)
###############################################################################
def log_wip(now, station, machine):
    r_count = len(received_queue[station][machine])
    f_count = len(finished_queue[station][machine])
    wip_history.append({
        'time': now,
        'station': station,
        'machine': machine,
        'received_wip': r_count,
        'finished_wip': f_count
    })

###############################################################################
# 4) Downtime Process (applies per station)
###############################################################################
def downtime_process(env, op_name, resource, data):
    capacity = data['capacity']
    oee = data['OEE']
    mean_time_to_fail = 50.0
    mean_time_to_repair = mean_time_to_fail * (1 - oee) / oee

    while True:
        machine_status[op_name] = True
        ttf = random.expovariate(1.0 / mean_time_to_fail)
        yield env.timeout(ttf)

        # When station goes down, we seize the resource for all machines
        requests = []
        for _ in range(capacity):
            r = resource.request(priority=-999)
            yield r
            requests.append(r)
        machine_status[op_name] = False
        print(f"*** [{env.now:.2f}] {op_name} is DOWN ***")
        ttr = random.expovariate(1.0 / mean_time_to_repair)
        yield env.timeout(ttr)
        for r in requests:
            resource.release(r)
        print(f"*** [{env.now:.2f}] {op_name} is UP ***")

###############################################################################
# 5) Machine Process (each machine in a station processes items)
###############################################################################
def machine_process(env, op_name, machine_idx, forklift):
    cycle_time = process_data[op_name]['cycle_time']
    while True:
        # If station is down, wait a bit
        if not machine_status[op_name]:
            yield env.timeout(0.2)
            continue
        # If no item in the machine's received queue, wait
        if not received_queue[op_name][machine_idx]:
            yield env.timeout(0.2)
            continue

        # Process one item from this machine's received queue
        item_id = received_queue[op_name][machine_idx].pop(0)
        log_wip(env.now, op_name, machine_idx)
        start_time = env.now
        yield env.timeout(cycle_time)
        finish_time = env.now
        print(f"[{finish_time:.2f}] {item_id} processed at {op_name} (machine {machine_idx}), dur={finish_time-start_time:.2f}")
        finished_queue[op_name][machine_idx].append(item_id)
        log_wip(env.now, op_name, machine_idx)

        # Check if finished queue has reached batch size
        if len(finished_queue[op_name][machine_idx]) >= BATCH_SIZE:
            nxt = next_station[op_name]
            if nxt is not None:
                with forklift.request() as fk_req:
                    yield fk_req
                    t_time = transport_times.get((op_name, nxt), 0.0)
                    print(f"[{env.now:.2f}] Transporting {BATCH_SIZE} from {op_name} (machine {machine_idx}) -> {nxt}, t={t_time}")
                    yield env.timeout(t_time)
                batch = finished_queue[op_name][machine_idx][:BATCH_SIZE]
                del finished_queue[op_name][machine_idx][:BATCH_SIZE]
                log_wip(env.now, op_name, machine_idx)
                # Distribute batch to next station:
                # Choose next station's machine with the shortest received queue.
                for item in batch:
                    idx = min(range(len(received_queue[nxt])), key=lambda i: len(received_queue[nxt][i]))
                    received_queue[nxt][idx].append(item)
                    log_wip(env.now, nxt, idx)
            else:
                # If nxt is None, this is the final station.
                # For each item in the batch, record departure.
                for item in finished_queue[op_name][machine_idx]:
                    dep_time = env.now
                    arr_time = arrival_time[item]
                    results.append({
                        'ItemID': item,
                        'ArrivalTime': arr_time,
                        'DepartureTime': dep_time,
                        'TimeInSystem': dep_time - arr_time
                    })
                finished_queue[op_name][machine_idx] = []  # clear the batch

###############################################################################
# 6) Yard Generator (pull-based) -- Produces new items into the starting station
###############################################################################
def yard_generator(env, station_name, interarrival_time):
    """Continuously create new items from the yard and assign them to the machine
    (pallet) in 'station_name' with the shortest received queue."""
    item_counter = 0
    while True:
        # Pull condition could be added here if desired (e.g., check downstream WIP)
        item_counter += 1
        new_item = f"YardItem-{station_name}-{item_counter}"
        arrival_time[new_item] = env.now
        # Assign to the machine (pallet) with the fewest items:
        idx = min(range(len(received_queue[station_name])), key=lambda i: len(received_queue[station_name][i]))
        received_queue[station_name][idx].append(new_item)
        log_wip(env.now, station_name, idx)
        print(f"[{env.now:.2f}] Created {new_item} for {station_name} (machine {idx})")
        yield env.timeout(interarrival_time)

###############################################################################
# 7) Main Simulation
###############################################################################
def run_simulation():
    random.seed(42)
    env = simpy.Environment()

    # Initialize global data structures for each station per machine.
    resources = {}
    for op_name, data in process_data.items():
        cap = data['capacity']
        resources[op_name] = simpy.PriorityResource(env, capacity=cap)
        machine_status[op_name] = True
        # Create separate queues per machine for received and finished goods.
        received_queue[op_name] = [[] for _ in range(cap)]
        finished_queue[op_name] = [[] for _ in range(cap)]

    forklift = simpy.Resource(env, capacity=1)

    # Start downtime processes
    for op_name, data in process_data.items():
        env.process(downtime_process(env, op_name, resources[op_name], data))

    # Start machine processes for each station (one per machine)
    for op_name, data in process_data.items():
        cap = data['capacity']
        for i in range(cap):
            env.process(machine_process(env, op_name, i, forklift))

    # Start yard generators for the starting stations.
    # We assume the yard feeds OP10A and OP10B.
    env.process(yard_generator(env, 'OP10A', interarrival_time=5.0))
    env.process(yard_generator(env, 'OP10B', interarrival_time=5.0))

    # Run simulation
    env.run(until=SIM_TIME)
    print("\nSimulation complete.\n")

    # Build final results dataframe:
    # For the final station(s), items that are still in finished_queue are "complete."
    final_station = 'OP66'
    # For each machine in final station:
    for i in range(len(finished_queue[final_station])):
        for item in finished_queue[final_station][i]:
            dep = SIM_TIME
            arr = arrival_time[item]
            results.append({
                'ItemID': item,
                'ArrivalTime': arr,
                'DepartureTime': dep,
                'TimeInSystem': dep - arr
            })
    df_results = pd.DataFrame(results)
    df_wip = pd.DataFrame(wip_history)
    return df_results, df_wip

###############################################################################
# 8) Execute Simulation and Output DataFrames
###############################################################################
if __name__ == '__main__':
    df_results, df_wip = run_simulation()
    print("\n--- RESULTS DataFrame (TIS) ---")
    print(df_results.head(20))
    print("\n--- WIP DataFrame ---")
    print(df_wip.head(20))
# Out:
# [0.00] Created YardItem-OP10A-1 for OP10A (machine 0)
# [0.00] Created YardItem-OP10B-1 for OP10B (machine 0)
# *** [1.27] OP20A is DOWN ***
# *** [1.51] OP65 is DOWN ***
# *** [2.02] OP65 is UP ***
# 42  YardItem-OP10A-17         80.0          813.6         733.6
# 43  YardItem-OP10A-23        110.0          813.6         703.6
# 44  YardItem-OP10B-20         95.0          813.6         718.6

# %%
import simpy
import random
import pandas as pd
from collections import defaultdict

###############################################################################
# 1) User-Supplied Dictionaries & Constants
###############################################################################
# (These dictionaries come from your code)
process_data = {
    'OP10A': {'capacity': 2, 'cycle_time': 11.38, 'OEE': 0.8313},
    'OP20A': {'capacity': 2, 'cycle_time': 3.78,  'OEE': 0.4259},
    'OP30A': {'capacity': 1, 'cycle_time': 6.32,  'OEE': 0.4259},
    
    'OP10B': {'capacity': 2, 'cycle_time': 6.55,  'OEE': 0.8313},
    'OP20B': {'capacity': 1, 'cycle_time': 3.78,  'OEE': 0.4259},
    'OP30B': {'capacity': 1, 'cycle_time': 3.67,  'OEE': 0.4259},
    
    'OP40':  {'capacity': 3, 'cycle_time': 8.21,  'OEE': 0.8050},
    'OP50':  {'capacity': 2, 'cycle_time': 2.46,  'OEE': 0.8330},
    'OP60':  {'capacity': 5, 'cycle_time': 11.33, 'OEE': 0.4242},
    'OP65':  {'capacity': 3, 'cycle_time': 10.63, 'OEE': 0.7251},
    'OP66':  {'capacity': 3, 'cycle_time': 10.28, 'OEE': 0.8},
}

next_station = {
    'OP10A': 'OP20A',
    'OP20A': 'OP30A',
    'OP30A': 'OP40',
    'OP10B': 'OP20B',
    'OP20B': 'OP30B',
    'OP30B': 'OP40',
    'OP40':  'OP50',
    'OP50':  'OP60',
    'OP60':  'OP65',
    'OP65':  'OP66',
    'OP66':  None,
}

transport_times = {
    ('OP10A','OP20A'): 1.0488,
    ('OP10B','OP20B'): 1.0813,
    ('OP20A','OP30A'): 3.0,
    ('OP20B','OP30B'): 3.0,
    ('OP30A','OP40'):  1.2114,
    ('OP30B','OP40'):  1.2114,
    ('OP40','OP50'):   1.1301,
    ('OP50','OP60'):   1.8130,
    ('OP60','OP65'):   1.0488,
    ('OP65','OP66'):   1.1301,
}

BATCH_SIZE = 5
SIM_TIME   = 1150

###############################################################################
# 2) Global Data Structures for Item-Level Tracking & WIP Logging
###############################################################################
# For each item, store its arrival time (set when it is created by the yard generator)
arrival_time = {}    # key: ItemID, value: arrival time

# Results: a list of dictionaries for items that complete the final station.
results = []         # each dict: {ItemID, ArrivalTime, DepartureTime, TimeInSystem}

# WIP logging: we collect a record every time a machine’s queue changes.
wip_history = []     # each record: {time, station, machine, received_wip, finished_wip}

# For each station, we have separate queues for each machine (i.e., pallet).
# received_queue and finished_queue are dictionaries mapping station name to a list of lists.
# For example, if OP40 has 3 machines, then:
#   received_queue['OP40'] = [[], [], []]
#   finished_queue['OP40'] = [[], [], []]
received_queue = {}
finished_queue = {}

# We'll track the machine up/down status per station (applies to all machines equally)
machine_status = {}

###############################################################################
# 3) WIP Logging Function
###############################################################################
def log_wip(now, station, machine):
    """Record the current number of items in the received and finished queues
    for the given station and machine."""
    r_count = len(received_queue[station][machine])
    f_count = len(finished_queue[station][machine])
    wip_history.append({
        'time': now,
        'station': station,
        'machine': machine,
        'received_wip': r_count,
        'finished_wip': f_count
    })

###############################################################################
# 4) Downtime Process (per station)
###############################################################################
def downtime_process(env, op_name, resource, data):
    capacity = data['capacity']
    oee = data['OEE']
    mean_time_to_fail = 50.0
    mean_time_to_repair = mean_time_to_fail * (1 - oee) / oee

    while True:
        machine_status[op_name] = True
        ttf = random.expovariate(1.0 / mean_time_to_fail)
        yield env.timeout(ttf)

        # Seize resource for all machines (simulate station downtime)
        requests = []
        for _ in range(capacity):
            r = resource.request(priority=-999)
            yield r
            requests.append(r)
        machine_status[op_name] = False
        print(f"*** [{env.now:.2f}] {op_name} is DOWN ***")
        ttr = random.expovariate(1.0 / mean_time_to_repair)
        yield env.timeout(ttr)
        for r in requests:
            resource.release(r)
        print(f"*** [{env.now:.2f}] {op_name} is UP ***")

###############################################################################
# 5) Machine Process (each machine on a station)
###############################################################################
def machine_process(env, op_name, machine_idx, forklift):
    cycle_time = process_data[op_name]['cycle_time']
    while True:
        # If station is down or no item waiting in this machine's received queue, wait
        if (not machine_status[op_name]) or (len(received_queue[op_name][machine_idx]) == 0):
            yield env.timeout(0.2)
            continue

        # Process one item
        with resources[op_name].request(priority=0) as req:
            yield req
            # Pop the item from this machine's received queue
            item_id = received_queue[op_name][machine_idx].pop(0)
            log_wip(env.now, op_name, machine_idx)
            start_time = env.now
            yield env.timeout(cycle_time)
            finish_time = env.now
            print(f"[{finish_time:.2f}] {item_id} processed at {op_name} (machine {machine_idx}), dur={finish_time-start_time:.2f}")
            # Push the item into this machine's finished queue
            finished_queue[op_name][machine_idx].append(item_id)
            log_wip(env.now, op_name, machine_idx)

        # Check if this machine has enough finished items to form a pallet (batch)
        if len(finished_queue[op_name][machine_idx]) >= BATCH_SIZE:
            nxt = next_station[op_name]
            if nxt is not None:
                with forklift.request() as fk_req:
                    yield fk_req
                    t_time = transport_times.get((op_name, nxt), 0.0)
                    print(f"[{env.now:.2f}] Transporting {BATCH_SIZE} items from {op_name} (machine {machine_idx}) -> {nxt}, t={t_time}")
                    yield env.timeout(t_time)
                # Remove the batch and assign to a machine in the next station.
                batch = finished_queue[op_name][machine_idx][:BATCH_SIZE]
                del finished_queue[op_name][machine_idx][:BATCH_SIZE]
                log_wip(env.now, op_name, machine_idx)
                # In next station, assign each item to the machine with the smallest received queue.
                for item in batch:
                    # For next station, find machine index with minimal received queue length.
                    next_machines = received_queue[nxt]
                    target_idx = min(range(len(next_machines)), key=lambda i: len(next_machines[i]))
                    received_queue[nxt][target_idx].append(item)
                    log_wip(env.now, nxt, target_idx)
            else:
                # This is final station; record departure for each item in the batch.
                for item in finished_queue[op_name][machine_idx]:
                    dep_time = env.now
                    arr_time = arrival_time[item]
                    results.append({
                        'ItemID': item,
                        'ArrivalTime': arr_time,
                        'DepartureTime': dep_time,
                        'TimeInSystem': dep_time - arr_time
                    })
                finished_queue[op_name][machine_idx] = []  # Clear batch

###############################################################################
# 6) Pull-based Yard Generator for Starting Stations (OP10A and OP10B)
###############################################################################
def wait_for_line_conditions(env, resources, machine_status, station, downstream_station, threshold):
    """
    Wait until the downstream station (e.g. OP20A or OP20B) has less than the threshold of WIP.
    Also, wait until the bottleneck (OP30A or OP30B) is up.
    """
    while True:
        # Determine downstream condition: use the received queue of the downstream station.
        downstream_wip = sum(len(received_queue[downstream_station][i]) for i in range(len(received_queue[downstream_station])))
        # Check that the bottleneck (OP30A/OP30B) is up.
        if station == 'OP10A':
            if (machine_status['OP30A']) and (downstream_wip < threshold):
                return
        elif station == 'OP10B':
            if (machine_status['OP30B']) and (downstream_wip < threshold):
                return
        yield env.timeout(1.0)

def yard_generator(env, station_name, interarrival_time):
    """
    Pull-based yard generator: creates new items only when conditions are met.
    For the starting station (e.g., OP10A or OP10B), wait until:
      - The downstream station (e.g., OP20A/OP20B) has less than a given WIP threshold,
      - The bottleneck (e.g., OP30A/OP30B) is up.
    Then seize the station's OP10 cycle time (simulate production delay) and then create a new item.
    """
    item_counter = 0
    res = resources[station_name]
    cycle_time_val = process_data[station_name]['cycle_time']
    # Set threshold (e.g., 100 units) for the received WIP of downstream station.
    threshold = 100
    # Determine downstream station: for OP10A, downstream is OP20A; for OP10B, OP20B.
    if station_name == 'OP10A':
        downstream = 'OP20A'
    else:
        downstream = 'OP20B'
    while True:
        yield env.process(wait_for_line_conditions(env, resources, machine_status, station_name, downstream, threshold))
        # Seize the OP10 machine (simulate production delay)
        with res.request(priority=0) as req:
            yield req
            yield env.timeout(cycle_time_val)
        item_counter += 1
        new_id = f"YardItem-{station_name}-{item_counter}"
        arrival_time[new_id] = env.now
        # Assign the new item to the machine (pallet) with the fewest items in the received queue.
        target_idx = min(range(len(received_queue[station_name])), key=lambda i: len(received_queue[station_name][i]))
        received_queue[station_name][target_idx].append(new_id)
        log_wip(env.now, station_name, target_idx)
        print(f"[{env.now:.2f}] Created {new_id} for {station_name} (machine {target_idx})")
        yield env.timeout(interarrival_time)

###############################################################################
# 7) Main Simulation Function
###############################################################################
def run_simulation():
    random.seed(42)
    env = simpy.Environment()

    # Create station resources and set machine_status.
    global resources  # so that yard_generator and machine_process can see it
    resources = {}
    for op_name, data in process_data.items():
        resources[op_name] = simpy.PriorityResource(env, capacity=data['capacity'])
        machine_status[op_name] = True
        # For each station, create per-machine queues.
        cap = data['capacity']
        received_queue[op_name] = [[] for _ in range(cap)]
        finished_queue[op_name] = [[] for _ in range(cap)]
    # Create a forklift resource (assume single forklift)
    forklift = simpy.Resource(env, capacity=1)

    # Start downtime processes for each station.
    for op_name, data in process_data.items():
        env.process(downtime_process(env, op_name, resources[op_name], data))

    # Start machine processes for each station (one per machine)
    for op_name, data in process_data.items():
        cap = data['capacity']
        for i in range(cap):
            env.process(machine_process(env, op_name, i, forklift))

    # Start yard generators for the starting stations (OP10A and OP10B).
    env.process(yard_generator(env, 'OP10A', interarrival_time=5.0))
    env.process(yard_generator(env, 'OP10B', interarrival_time=5.0))

    # Run simulation.
    env.run(until=SIM_TIME)
    print("\nSimulation complete.\n")

    # Build final item-level results DataFrame.
    final_station = 'OP66'
    for m in range(len(finished_queue[final_station])):
        for item in finished_queue[final_station][m]:
            dep = SIM_TIME
            arr = arrival_time[item]
            results.append({
                'ItemID': item,
                'ArrivalTime': arr,
                'DepartureTime': dep,
                'TimeInSystem': dep - arr
            })
    df_results = pd.DataFrame(results)

    # Build WIP DataFrame (wide format): For each station and time, each machine gets its own columns.
    df_wip_raw = pd.DataFrame(wip_history)
    # Pivot the data so that each (station, time) row has separate columns for each machine's received and finished counts.
    if not df_wip_raw.empty:
        df_wip = df_wip_raw.pivot_table(index=['time','station'], columns='machine', 
                                        values=['received_wip','finished_wip'])
        # Flatten columns: e.g. machine0_received_wip, machine0_finished_wip, etc.
        df_wip.columns = [f"machine{col[1]}_{col[0]}" for col in df_wip.columns]
        df_wip.reset_index(inplace=True)
    else:
        df_wip = pd.DataFrame()

    return df_results, df_wip

###############################################################################
# 8) Execute Simulation and Output DataFrames
###############################################################################
if __name__ == '__main__':
    df_results, df_wip = run_simulation()
    print("\n--- RESULTS DataFrame (TIS) ---")
    print(df_results.head(20))
    print("\n--- WIP DataFrame ---")
    print(df_wip.head(20))
# Out:
# *** [1.27] OP20A is DOWN ***
# *** [1.51] OP65 is DOWN ***
# *** [2.02] OP65 is UP ***
# *** [4.55] OP50 is DOWN ***
# [6.55] Created YardItem-OP10B-1 for OP10B (machine 0)
# [11.38] Created YardItem-OP10A-1 for OP10A (machine 0)
# *** [12.34] OP66 is DOWN ***
# *** [13.11] OP65 is DOWN ***
# [13.15] YardItem-OP10B-1 processed at OP10B (machine 0), dur=6.55
# *** [15.07] OP50 is UP ***
# *** [16.08] OP30A is DOWN ***
# *** [17.83] OP65 is UP ***
# [18.10] Created YardItem-OP10B-2 for OP10B (machine 0)
# *** [18.10] OP10B is DOWN ***
# *** [18.15] OP65 is DOWN ***
# *** [22.18] OP66 is UP ***
# [22.78] YardItem-OP10A-1 processed at OP10A (machine 0), dur=11.38
# *** [27.40] OP60 is DOWN ***
# *** [34.73] OP10B is UP ***
# *** [38.87] OP60 is UP ***
# *** [40.86] OP65 is UP ***
# [41.28] Created YardItem-OP10B-3 for OP10B (machine 0)
# [41.30] YardItem-OP10B-2 processed at OP10B (machine 0), dur=6.55
# *** [42.97] OP66 is DOWN ***
# *** [44.24] OP66 is UP ***
# *** [45.73] OP65 is DOWN ***
# [47.85] YardItem-OP10B-3 processed at OP10B (machine 0), dur=6.55
# *** [48.71] OP20A is UP ***
# *** [51.00] OP10A is DOWN ***
# [52.83] Created YardItem-OP10B-4 for OP10B (machine 0)
# *** [56.46] OP30B is DOWN ***
# *** [59.39] OP60 is DOWN ***
# [59.40] YardItem-OP10B-4 processed at OP10B (machine 0), dur=6.55
# *** [59.56] OP50 is DOWN ***
# *** [63.27] OP65 is UP ***
# *** [64.28] OP10A is UP ***
# *** [64.33] OP50 is UP ***
# *** [66.68] OP20B is DOWN ***
# *** [103.42] OP65 is DOWN ***
# *** [108.25] OP30B is UP ***
# *** [111.36] OP40 is DOWN ***
# *** [111.93] OP40 is UP ***
# *** [112.51] OP50 is DOWN ***
# [115.38] Created YardItem-OP10B-5 for OP10B (machine 0)
# *** [115.94] OP50 is UP ***
# *** [119.75] OP65 is UP ***
# *** [120.09] OP50 is DOWN ***
# *** [121.16] OP50 is UP ***
# [121.95] YardItem-OP10B-5 processed at OP10B (machine 0), dur=6.55
# [121.95] Transporting 5 items from OP10B (machine 0) -> OP20B, t=1.0813
# *** [124.86] OP40 is DOWN ***
# [126.93] Created YardItem-OP10B-6 for OP10B (machine 0)
# *** [127.81] OP30A is UP ***
# *** [131.00] OP20A is DOWN ***
# *** [133.00] OP65 is DOWN ***
# [133.58] YardItem-OP10B-6 processed at OP10B (machine 0), dur=6.55
# *** [137.09] OP40 is UP ***
# *** [137.45] OP50 is DOWN ***
# *** [137.46] OP65 is UP ***
# *** [138.27] OP66 is DOWN ***
# [138.48] Created YardItem-OP10B-7 for OP10B (machine 0)
# [139.76] Created YardItem-OP10A-2 for OP10A (machine 0)
# [145.13] YardItem-OP10B-7 processed at OP10B (machine 0), dur=6.55
# *** [150.01] OP66 is UP ***
# [150.03] Created YardItem-OP10B-8 for OP10B (machine 0)
# *** [150.50] OP30A is DOWN ***
# [151.16] YardItem-OP10A-2 processed at OP10A (machine 0), dur=11.38
# *** [152.62] OP40 is DOWN ***
# *** [154.78] OP40 is UP ***
# [156.14] Created YardItem-OP10A-3 for OP10A (machine 0)
# *** [156.14] OP10A is DOWN ***
# [156.68] YardItem-OP10B-8 processed at OP10B (machine 0), dur=6.55
# *** [159.40] OP66 is DOWN ***
# [161.58] Created YardItem-OP10B-9 for OP10B (machine 0)
# *** [162.16] OP20A is UP ***
# *** [165.10] OP50 is UP ***
# [168.23] YardItem-OP10B-9 processed at OP10B (machine 0), dur=6.55
# *** [169.21] OP30B is DOWN ***
# *** [172.17] OP66 is UP ***
# [173.13] Created YardItem-OP10B-10 for OP10B (machine 0)
# *** [178.64] OP40 is DOWN ***
# [179.78] YardItem-OP10B-10 processed at OP10B (machine 0), dur=6.55
# [179.78] Transporting 5 items from OP10B (machine 0) -> OP20B, t=1.0813
# *** [181.79] OP40 is UP ***
# *** [183.42] OP40 is DOWN ***
# *** [188.01] OP40 is UP ***
# *** [189.67] OP65 is DOWN ***
# *** [192.31] OP10B is DOWN ***
# *** [194.16] OP65 is UP ***
# *** [200.02] OP20B is UP ***
# *** [202.40] OP10A is UP ***
# *** [202.86] OP20A is DOWN ***
# *** [203.60] OP40 is DOWN ***
# [203.98] YardItem-OP10B-1 processed at OP20B (machine 0), dur=3.78
# [207.76] YardItem-OP10B-2 processed at OP20B (machine 0), dur=3.78
# [211.54] YardItem-OP10B-3 processed at OP20B (machine 0), dur=3.78
# [213.94] YardItem-OP10A-3 processed at OP10A (machine 0), dur=11.38
# [215.32] YardItem-OP10B-4 processed at OP20B (machine 0), dur=3.78
# [219.10] YardItem-OP10B-5 processed at OP20B (machine 0), dur=3.78
# [219.10] Transporting 5 items from OP20B (machine 0) -> OP30B, t=3.0
# *** [219.10] OP20B is DOWN ***
# *** [221.36] OP10B is UP ***
# *** [222.80] OP50 is DOWN ***
# *** [225.64] OP50 is UP ***
# *** [233.39] OP40 is UP ***
# *** [236.74] OP10B is DOWN ***
# *** [236.80] OP20A is UP ***
# *** [238.53] OP30A is UP ***
# *** [245.66] OP10B is UP ***
# *** [246.97] OP66 is DOWN ***
# *** [248.63] OP40 is DOWN ***
# [250.52] Created YardItem-OP10A-4 for OP10A (machine 0)
# *** [257.26] OP40 is UP ***
# *** [258.04] OP10B is DOWN ***
# *** [258.53] OP10B is UP ***
# *** [260.49] OP20B is UP ***
# [261.92] YardItem-OP10A-4 processed at OP10A (machine 0), dur=11.38
# *** [262.02] OP40 is DOWN ***
# *** [264.02] OP30A is DOWN ***
# [264.28] YardItem-OP10B-6 processed at OP20B (machine 0), dur=3.78
# *** [264.33] OP10B is DOWN ***
# *** [265.00] OP10B is UP ***
# *** [266.84] OP50 is DOWN ***
# [266.90] Created YardItem-OP10A-5 for OP10A (machine 0)
# *** [266.90] OP10A is DOWN ***
# [268.06] YardItem-OP10B-7 processed at OP20B (machine 0), dur=3.78
# [271.84] YardItem-OP10B-8 processed at OP20B (machine 0), dur=3.78
# *** [274.54] OP10A is UP ***
# [275.62] YardItem-OP10B-9 processed at OP20B (machine 0), dur=3.78
# [279.40] YardItem-OP10B-10 processed at OP20B (machine 0), dur=3.78
# [279.40] Transporting 5 items from OP20B (machine 0) -> OP30B, t=3.0
# *** [281.05] OP40 is UP ***
# [286.10] YardItem-OP10A-5 processed at OP10A (machine 0), dur=11.38
# [286.10] Transporting 5 items from OP10A (machine 0) -> OP20A, t=1.0488
# *** [289.03] OP10B is DOWN ***
# *** [289.15] OP10B is UP ***
# [290.98] YardItem-OP10A-1 processed at OP20A (machine 0), dur=3.78
# [290.98] YardItem-OP10A-2 processed at OP20A (machine 1), dur=3.78
# *** [293.94] OP30B is UP ***
# [294.76] YardItem-OP10A-3 processed at OP20A (machine 0), dur=3.78
# [294.76] YardItem-OP10A-4 processed at OP20A (machine 1), dur=3.78
# [297.67] YardItem-OP10B-1 processed at OP30B (machine 0), dur=3.67
# [298.54] YardItem-OP10A-5 processed at OP20A (machine 0), dur=3.78
# *** [298.68] OP65 is DOWN ***
# [300.68] Created YardItem-OP10B-11 for OP10B (machine 0)
# *** [300.99] OP30A is UP ***
# [301.34] YardItem-OP10B-2 processed at OP30B (machine 0), dur=3.67
# *** [304.82] OP60 is UP ***
# [305.01] YardItem-OP10B-3 processed at OP30B (machine 0), dur=3.67
# [307.41] YardItem-OP10B-11 processed at OP10B (machine 0), dur=6.55
# [308.68] YardItem-OP10B-4 processed at OP30B (machine 0), dur=3.67
# *** [309.86] OP20B is DOWN ***
# [312.23] Created YardItem-OP10B-12 for OP10B (machine 0)
# [312.35] YardItem-OP10B-5 processed at OP30B (machine 0), dur=3.67
# [312.35] Transporting 5 items from OP30B (machine 0) -> OP40, t=1.2114
# *** [313.28] OP65 is UP ***
# [313.28] Created YardItem-OP10A-6 for OP10A (machine 0)
# *** [316.51] OP30A is DOWN ***
# [458.32] YardItem-OP10B-15 processed at OP40 (machine 1), dur=8.21
# [458.84] YardItem-OP10B-5 processed at OP50 (machine 0), dur=2.46
# [458.84] YardItem-OP10B-7 processed at OP50 (machine 1), dur=2.46
# [459.54] YardItem-OP10B-18 processed at OP10B (machine 0), dur=6.55
# *** [459.80] OP10A is UP ***
# [461.30] YardItem-OP10B-10 processed at OP50 (machine 0), dur=2.46
# [461.30] YardItem-OP10B-12 processed at OP50 (machine 1), dur=2.46
# [461.30] Transporting 5 items from OP50 (machine 0) -> OP60, t=1.813
# [463.11] Transporting 5 items from OP50 (machine 1) -> OP60, t=1.813
# [464.51] Created YardItem-OP10B-19 for OP10B (machine 0)
# *** [464.51] OP10B is DOWN ***
# *** [466.62] OP50 is DOWN ***
# *** [468.07] OP66 is DOWN ***
# *** [469.01] OP50 is UP ***
# *** [470.09] OP10B is UP ***
# *** [471.58] OP20B is DOWN ***
# [476.64] Created YardItem-OP10B-20 for OP10B (machine 0)
# [476.69] YardItem-OP10B-19 processed at OP10B (machine 0), dur=6.55
# *** [477.76] OP66 is UP ***
# *** [482.59] OP65 is DOWN ***
# [483.24] YardItem-OP10B-20 processed at OP10B (machine 0), dur=6.55
# [483.24] Transporting 5 items from OP10B (machine 0) -> OP20B, t=1.0813
# *** [483.24] OP10B is DOWN ***
# *** [489.09] OP10B is UP ***
# [495.64] Created YardItem-OP10B-21 for OP10B (machine 0)
# *** [496.76] OP20B is UP ***
# [500.68] YardItem-OP10B-16 processed at OP20B (machine 0), dur=3.78
# [502.28] YardItem-OP10B-21 processed at OP10B (machine 0), dur=6.55
# *** [502.49] OP65 is UP ***
# [504.46] YardItem-OP10B-17 processed at OP20B (machine 0), dur=3.78
# *** [504.46] OP20B is DOWN ***
# [507.19] Created YardItem-OP10B-22 for OP10B (machine 0)
# [513.83] YardItem-OP10B-22 processed at OP10B (machine 0), dur=6.55
# *** [515.21] OP65 is DOWN ***
# *** [515.69] OP30B is DOWN ***
# [518.74] Created YardItem-OP10B-23 for OP10B (machine 0)
# [525.38] YardItem-OP10B-23 processed at OP10B (machine 0), dur=6.55
# *** [525.54] OP10B is DOWN ***
# *** [528.06] OP10B is UP ***
# *** [531.75] OP10B is DOWN ***
# *** [531.79] OP40 is DOWN ***
# *** [532.04] OP65 is UP ***
# *** [532.27] OP20B is UP ***
# *** [532.62] OP20A is UP ***
# *** [533.32] OP30B is UP ***
# *** [534.46] OP50 is DOWN ***
# *** [534.94] OP40 is UP ***
# [536.05] YardItem-OP10B-18 processed at OP20B (machine 0), dur=3.78
# [536.52] YardItem-OP10A-6 processed at OP20A (machine 0), dur=3.78
# [536.54] YardItem-OP10A-7 processed at OP20A (machine 1), dur=3.78
# *** [536.54] OP20A is DOWN ***
# *** [539.71] OP60 is UP ***
# [539.83] YardItem-OP10B-19 processed at OP20B (machine 0), dur=3.78
# *** [541.86] OP10B is UP ***
# [543.61] YardItem-OP10B-20 processed at OP20B (machine 0), dur=3.78
# [543.61] Transporting 5 items from OP20B (machine 0) -> OP30B, t=3.0
# [597.41] YardItem-OP10B-19 processed at OP40 (machine 0), dur=8.21
# [597.54] YardItem-OP10B-20 processed at OP40 (machine 1), dur=8.21
# *** [598.41] OP40 is DOWN ***
# [598.71] YardItem-OP10B-25 processed at OP20B (machine 0), dur=3.78
# [598.71] Transporting 5 items from OP20B (machine 0) -> OP30B, t=3.0
# *** [601.46] OP10B is UP ***
# [608.01] Created YardItem-OP10B-27 for OP10B (machine 0)
# *** [613.76] OP10A is DOWN ***
# [614.66] YardItem-OP10B-27 processed at OP10B (machine 0), dur=6.55
# *** [615.75] OP10B is DOWN ***
# *** [615.90] OP10A is UP ***
# *** [621.79] OP10B is UP ***
# *** [622.37] OP40 is UP ***
# *** [622.87] OP20A is DOWN ***
# *** [626.86] OP30B is UP ***
# *** [627.06] OP30A is UP ***
# *** [630.45] OP20B is DOWN ***
# [630.64] YardItem-OP10B-21 processed at OP30B (machine 0), dur=3.67
# [633.52] YardItem-OP10A-1 processed at OP30A (machine 0), dur=6.32
# [633.56] Created YardItem-OP10B-28 for OP10B (machine 0)
# [634.31] YardItem-OP10B-22 processed at OP30B (machine 0), dur=3.67
# *** [636.74] OP40 is DOWN ***
# *** [637.37] OP40 is UP ***
# [637.98] YardItem-OP10B-23 processed at OP30B (machine 0), dur=3.67
# [638.56] Created YardItem-OP10A-12 for OP10A (machine 0)
# [639.84] YardItem-OP10A-3 processed at OP30A (machine 0), dur=6.32
# [640.21] YardItem-OP10B-28 processed at OP10B (machine 0), dur=6.55
# *** [640.21] OP10B is DOWN ***
# [641.65] YardItem-OP10B-24 processed at OP30B (machine 0), dur=3.67
# [645.32] YardItem-OP10B-25 processed at OP30B (machine 0), dur=3.67
# [645.32] Transporting 5 items from OP30B (machine 0) -> OP40, t=1.2114
# [646.16] YardItem-OP10A-5 processed at OP30A (machine 0), dur=6.32
# *** [649.95] OP65 is DOWN ***
# [650.06] YardItem-OP10A-12 processed at OP10A (machine 0), dur=11.38
# *** [650.06] OP10A is DOWN ***
# [652.48] YardItem-OP10A-6 processed at OP30A (machine 0), dur=6.32
# [654.75] YardItem-OP10B-22 processed at OP40 (machine 1), dur=8.21
# [654.82] YardItem-OP10B-21 processed at OP40 (machine 0), dur=8.21
# [654.85] YardItem-OP10B-23 processed at OP40 (machine 2), dur=8.21
# [654.85] Transporting 5 items from OP40 (machine 2) -> OP50, t=1.1301
# *** [656.13] OP30B is DOWN ***
# *** [658.55] OP10B is UP ***
# [658.57] YardItem-OP10B-3 processed at OP50 (machine 0), dur=2.46
# [658.59] YardItem-OP10B-8 processed at OP50 (machine 1), dur=2.46
# [658.80] YardItem-OP10A-8 processed at OP30A (machine 0), dur=6.32
# [658.80] Transporting 5 items from OP30A (machine 0) -> OP40, t=1.2114
# [661.03] YardItem-OP10B-13 processed at OP50 (machine 0), dur=2.46
# [661.05] YardItem-OP10B-18 processed at OP50 (machine 1), dur=2.46
# [662.96] YardItem-OP10B-25 processed at OP40 (machine 1), dur=8.21
# [662.96] Transporting 5 items from OP40 (machine 1) -> OP50, t=1.1301
# *** [742.26] OP10A is UP ***
# *** [743.29] OP65 is DOWN ***
# *** [744.19] OP66 is DOWN ***
# *** [745.84] OP10B is UP ***
# *** [746.48] OP65 is UP ***
# *** [748.59] OP66 is UP ***
# [753.64] Created YardItem-OP10A-14 for OP10A (machine 0)
# [765.22] YardItem-OP10A-14 processed at OP10A (machine 0), dur=11.38
# *** [783.41] OP30B is UP ***
# *** [787.65] OP66 is DOWN ***
# *** [788.39] OP66 is UP ***
# *** [789.76] OP65 is DOWN ***
# [790.65] Created YardItem-OP10B-30 for OP10B (machine 0)
# *** [795.91] OP20A is UP ***
# [797.31] YardItem-OP10B-30 processed at OP10B (machine 0), dur=6.55
# [797.31] Transporting 5 items from OP10B (machine 0) -> OP20B, t=1.0813
# *** [797.91] OP50 is DOWN ***
# *** [799.63] OP50 is UP ***
# [802.20] Created YardItem-OP10B-31 for OP10B (machine 0)
# [802.29] YardItem-OP10B-26 processed at OP20B (machine 0), dur=3.78
# *** [803.01] OP65 is UP ***
# *** [805.63] OP10A is DOWN ***
# [806.07] YardItem-OP10B-27 processed at OP20B (machine 0), dur=3.78
# *** [807.18] OP65 is DOWN ***
# *** [807.71] OP10A is UP ***
# *** [808.88] OP60 is UP ***
# [808.94] YardItem-OP10B-31 processed at OP10B (machine 0), dur=6.55
# [809.85] YardItem-OP10B-28 processed at OP20B (machine 0), dur=3.78
# [813.63] YardItem-OP10B-29 processed at OP20B (machine 0), dur=3.78
# [813.75] Created YardItem-OP10B-32 for OP10B (machine 0)
# [817.41] YardItem-OP10B-30 processed at OP20B (machine 0), dur=3.78
# [817.41] Transporting 5 items from OP20B (machine 0) -> OP30B, t=3.0
# [820.49] YardItem-OP10B-32 processed at OP10B (machine 0), dur=6.55
# *** [822.29] OP60 is DOWN ***
# [824.20] YardItem-OP10B-26 processed at OP30B (machine 0), dur=3.67
# *** [824.32] OP65 is UP ***
# [825.30] Created YardItem-OP10B-33 for OP10B (machine 0)
# [827.87] YardItem-OP10B-27 processed at OP30B (machine 0), dur=3.67
# *** [830.95] OP60 is UP ***
# [831.54] YardItem-OP10B-28 processed at OP30B (machine 0), dur=3.67
# [832.04] YardItem-OP10B-33 processed at OP10B (machine 0), dur=6.55
# *** [832.26] OP66 is DOWN ***
# [835.21] YardItem-OP10B-29 processed at OP30B (machine 0), dur=3.67
# [836.85] Created YardItem-OP10B-34 for OP10B (machine 0)
# [838.88] YardItem-OP10B-30 processed at OP30B (machine 0), dur=3.67
# [838.88] Transporting 5 items from OP30B (machine 0) -> OP40, t=1.2114
# *** [843.55] OP66 is UP ***
# [843.59] YardItem-OP10B-34 processed at OP10B (machine 0), dur=6.55
# *** [845.09] OP60 is DOWN ***
# [848.32] YardItem-OP10B-27 processed at OP40 (machine 1), dur=8.21
# [848.40] YardItem-OP10B-28 processed at OP40 (machine 2), dur=8.21
# [848.40] Created YardItem-OP10B-35 for OP10B (machine 0)
# [848.45] YardItem-OP10B-26 processed at OP40 (machine 0), dur=8.21
# *** [852.32] OP30B is DOWN ***
# [855.14] YardItem-OP10B-35 processed at OP10B (machine 0), dur=6.55
# [855.14] Transporting 5 items from OP10B (machine 0) -> OP20B, t=1.0813
# [856.53] YardItem-OP10B-30 processed at OP40 (machine 1), dur=8.21
# [856.66] YardItem-OP10B-29 processed at OP40 (machine 0), dur=8.21
# [860.19] YardItem-OP10B-31 processed at OP20B (machine 0), dur=3.78
# *** [863.94] OP10A is DOWN ***
# [863.97] YardItem-OP10B-32 processed at OP20B (machine 0), dur=3.78
# [867.75] YardItem-OP10B-33 processed at OP20B (machine 0), dur=3.78
# *** [871.45] OP10A is UP ***
# [871.53] YardItem-OP10B-34 processed at OP20B (machine 0), dur=3.78
# [875.31] YardItem-OP10B-35 processed at OP20B (machine 0), dur=3.78
# [875.31] Transporting 5 items from OP20B (machine 0) -> OP30B, t=3.0
# *** [877.14] OP20B is DOWN ***
# *** [881.97] OP60 is UP ***
# *** [891.68] OP20A is DOWN ***
# *** [891.84] OP66 is DOWN ***
# *** [892.54] OP20B is UP ***
# *** [898.14] OP66 is UP ***
# *** [910.06] OP20A is UP ***
# *** [911.38] OP30B is UP ***
# [915.16] YardItem-OP10B-31 processed at OP30B (machine 0), dur=3.67
# *** [915.98] OP66 is DOWN ***
# *** [916.92] OP66 is UP ***
# [917.95] Created YardItem-OP10B-36 for OP10B (machine 0)
# [918.83] YardItem-OP10B-32 processed at OP30B (machine 0), dur=3.67
# [922.50] YardItem-OP10B-33 processed at OP30B (machine 0), dur=3.67
# [924.57] YardItem-OP10B-36 processed at OP10B (machine 0), dur=6.55
# *** [924.57] OP10B is DOWN ***
# [926.17] YardItem-OP10B-34 processed at OP30B (machine 0), dur=3.67
# *** [929.07] OP20A is DOWN ***
# [929.84] YardItem-OP10B-35 processed at OP30B (machine 0), dur=3.67
# [929.84] Transporting 5 items from OP30B (machine 0) -> OP40, t=1.2114
# *** [934.81] OP65 is DOWN ***
# *** [936.25] OP65 is UP ***
# [939.27] YardItem-OP10B-31 processed at OP40 (machine 0), dur=8.21
# [939.27] Transporting 5 items from OP40 (machine 0) -> OP50, t=1.1301
# [939.34] YardItem-OP10B-32 processed at OP40 (machine 1), dur=8.21
# [939.41] YardItem-OP10B-33 processed at OP40 (machine 2), dur=8.21
# [940.40] Transporting 5 items from OP40 (machine 1) -> OP50, t=1.1301
# [942.87] YardItem-OP10A-1 processed at OP50 (machine 0), dur=2.46
# [943.02] YardItem-OP10A-6 processed at OP50 (machine 1), dur=2.46
# *** [944.94] OP60 is DOWN ***
# [945.33] YardItem-OP10B-26 processed at OP50 (machine 0), dur=2.46
# [945.33] Transporting 5 items from OP50 (machine 0) -> OP60, t=1.813
# [945.48] YardItem-OP10B-29 processed at OP50 (machine 1), dur=2.46
# *** [947.57] OP66 is DOWN ***
# [947.94] YardItem-OP10A-3 processed at OP50 (machine 1), dur=2.46
# [947.94] Transporting 5 items from OP50 (machine 1) -> OP60, t=1.813
# *** [948.23] OP20B is DOWN ***
# *** [948.24] OP65 is DOWN ***
# [948.61] YardItem-OP10B-34 processed at OP40 (machine 0), dur=8.21
# [949.60] YardItem-OP10B-31 processed at OP50 (machine 0), dur=2.46
# [949.74] YardItem-OP10B-35 processed at OP40 (machine 1), dur=8.21
# [952.06] YardItem-OP10A-8 processed at OP50 (machine 0), dur=2.46
# [952.21] YardItem-OP10B-27 processed at OP50 (machine 1), dur=2.46
# [954.52] YardItem-OP10B-30 processed at OP50 (machine 0), dur=2.46
# [954.67] YardItem-OP10B-32 processed at OP50 (machine 1), dur=2.46
# *** [961.55] OP50 is DOWN ***
# *** [965.85] OP60 is UP ***
# *** [966.18] OP50 is UP ***
# [977.25] YardItem-OP10B-25 processed at OP60 (machine 0), dur=11.33
# [977.25] YardItem-OP10B-16 processed at OP60 (machine 1), dur=11.33
# [977.25] YardItem-OP10B-21 processed at OP60 (machine 2), dur=11.33
# [977.25] YardItem-OP10A-1 processed at OP60 (machine 3), dur=11.33
# [977.25] Transporting 5 items from OP60 (machine 0) -> OP65, t=1.0488
# [977.38] YardItem-OP10B-26 processed at OP60 (machine 4), dur=11.33
# *** [977.38] OP60 is DOWN ***
# [978.30] Transporting 5 items from OP60 (machine 1) -> OP65, t=1.0488
# [979.35] Transporting 5 items from OP60 (machine 2) -> OP65, t=1.0488
# [980.40] Transporting 5 items from OP60 (machine 3) -> OP65, t=1.0488
# *** [981.07] OP30B is DOWN ***
# *** [981.41] OP66 is UP ***
# [981.45] Transporting 5 items from OP60 (machine 4) -> OP65, t=1.0488
# *** [988.32] OP65 is UP ***
# *** [990.24] OP10B is UP ***
# [996.79] Created YardItem-OP10B-37 for OP10B (machine 0)
# *** [996.79] OP10B is DOWN ***
# [999.03] YardItem-OP10B-1 processed at OP65 (machine 0), dur=10.63
# [999.03] YardItem-OP10B-4 processed at OP65 (machine 1), dur=10.63
# [999.03] YardItem-OP10B-3 processed at OP65 (machine 2), dur=10.63
# *** [999.36] OP40 is DOWN ***
# *** [1003.66] OP40 is UP ***
# *** [1007.89] OP10A is DOWN ***
# [1009.66] YardItem-OP10B-8 processed at OP65 (machine 0), dur=10.63
# [1009.66] YardItem-OP10B-25 processed at OP65 (machine 1), dur=10.63
# [1009.66] YardItem-OP10B-6 processed at OP65 (machine 2), dur=10.63
# *** [1014.03] OP10B is UP ***
# [1020.29] YardItem-OP10B-9 processed at OP65 (machine 0), dur=10.63
# [1020.29] YardItem-OP10B-13 processed at OP65 (machine 1), dur=10.63
# [1020.29] YardItem-OP10B-18 processed at OP65 (machine 2), dur=10.63
# [1020.72] YardItem-OP10B-37 processed at OP10B (machine 0), dur=6.55
# *** [1021.24] OP10B is DOWN ***
# *** [1022.49] OP10B is UP ***
# *** [1028.15] OP10B is DOWN ***
# [1030.92] YardItem-OP10B-16 processed at OP65 (machine 0), dur=10.63
# [1030.92] YardItem-OP10B-11 processed at OP65 (machine 1), dur=10.63
# [1030.92] YardItem-OP10B-2 processed at OP65 (machine 2), dur=10.63
# *** [1036.26] OP10A is UP ***
# *** [1036.32] OP10B is UP ***
# [1041.55] YardItem-OP10B-23 processed at OP65 (machine 0), dur=10.63
# *** [1093.51] OP10B is DOWN ***
# [1094.20] YardItem-OP10B-18 processed at OP66 (machine 0), dur=10.28
# [1094.20] YardItem-OP10B-2 processed at OP66 (machine 1), dur=10.28
# [1094.20] YardItem-OP10B-21 processed at OP66 (machine 2), dur=10.28
# *** [1094.31] OP10B is UP ***
# [1101.02] Created YardItem-OP10A-15 for OP10A (machine 0)
# *** [1101.02] OP10A is DOWN ***
# *** [1101.40] OP30B is UP ***
# *** [1101.85] OP40 is DOWN ***
# [1108.89] Created YardItem-OP10B-39 for OP10B (machine 0)
# *** [1112.57] OP65 is UP ***
# [1115.62] YardItem-OP10B-39 processed at OP10B (machine 0), dur=6.55
# *** [1119.52] OP20B is DOWN ***
# [1120.44] Created YardItem-OP10B-40 for OP10B (machine 0)
# [1123.20] YardItem-OP10B-14 processed at OP65 (machine 2), dur=10.63
# [1123.20] YardItem-OP10B-20 processed at OP65 (machine 1), dur=10.63
# [1123.20] YardItem-OP10B-12 processed at OP65 (machine 0), dur=10.63
# *** [1123.64] OP40 is UP ***
# *** [1124.79] OP10A is UP ***
# [1127.17] YardItem-OP10B-40 processed at OP10B (machine 0), dur=6.55
# [1127.17] Transporting 5 items from OP10B (machine 0) -> OP20B, t=1.0813
# *** [1129.01] OP30A is DOWN ***
# *** [1130.32] OP20B is UP ***
# *** [1130.46] OP40 is DOWN ***
# [1131.99] Created YardItem-OP10B-41 for OP10B (machine 0)
# [1133.83] YardItem-OP10B-26 processed at OP65 (machine 0), dur=10.63
# [1134.29] YardItem-OP10B-36 processed at OP20B (machine 0), dur=3.78
# [1136.17] Created YardItem-OP10A-16 for OP10A (machine 0)
# [1136.20] YardItem-OP10A-15 processed at OP10A (machine 0), dur=11.38
# [1136.20] Transporting 5 items from OP10A (machine 0) -> OP20A, t=1.0488
# [1138.07] YardItem-OP10B-37 processed at OP20B (machine 0), dur=3.78
# [1138.60] YardItem-OP10B-41 processed at OP10B (machine 0), dur=6.55
# *** [1140.83] OP30B is DOWN ***
# [1141.85] YardItem-OP10B-38 processed at OP20B (machine 0), dur=3.78
# [1143.54] Created YardItem-OP10B-42 for OP10B (machine 0)
# *** [1145.39] OP60 is DOWN ***
# [1145.63] YardItem-OP10B-39 processed at OP20B (machine 0), dur=3.78
# [1148.63] YardItem-OP10A-16 processed at OP10A (machine 0), dur=11.38
# *** [1148.63] OP10A is DOWN ***
# [1149.41] YardItem-OP10B-40 processed at OP20B (machine 0), dur=3.78
# [1149.41] Transporting 5 items from OP20B (machine 0) -> OP30B, t=3.0
#
# Simulation complete.
#
#
# --- RESULTS DataFrame (TIS) ---
#                ItemID  ArrivalTime  DepartureTime  TimeInSystem
# 0    YardItem-OP10B-1     6.550000         1094.2   1087.650000
# 1   YardItem-OP10B-16   429.855405         1094.2    664.344595
# 2   YardItem-OP10B-25   571.963979         1094.2    522.236021
# 3   YardItem-OP10B-17   441.405405         1094.2    652.794595
# 4   YardItem-OP10B-18   452.955405         1094.2    641.244595
# 5    YardItem-OP10B-8   150.030190         1094.2    944.169810
