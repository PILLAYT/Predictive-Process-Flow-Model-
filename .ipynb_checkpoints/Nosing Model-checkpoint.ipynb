# %%
# ---
# Nosing (NP) mini-model — pallet=42, constrained heat-area, pallet-by-pallet weighing
# SimPy 4.x
# ---

import simpy
from dataclasses import dataclass, asdict
from collections import deque, defaultdict

# ----------------------------
# Editable parameters up front
# ----------------------------
@dataclass
class Params:
    SIM_TIME: float = 11 * 60.0             # total sim time (minutes)
    BATCH_SIZE: int = 42                   # shells per pallet
    ARRIVAL_MEAN: float = 140.0             # minutes between arriving pallets (editable)

    # Handling / process times (minutes)
    t_transfer_per_shell: float = 0.1476     # transfer wood->metal, per shell
    t_heat_per_pallet: float    = 60    # torch dwell per pallet
    t_graphite_per_shell: float = 1.6913     # graphite painting (capacity = 1)
    t_cool_pallet: float        = 57.17     # cooling dwell (infinite capacity)

    # Weigh & mark: operator processes one full pallet at a time (one-by-one within pallet)
    t_weigh_per_shell: float    = 0.4719

    # Induction + press (single-piece sequential)
    t_induction_per_shell: float = 1.8667
    t_press_per_shell: float     = 0.5167

    # Capacities
    HEAT_WAIT_CAP_PALLETS: int = 2         # max pallets waiting for torch (excludes the one under torch)
    GRAPHITE_CAPACITY: int     = 1       # strictly one-at-a-time

P = Params()

# ----------------------------
# Simple KPI/trace collectors
# ----------------------------
class KPIs:
    def __init__(self):
        self.ct = defaultdict(int)     # counters
        self.log = deque(maxlen=2000)  # short rolling log

    def note(self, t, msg):
        line = f"[{t:7.2f}] {msg}"
        self.log.append(line)
        print(line)   # live console output

kpi = KPIs()

# ----------------------------
# Helper containers & objects
# ----------------------------
class Shell:
    """Single unit flowing through NP. Carries batch/unit IDs for logging."""
    _seq = 0
    def __init__(self, batch_id: int, unit_in_batch: int):
        Shell._seq += 1
        self.gid = Shell._seq                   # global unique id
        self.batch = batch_id                   # == pallet id
        self.unit = unit_in_batch               # 1..BATCH_SIZE
        self.label = f"B{self.batch}-U{self.unit}"

    def __repr__(self):
        return f"Shell#{self.gid}({self.label})"


class Pallet:
    """Bundle of shells; batch_id == pallet id. Holds actual Shell objects."""
    _seq = 0
    def __init__(self, n_shells):
        Pallet._seq += 1
        self.id = Pallet._seq
        # build shells now so batch/unit labels are fixed
        self.shells = [Shell(self.id, i+1) for i in range(n_shells)]
        self.tag = "WOOD_IN"  # WOOD_IN → METAL_HEAT → WOOD_COOL → ...

    @property
    def n(self):
        return len(self.shells)

    def __repr__(self):
        return f"Pallet#{self.id}(n={self.n}, tag={self.tag})"
# ----------------------------
# Model
# ----------------------------
def arrival(env, params, input_queue):
    """Batched arrivals of WOOD pallets into the NP input buffer."""
    while True:
        # create an arriving wood pallet of 42
        p = Pallet(params.BATCH_SIZE)
        kpi.ct['arrived_pallets'] += 1
        kpi.note(env.now, f"Arrive {p}")
        input_queue.put(p)
        # next pallet arrival
        yield env.timeout(params.ARRIVAL_MEAN)

def transfer_to_metal(env, params, input_queue, heat_wait_q, heat_ready):
    """
    Transfer one-by-one from WOOD pallet to a METAL pallet, then push METAL pallet to the
    heating wait area (capacity-limited). We reserve a heat-wait slot *before* starting.
    """
    while True:
        # get a wood pallet from input
        p_in = yield input_queue.get()

        # reserve one waiting-bay token (capacity control)
        yield heat_wait_q.put(1)

        # create empty metal pallet and move shells one-by-one
        p_metal = Pallet(0)
        p_metal.tag = "METAL_HEAT"

        for s in list(p_in.shells):
            yield env.timeout(params.t_transfer_per_shell)
            p_in.shells.remove(s)
            p_metal.shells.append(s)
            kpi.note(env.now, f"{s} moved WOOD → METAL (to {p_metal})")

        # done transferring this pallet
        kpi.ct['transferred_pallets'] += 1
        kpi.note(env.now, f"Transferred -> {p_metal} (reserved heat slot)")

        # hand metal pallet to heat queue (explicit event yield)
        yield heat_ready.put(p_metal)


def torch_heating(env, params, heat_ready, heat_wait_q, torch_busy, hot_pallets):
    """
    Single torch heats one pallet at a time. The wait area has limited capacity.
    When a pallet finishes heating, we release a slot token (heat_wait_q.get()).
    """
    while True:
        p = yield heat_ready.get()
        with torch_busy.request() as req:
            yield req
            kpi.note(env.now, f"Torch start {p}")
            yield env.timeout(params.t_heat_per_pallet)
            kpi.ct['heated_pallets'] += 1
            kpi.note(env.now, f"Torch done  {p}")

        # after heating, send pallet to graphite and free a waiting slot
        yield hot_pallets.put(p)
        yield heat_wait_q.get(1)

def graphite_station(env, params, hot_pallets, graphite_busy, cooled_pallets):
    """
    One pallet in graphite at a time (graphite_busy capacity=1),
    but within that pallet, process shells in parallel batches of size K=GRAPHITE_CAPACITY.
    This makes K shells start and finish at the same time each wave.
    """
    while True:
        p = yield hot_pallets.get()

        # Hold the station for this pallet
        with graphite_busy.request() as req:
            yield req
            kpi.note(env.now, f"Graphite start on {p}")

            K = max(1, params.GRAPHITE_CAPACITY)
            shells = list(p.shells)

            # Process in waves of K shells concurrently
            for i in range(0, len(shells), K):
                batch = shells[i:i+K]
                kpi.note(env.now, f"Graphite wave start ({len(batch)}/{K}) on {p}")

                def paint_one(env, s):
                    yield env.timeout(params.t_graphite_per_shell)
                    kpi.ct['graphited_shells'] += 1
                    kpi.note(env.now, f"{s} graphite done")

                procs = [env.process(paint_one(env, s)) for s in batch]
                # Wait until this wave finishes (so they end together)
                yield simpy.AllOf(env, procs)

            kpi.note(env.now, f"Graphite done  on {p}")

        # Cooling dwell after graphite (station is free while cooling)
        yield env.timeout(params.t_cool_pallet)
        p.tag = "WOOD_COOL"
        yield cooled_pallets.put(p)
        kpi.note(env.now, f"Pallet cooled {p}")

def weigh_operator(env, params, cooled_pallets, ready_pallets, weigh_busy):
    """
    Operator fetches cooled pallets and weighs/classifies shells one-by-one.
    We assemble new outbound pallets of size BATCH_SIZE before releasing downstream.
    """
    acc = []  # accumulating weighed shells

    while True:
        p = yield cooled_pallets.get()
        with weigh_busy.request() as req:
            yield req
            kpi.note(env.now, f"Weigh start  {p}")

            for s in list(p.shells):
                yield env.timeout(params.t_weigh_per_shell)
                kpi.ct['weighed_shells'] += 1
                acc.append(s)
                kpi.note(env.now, f"{s} weighed/classified → staged (pallet assembly {len(acc)}/{params.BATCH_SIZE})")

                # assemble as many full pallets as possible (robust if >42 available)
                while len(acc) >= params.BATCH_SIZE:
                    p_full = Pallet(0)
                    p_full.tag = "WEIGHED_FULL"
                    p_full.shells = acc[:params.BATCH_SIZE]
                    del acc[:params.BATCH_SIZE]

                    kpi.ct['assembled_full_pallets'] += 1
                    kpi.note(env.now, f"Assembled FULL pallet → {p_full} → READY_PALLETS")
                    yield ready_pallets.put(p_full)

            kpi.note(env.now, f"Weigh done   {p}")

def induction_heater(env, params, weighed_shells_q, press_in_q):
    """Single-piece induction heating. Infinite waiting queue upstream."""
    while True:
        s = yield weighed_shells_q.get()
        kpi.note(env.now, f"IH start {s}")
        yield env.timeout(params.t_induction_per_shell)
        kpi.ct['heated_shells'] += 1
        kpi.note(env.now, f"IH done  {s} → Press queue")
        press_in_q.put(s)

def nosing_press(env, params, press_in_q, finished_q):
    """Single-piece press cycle."""
    while True:
        s = yield press_in_q.get()
        kpi.note(env.now, f"Press start {s}")
        yield env.timeout(params.t_press_per_shell)
        kpi.ct['forged_shells'] += 1
        kpi.note(env.now, f"Press done  {s} → Finished")
        finished_q.put(s)
        
def sink(env, finished_q, output_q):
    """Collect completions into the OUTPUT_Q (do not destroy)."""
    while True:
        s = yield finished_q.get()
        kpi.ct['completed_shells'] += 1
        output_q.put(s)  # keep it
        kpi.note(env.now, f"COMPLETED {s} → OUTPUT_Q")
        
def pallet_feeder(env, params, ready_pallets, weighed_shells_q):
    """
    Take a full pallet and release shells one-by-one into weighed_shells_q.
    """
    while True:
        p = yield ready_pallets.get()
        kpi.note(env.now, f"Feeder releasing from {p} → IH queue (one-by-one)")
        for s in list(p.shells):
            yield weighed_shells_q.put(s)
            kpi.note(env.now, f"{s} → IH queue (from {p})")
# ----------------------------
# Build & run
# ----------------------------
def build_and_run(params=P, seed=1):
    rng = simpy.Environment()

    # QUEUES / BUFFERS
    INPUT_Q        = simpy.Store(rng)                    # arriving wood pallets
    HEAT_WAIT_Q    = simpy.Container(rng, init=0, capacity=params.HEAT_WAIT_CAP_PALLETS)
    HEAT_READY     = simpy.Store(rng)                    # metal pallets ready for torch
    HOT_PALLETS    = simpy.Store(rng)                    # hot pallets going to graphite
    COOLED_PALLETS = simpy.Store(rng)                    # infinite capacity
    WEIGHED_Q      = simpy.Store(rng)                    # per-shell queue
    PRESS_IN_Q     = simpy.Store(rng)
    FINISHED_Q     = simpy.Store(rng)
    OUTPUT_Q       = simpy.Store(rng)
    READY_PALLETS  = simpy.Store(rng)                    # full (42) pallets

    # RESOURCES (cap = 1 each station)
    torch_busy     = simpy.Resource(rng, capacity=1)
    graphite_busy  = simpy.Resource(rng, capacity=params.GRAPHITE_CAPACITY)  # =1
    weigh_busy     = simpy.Resource(rng, capacity=1)

    # PROCESSES (independent consumers with buffers in between)
    rng.process(arrival(rng, params, INPUT_Q))
    rng.process(transfer_to_metal(rng, params, INPUT_Q, HEAT_WAIT_Q, HEAT_READY))
    rng.process(torch_heating(rng, params, HEAT_READY, HEAT_WAIT_Q, torch_busy, HOT_PALLETS))
    rng.process(graphite_station(rng, params, HOT_PALLETS, graphite_busy, COOLED_PALLETS))
    rng.process(weigh_operator(rng, params, COOLED_PALLETS, READY_PALLETS, weigh_busy))
    rng.process(pallet_feeder(rng, params, READY_PALLETS, WEIGHED_Q))
    rng.process(induction_heater(rng, params, WEIGHED_Q, PRESS_IN_Q))
    rng.process(nosing_press(rng, params, PRESS_IN_Q, FINISHED_Q))
    rng.process(sink(rng, FINISHED_Q, OUTPUT_Q))

    rng.run(until=params.SIM_TIME)

    out = dict(asdict(params))
    out.update(kpi.ct)
    out["output_buffer_len"] = len(OUTPUT_Q.items)
    return out

# ----------------------------
# Run once (example)
# ----------------------------
results = build_and_run(P)
print("Parameters:", {k: v for k, v in asdict(P).items()})
print("\n--- Throughputs / Counts ---")
for k, v in results.items():
    if k not in asdict(P):
        print(f"{k:20s}: {v}")

# print("\n--- Recent event log (tail) ---")
# for row in list(kpi.log)[-25:]:
#     print(row)
    
print(f"\nFinished shells in OUTPUT buffer: {results['output_buffer_len']}")
if 'output_by_batch' in results:
    print("By batch:", results['output_by_batch'])
# Out:
# [   0.00] Arrive Pallet#1(n=42, tag=WOOD_IN)
# [   0.15] Shell#1(B1-U1) moved WOOD → METAL (to Pallet#2(n=1, tag=METAL_HEAT))
# [   0.30] Shell#2(B1-U2) moved WOOD → METAL (to Pallet#2(n=2, tag=METAL_HEAT))
# [   0.44] Shell#3(B1-U3) moved WOOD → METAL (to Pallet#2(n=3, tag=METAL_HEAT))
# [   0.59] Shell#4(B1-U4) moved WOOD → METAL (to Pallet#2(n=4, tag=METAL_HEAT))
# [   0.74] Shell#5(B1-U5) moved WOOD → METAL (to Pallet#2(n=5, tag=METAL_HEAT))
# [   0.89] Shell#6(B1-U6) moved WOOD → METAL (to Pallet#2(n=6, tag=METAL_HEAT))
# [   1.03] Shell#7(B1-U7) moved WOOD → METAL (to Pallet#2(n=7, tag=METAL_HEAT))
# [   1.18] Shell#8(B1-U8) moved WOOD → METAL (to Pallet#2(n=8, tag=METAL_HEAT))
# [   1.33] Shell#9(B1-U9) moved WOOD → METAL (to Pallet#2(n=9, tag=METAL_HEAT))
# [   1.48] Shell#10(B1-U10) moved WOOD → METAL (to Pallet#2(n=10, tag=METAL_HEAT))
# [   1.62] Shell#11(B1-U11) moved WOOD → METAL (to Pallet#2(n=11, tag=METAL_HEAT))
# [   1.77] Shell#12(B1-U12) moved WOOD → METAL (to Pallet#2(n=12, tag=METAL_HEAT))
# [   1.92] Shell#13(B1-U13) moved WOOD → METAL (to Pallet#2(n=13, tag=METAL_HEAT))
# [   2.07] Shell#14(B1-U14) moved WOOD → METAL (to Pallet#2(n=14, tag=METAL_HEAT))
# [   2.21] Shell#15(B1-U15) moved WOOD → METAL (to Pallet#2(n=15, tag=METAL_HEAT))
# [   2.36] Shell#16(B1-U16) moved WOOD → METAL (to Pallet#2(n=16, tag=METAL_HEAT))
# [   2.51] Shell#17(B1-U17) moved WOOD → METAL (to Pallet#2(n=17, tag=METAL_HEAT))
# [   2.66] Shell#18(B1-U18) moved WOOD → METAL (to Pallet#2(n=18, tag=METAL_HEAT))
# [   2.80] Shell#19(B1-U19) moved WOOD → METAL (to Pallet#2(n=19, tag=METAL_HEAT))
# [   2.95] Shell#20(B1-U20) moved WOOD → METAL (to Pallet#2(n=20, tag=METAL_HEAT))
# [   3.10] Shell#21(B1-U21) moved WOOD → METAL (to Pallet#2(n=21, tag=METAL_HEAT))
# [   3.25] Shell#22(B1-U22) moved WOOD → METAL (to Pallet#2(n=22, tag=METAL_HEAT))
# [   3.39] Shell#23(B1-U23) moved WOOD → METAL (to Pallet#2(n=23, tag=METAL_HEAT))
# [   3.54] Shell#24(B1-U24) moved WOOD → METAL (to Pallet#2(n=24, tag=METAL_HEAT))
# [   3.69] Shell#25(B1-U25) moved WOOD → METAL (to Pallet#2(n=25, tag=METAL_HEAT))
# [   3.84] Shell#26(B1-U26) moved WOOD → METAL (to Pallet#2(n=26, tag=METAL_HEAT))
# [   3.99] Shell#27(B1-U27) moved WOOD → METAL (to Pallet#2(n=27, tag=METAL_HEAT))
# [   4.13] Shell#28(B1-U28) moved WOOD → METAL (to Pallet#2(n=28, tag=METAL_HEAT))
# [   4.28] Shell#29(B1-U29) moved WOOD → METAL (to Pallet#2(n=29, tag=METAL_HEAT))
# [   4.43] Shell#30(B1-U30) moved WOOD → METAL (to Pallet#2(n=30, tag=METAL_HEAT))
# [   4.58] Shell#31(B1-U31) moved WOOD → METAL (to Pallet#2(n=31, tag=METAL_HEAT))
# [   4.72] Shell#32(B1-U32) moved WOOD → METAL (to Pallet#2(n=32, tag=METAL_HEAT))
# [   4.87] Shell#33(B1-U33) moved WOOD → METAL (to Pallet#2(n=33, tag=METAL_HEAT))
# [   5.02] Shell#34(B1-U34) moved WOOD → METAL (to Pallet#2(n=34, tag=METAL_HEAT))
# [   5.17] Shell#35(B1-U35) moved WOOD → METAL (to Pallet#2(n=35, tag=METAL_HEAT))
# [   5.31] Shell#36(B1-U36) moved WOOD → METAL (to Pallet#2(n=36, tag=METAL_HEAT))
# [   5.46] Shell#37(B1-U37) moved WOOD → METAL (to Pallet#2(n=37, tag=METAL_HEAT))
# [   5.61] Shell#38(B1-U38) moved WOOD → METAL (to Pallet#2(n=38, tag=METAL_HEAT))
# [   5.76] Shell#39(B1-U39) moved WOOD → METAL (to Pallet#2(n=39, tag=METAL_HEAT))
# [   5.90] Shell#40(B1-U40) moved WOOD → METAL (to Pallet#2(n=40, tag=METAL_HEAT))
# [   6.05] Shell#41(B1-U41) moved WOOD → METAL (to Pallet#2(n=41, tag=METAL_HEAT))
# [   6.20] Shell#42(B1-U42) moved WOOD → METAL (to Pallet#2(n=42, tag=METAL_HEAT))
# [   6.20] Transferred -> Pallet#2(n=42, tag=METAL_HEAT) (reserved heat slot)
# [   6.20] Torch start Pallet#2(n=42, tag=METAL_HEAT)
# [  66.20] Torch done  Pallet#2(n=42, tag=METAL_HEAT)
# [  66.20] Graphite start on Pallet#2(n=42, tag=METAL_HEAT)
# [  66.20] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  67.89] Shell#1(B1-U1) graphite done
# [  67.89] Shell#2(B1-U2) graphite done
# [  67.89] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  69.58] Shell#3(B1-U3) graphite done
# [  69.58] Shell#4(B1-U4) graphite done
# [  69.58] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  71.27] Shell#5(B1-U5) graphite done
# [  71.27] Shell#6(B1-U6) graphite done
# [  71.27] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  72.96] Shell#7(B1-U7) graphite done
# [  72.96] Shell#8(B1-U8) graphite done
# [  72.96] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  74.66] Shell#9(B1-U9) graphite done
# [  74.66] Shell#10(B1-U10) graphite done
# [  74.66] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  76.35] Shell#11(B1-U11) graphite done
# [  76.35] Shell#12(B1-U12) graphite done
# [  76.35] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  78.04] Shell#13(B1-U13) graphite done
# [  78.04] Shell#14(B1-U14) graphite done
# [  78.04] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  79.73] Shell#15(B1-U15) graphite done
# [  79.73] Shell#16(B1-U16) graphite done
# [  79.73] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  81.42] Shell#17(B1-U17) graphite done
# [  81.42] Shell#18(B1-U18) graphite done
# [  81.42] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  83.11] Shell#19(B1-U19) graphite done
# [  83.11] Shell#20(B1-U20) graphite done
# [  83.11] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  84.80] Shell#21(B1-U21) graphite done
# [  84.80] Shell#22(B1-U22) graphite done
# [  84.80] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  86.49] Shell#23(B1-U23) graphite done
# [  86.49] Shell#24(B1-U24) graphite done
# [  86.49] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  88.19] Shell#25(B1-U25) graphite done
# [  88.19] Shell#26(B1-U26) graphite done
# [  88.19] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  89.88] Shell#27(B1-U27) graphite done
# [  89.88] Shell#28(B1-U28) graphite done
# [  89.88] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  91.57] Shell#29(B1-U29) graphite done
# [  91.57] Shell#30(B1-U30) graphite done
# [  91.57] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  93.26] Shell#31(B1-U31) graphite done
# [  93.26] Shell#32(B1-U32) graphite done
# [  93.26] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  94.95] Shell#33(B1-U33) graphite done
# [  94.95] Shell#34(B1-U34) graphite done
# [  94.95] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  96.64] Shell#35(B1-U35) graphite done
# [  96.64] Shell#36(B1-U36) graphite done
# [  96.64] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [  98.33] Shell#37(B1-U37) graphite done
# [  98.33] Shell#38(B1-U38) graphite done
# [  98.33] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [ 100.03] Shell#39(B1-U39) graphite done
# [ 100.03] Shell#40(B1-U40) graphite done
# [ 100.03] Graphite wave start (2/2) on Pallet#2(n=42, tag=METAL_HEAT)
# [ 101.72] Shell#41(B1-U41) graphite done
# [ 101.72] Shell#42(B1-U42) graphite done
# [ 101.72] Graphite done  on Pallet#2(n=42, tag=METAL_HEAT)
# [ 140.00] Arrive Pallet#3(n=42, tag=WOOD_IN)
# [ 140.15] Shell#43(B3-U1) moved WOOD → METAL (to Pallet#4(n=1, tag=METAL_HEAT))
# [ 140.30] Shell#44(B3-U2) moved WOOD → METAL (to Pallet#4(n=2, tag=METAL_HEAT))
# [ 140.44] Shell#45(B3-U3) moved WOOD → METAL (to Pallet#4(n=3, tag=METAL_HEAT))
# [ 140.59] Shell#46(B3-U4) moved WOOD → METAL (to Pallet#4(n=4, tag=METAL_HEAT))
# [ 140.74] Shell#47(B3-U5) moved WOOD → METAL (to Pallet#4(n=5, tag=METAL_HEAT))
# [ 140.89] Shell#48(B3-U6) moved WOOD → METAL (to Pallet#4(n=6, tag=METAL_HEAT))
# [ 141.03] Shell#49(B3-U7) moved WOOD → METAL (to Pallet#4(n=7, tag=METAL_HEAT))
# [ 141.18] Shell#50(B3-U8) moved WOOD → METAL (to Pallet#4(n=8, tag=METAL_HEAT))
# [ 141.33] Shell#51(B3-U9) moved WOOD → METAL (to Pallet#4(n=9, tag=METAL_HEAT))
# [ 141.48] Shell#52(B3-U10) moved WOOD → METAL (to Pallet#4(n=10, tag=METAL_HEAT))
# [ 141.62] Shell#53(B3-U11) moved WOOD → METAL (to Pallet#4(n=11, tag=METAL_HEAT))
# [ 141.77] Shell#54(B3-U12) moved WOOD → METAL (to Pallet#4(n=12, tag=METAL_HEAT))
# [ 141.92] Shell#55(B3-U13) moved WOOD → METAL (to Pallet#4(n=13, tag=METAL_HEAT))
# [ 142.07] Shell#56(B3-U14) moved WOOD → METAL (to Pallet#4(n=14, tag=METAL_HEAT))
# [ 142.21] Shell#57(B3-U15) moved WOOD → METAL (to Pallet#4(n=15, tag=METAL_HEAT))
# [ 142.36] Shell#58(B3-U16) moved WOOD → METAL (to Pallet#4(n=16, tag=METAL_HEAT))
# [ 142.51] Shell#59(B3-U17) moved WOOD → METAL (to Pallet#4(n=17, tag=METAL_HEAT))
# [ 142.66] Shell#60(B3-U18) moved WOOD → METAL (to Pallet#4(n=18, tag=METAL_HEAT))
# [ 142.80] Shell#61(B3-U19) moved WOOD → METAL (to Pallet#4(n=19, tag=METAL_HEAT))
# [ 142.95] Shell#62(B3-U20) moved WOOD → METAL (to Pallet#4(n=20, tag=METAL_HEAT))
# [ 143.10] Shell#63(B3-U21) moved WOOD → METAL (to Pallet#4(n=21, tag=METAL_HEAT))
# [ 143.25] Shell#64(B3-U22) moved WOOD → METAL (to Pallet#4(n=22, tag=METAL_HEAT))
# [ 143.39] Shell#65(B3-U23) moved WOOD → METAL (to Pallet#4(n=23, tag=METAL_HEAT))
# [ 143.54] Shell#66(B3-U24) moved WOOD → METAL (to Pallet#4(n=24, tag=METAL_HEAT))
# [ 143.69] Shell#67(B3-U25) moved WOOD → METAL (to Pallet#4(n=25, tag=METAL_HEAT))
# [ 143.84] Shell#68(B3-U26) moved WOOD → METAL (to Pallet#4(n=26, tag=METAL_HEAT))
# [ 143.99] Shell#69(B3-U27) moved WOOD → METAL (to Pallet#4(n=27, tag=METAL_HEAT))
# [ 144.13] Shell#70(B3-U28) moved WOOD → METAL (to Pallet#4(n=28, tag=METAL_HEAT))
# [ 144.28] Shell#71(B3-U29) moved WOOD → METAL (to Pallet#4(n=29, tag=METAL_HEAT))
# [ 144.43] Shell#72(B3-U30) moved WOOD → METAL (to Pallet#4(n=30, tag=METAL_HEAT))
# [ 144.58] Shell#73(B3-U31) moved WOOD → METAL (to Pallet#4(n=31, tag=METAL_HEAT))
# [ 144.72] Shell#74(B3-U32) moved WOOD → METAL (to Pallet#4(n=32, tag=METAL_HEAT))
# [ 144.87] Shell#75(B3-U33) moved WOOD → METAL (to Pallet#4(n=33, tag=METAL_HEAT))
# [ 145.02] Shell#76(B3-U34) moved WOOD → METAL (to Pallet#4(n=34, tag=METAL_HEAT))
# [ 145.17] Shell#77(B3-U35) moved WOOD → METAL (to Pallet#4(n=35, tag=METAL_HEAT))
# [ 145.31] Shell#78(B3-U36) moved WOOD → METAL (to Pallet#4(n=36, tag=METAL_HEAT))
# [ 145.46] Shell#79(B3-U37) moved WOOD → METAL (to Pallet#4(n=37, tag=METAL_HEAT))
# [ 145.61] Shell#80(B3-U38) moved WOOD → METAL (to Pallet#4(n=38, tag=METAL_HEAT))
# [ 145.76] Shell#81(B3-U39) moved WOOD → METAL (to Pallet#4(n=39, tag=METAL_HEAT))
# [ 145.90] Shell#82(B3-U40) moved WOOD → METAL (to Pallet#4(n=40, tag=METAL_HEAT))
# [ 146.05] Shell#83(B3-U41) moved WOOD → METAL (to Pallet#4(n=41, tag=METAL_HEAT))
# [ 146.20] Shell#84(B3-U42) moved WOOD → METAL (to Pallet#4(n=42, tag=METAL_HEAT))
# [ 146.20] Transferred -> Pallet#4(n=42, tag=METAL_HEAT) (reserved heat slot)
# [ 146.20] Torch start Pallet#4(n=42, tag=METAL_HEAT)
# [ 158.89] Pallet cooled Pallet#2(n=42, tag=WOOD_COOL)
# [ 158.89] Weigh start  Pallet#2(n=42, tag=WOOD_COOL)
# [ 159.36] Shell#1(B1-U1) weighed/classified → staged (pallet assembly 1/42)
# [ 159.83] Shell#2(B1-U2) weighed/classified → staged (pallet assembly 2/42)
# [ 160.30] Shell#3(B1-U3) weighed/classified → staged (pallet assembly 3/42)
# [ 160.77] Shell#4(B1-U4) weighed/classified → staged (pallet assembly 4/42)
# [ 161.25] Shell#5(B1-U5) weighed/classified → staged (pallet assembly 5/42)
# [ 161.72] Shell#6(B1-U6) weighed/classified → staged (pallet assembly 6/42)
# [ 162.19] Shell#7(B1-U7) weighed/classified → staged (pallet assembly 7/42)
# [ 162.66] Shell#8(B1-U8) weighed/classified → staged (pallet assembly 8/42)
# [ 163.13] Shell#9(B1-U9) weighed/classified → staged (pallet assembly 9/42)
# [ 163.61] Shell#10(B1-U10) weighed/classified → staged (pallet assembly 10/42)
# [ 164.08] Shell#11(B1-U11) weighed/classified → staged (pallet assembly 11/42)
# [ 164.55] Shell#12(B1-U12) weighed/classified → staged (pallet assembly 12/42)
# [ 165.02] Shell#13(B1-U13) weighed/classified → staged (pallet assembly 13/42)
# [ 165.49] Shell#14(B1-U14) weighed/classified → staged (pallet assembly 14/42)
# [ 165.97] Shell#15(B1-U15) weighed/classified → staged (pallet assembly 15/42)
# [ 166.44] Shell#16(B1-U16) weighed/classified → staged (pallet assembly 16/42)
# [ 166.91] Shell#17(B1-U17) weighed/classified → staged (pallet assembly 17/42)
# [ 167.38] Shell#18(B1-U18) weighed/classified → staged (pallet assembly 18/42)
# [ 167.85] Shell#19(B1-U19) weighed/classified → staged (pallet assembly 19/42)
# [ 168.32] Shell#20(B1-U20) weighed/classified → staged (pallet assembly 20/42)
# [ 168.80] Shell#21(B1-U21) weighed/classified → staged (pallet assembly 21/42)
# [ 169.27] Shell#22(B1-U22) weighed/classified → staged (pallet assembly 22/42)
# [ 169.74] Shell#23(B1-U23) weighed/classified → staged (pallet assembly 23/42)
# [ 170.21] Shell#24(B1-U24) weighed/classified → staged (pallet assembly 24/42)
# [ 170.68] Shell#25(B1-U25) weighed/classified → staged (pallet assembly 25/42)
# [ 171.16] Shell#26(B1-U26) weighed/classified → staged (pallet assembly 26/42)
# [ 171.63] Shell#27(B1-U27) weighed/classified → staged (pallet assembly 27/42)
# [ 172.10] Shell#28(B1-U28) weighed/classified → staged (pallet assembly 28/42)
# [ 172.57] Shell#29(B1-U29) weighed/classified → staged (pallet assembly 29/42)
# [ 173.04] Shell#30(B1-U30) weighed/classified → staged (pallet assembly 30/42)
# [ 173.52] Shell#31(B1-U31) weighed/classified → staged (pallet assembly 31/42)
# [ 173.99] Shell#32(B1-U32) weighed/classified → staged (pallet assembly 32/42)
# [ 174.46] Shell#33(B1-U33) weighed/classified → staged (pallet assembly 33/42)
# [ 174.93] Shell#34(B1-U34) weighed/classified → staged (pallet assembly 34/42)
# [ 175.40] Shell#35(B1-U35) weighed/classified → staged (pallet assembly 35/42)
# [ 175.87] Shell#36(B1-U36) weighed/classified → staged (pallet assembly 36/42)
# [ 176.35] Shell#37(B1-U37) weighed/classified → staged (pallet assembly 37/42)
# [ 176.82] Shell#38(B1-U38) weighed/classified → staged (pallet assembly 38/42)
# [ 177.29] Shell#39(B1-U39) weighed/classified → staged (pallet assembly 39/42)
# [ 177.76] Shell#40(B1-U40) weighed/classified → staged (pallet assembly 40/42)
# [ 178.23] Shell#41(B1-U41) weighed/classified → staged (pallet assembly 41/42)
# [ 178.71] Shell#42(B1-U42) weighed/classified → staged (pallet assembly 42/42)
# [ 178.71] Assembled FULL pallet → Pallet#5(n=42, tag=WEIGHED_FULL) → READY_PALLETS
# [ 178.71] Weigh done   Pallet#2(n=42, tag=WOOD_COOL)
# [ 178.71] Feeder releasing from Pallet#5(n=42, tag=WEIGHED_FULL) → IH queue (one-by-one)
# [ 178.71] Shell#1(B1-U1) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] IH start Shell#1(B1-U1)
# [ 178.71] Shell#2(B1-U2) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#3(B1-U3) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#4(B1-U4) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#5(B1-U5) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#6(B1-U6) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#7(B1-U7) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#8(B1-U8) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#9(B1-U9) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#10(B1-U10) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#11(B1-U11) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#12(B1-U12) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#13(B1-U13) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#14(B1-U14) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#15(B1-U15) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#16(B1-U16) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#17(B1-U17) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#18(B1-U18) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#19(B1-U19) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#20(B1-U20) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#21(B1-U21) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#22(B1-U22) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#23(B1-U23) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#24(B1-U24) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#25(B1-U25) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#26(B1-U26) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#27(B1-U27) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#28(B1-U28) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#29(B1-U29) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#30(B1-U30) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#31(B1-U31) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#32(B1-U32) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#33(B1-U33) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#34(B1-U34) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#35(B1-U35) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#36(B1-U36) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#37(B1-U37) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#38(B1-U38) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#39(B1-U39) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#40(B1-U40) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#41(B1-U41) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 178.71] Shell#42(B1-U42) → IH queue (from Pallet#5(n=42, tag=WEIGHED_FULL))
# [ 180.57] IH done  Shell#1(B1-U1) → Press queue
# [ 180.57] IH start Shell#2(B1-U2)
# [ 180.57] Press start Shell#1(B1-U1)
# [ 181.09] Press done  Shell#1(B1-U1) → Finished
# [ 181.09] COMPLETED Shell#1(B1-U1) → OUTPUT_Q
# [ 182.44] IH done  Shell#2(B1-U2) → Press queue
# [ 182.44] IH start Shell#3(B1-U3)
# [ 182.44] Press start Shell#2(B1-U2)
# [ 182.96] Press done  Shell#2(B1-U2) → Finished
# [ 182.96] COMPLETED Shell#2(B1-U2) → OUTPUT_Q
# [ 184.31] IH done  Shell#3(B1-U3) → Press queue
# [ 184.31] IH start Shell#4(B1-U4)
# [ 184.31] Press start Shell#3(B1-U3)
# [ 184.82] Press done  Shell#3(B1-U3) → Finished
# [ 184.82] COMPLETED Shell#3(B1-U3) → OUTPUT_Q
# [ 186.17] IH done  Shell#4(B1-U4) → Press queue
# [ 186.17] IH start Shell#5(B1-U5)
# [ 186.17] Press start Shell#4(B1-U4)
# [ 186.69] Press done  Shell#4(B1-U4) → Finished
# [ 186.69] COMPLETED Shell#4(B1-U4) → OUTPUT_Q
# [ 188.04] IH done  Shell#5(B1-U5) → Press queue
# [ 188.04] IH start Shell#6(B1-U6)
# [ 188.04] Press start Shell#5(B1-U5)
# [ 188.56] Press done  Shell#5(B1-U5) → Finished
# [ 188.56] COMPLETED Shell#5(B1-U5) → OUTPUT_Q
# [ 189.91] IH done  Shell#6(B1-U6) → Press queue
# [ 189.91] IH start Shell#7(B1-U7)
# [ 189.91] Press start Shell#6(B1-U6)
# [ 190.42] Press done  Shell#6(B1-U6) → Finished
# [ 190.42] COMPLETED Shell#6(B1-U6) → OUTPUT_Q
# [ 191.77] IH done  Shell#7(B1-U7) → Press queue
# [ 191.77] IH start Shell#8(B1-U8)
# [ 191.77] Press start Shell#7(B1-U7)
# [ 192.29] Press done  Shell#7(B1-U7) → Finished
# [ 192.29] COMPLETED Shell#7(B1-U7) → OUTPUT_Q
# [ 193.64] IH done  Shell#8(B1-U8) → Press queue
# [ 193.64] IH start Shell#9(B1-U9)
# [ 193.64] Press start Shell#8(B1-U8)
# [ 194.16] Press done  Shell#8(B1-U8) → Finished
# [ 194.16] COMPLETED Shell#8(B1-U8) → OUTPUT_Q
# [ 195.51] IH done  Shell#9(B1-U9) → Press queue
# [ 195.51] IH start Shell#10(B1-U10)
# [ 195.51] Press start Shell#9(B1-U9)
# [ 196.02] Press done  Shell#9(B1-U9) → Finished
# [ 196.02] COMPLETED Shell#9(B1-U9) → OUTPUT_Q
# [ 197.37] IH done  Shell#10(B1-U10) → Press queue
# [ 197.37] IH start Shell#11(B1-U11)
# [ 197.37] Press start Shell#10(B1-U10)
# [ 197.89] Press done  Shell#10(B1-U10) → Finished
# [ 197.89] COMPLETED Shell#10(B1-U10) → OUTPUT_Q
# [ 199.24] IH done  Shell#11(B1-U11) → Press queue
# [ 199.24] IH start Shell#12(B1-U12)
# [ 199.24] Press start Shell#11(B1-U11)
# [ 199.76] Press done  Shell#11(B1-U11) → Finished
# [ 199.76] COMPLETED Shell#11(B1-U11) → OUTPUT_Q
# [ 201.11] IH done  Shell#12(B1-U12) → Press queue
# [ 201.11] IH start Shell#13(B1-U13)
# [ 201.11] Press start Shell#12(B1-U12)
# [ 201.62] Press done  Shell#12(B1-U12) → Finished
# [ 201.62] COMPLETED Shell#12(B1-U12) → OUTPUT_Q
# [ 202.97] IH done  Shell#13(B1-U13) → Press queue
# [ 202.97] IH start Shell#14(B1-U14)
# [ 202.97] Press start Shell#13(B1-U13)
# [ 203.49] Press done  Shell#13(B1-U13) → Finished
# [ 203.49] COMPLETED Shell#13(B1-U13) → OUTPUT_Q
# [ 204.84] IH done  Shell#14(B1-U14) → Press queue
# [ 204.84] IH start Shell#15(B1-U15)
# [ 204.84] Press start Shell#14(B1-U14)
# [ 205.36] Press done  Shell#14(B1-U14) → Finished
# [ 205.36] COMPLETED Shell#14(B1-U14) → OUTPUT_Q
# [ 206.20] Torch done  Pallet#4(n=42, tag=METAL_HEAT)
# [ 206.20] Graphite start on Pallet#4(n=42, tag=METAL_HEAT)
# [ 206.20] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 206.71] IH done  Shell#15(B1-U15) → Press queue
# [ 206.71] IH start Shell#16(B1-U16)
# [ 206.71] Press start Shell#15(B1-U15)
# [ 207.22] Press done  Shell#15(B1-U15) → Finished
# [ 207.22] COMPLETED Shell#15(B1-U15) → OUTPUT_Q
# [ 207.89] Shell#43(B3-U1) graphite done
# [ 207.89] Shell#44(B3-U2) graphite done
# [ 207.89] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 208.57] IH done  Shell#16(B1-U16) → Press queue
# [ 208.57] IH start Shell#17(B1-U17)
# [ 208.57] Press start Shell#16(B1-U16)
# [ 209.09] Press done  Shell#16(B1-U16) → Finished
# [ 209.09] COMPLETED Shell#16(B1-U16) → OUTPUT_Q
# [ 209.58] Shell#45(B3-U3) graphite done
# [ 209.58] Shell#46(B3-U4) graphite done
# [ 209.58] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 210.44] IH done  Shell#17(B1-U17) → Press queue
# [ 210.44] IH start Shell#18(B1-U18)
# [ 210.44] Press start Shell#17(B1-U17)
# [ 210.96] Press done  Shell#17(B1-U17) → Finished
# [ 210.96] COMPLETED Shell#17(B1-U17) → OUTPUT_Q
# [ 211.27] Shell#47(B3-U5) graphite done
# [ 211.27] Shell#48(B3-U6) graphite done
# [ 211.27] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 212.31] IH done  Shell#18(B1-U18) → Press queue
# [ 212.31] IH start Shell#19(B1-U19)
# [ 212.31] Press start Shell#18(B1-U18)
# [ 212.82] Press done  Shell#18(B1-U18) → Finished
# [ 212.82] COMPLETED Shell#18(B1-U18) → OUTPUT_Q
# [ 212.96] Shell#49(B3-U7) graphite done
# [ 212.96] Shell#50(B3-U8) graphite done
# [ 212.96] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 214.17] IH done  Shell#19(B1-U19) → Press queue
# [ 214.17] IH start Shell#20(B1-U20)
# [ 214.17] Press start Shell#19(B1-U19)
# [ 214.66] Shell#51(B3-U9) graphite done
# [ 214.66] Shell#52(B3-U10) graphite done
# [ 214.66] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 214.69] Press done  Shell#19(B1-U19) → Finished
# [ 214.69] COMPLETED Shell#19(B1-U19) → OUTPUT_Q
# [ 216.04] IH done  Shell#20(B1-U20) → Press queue
# [ 216.04] IH start Shell#21(B1-U21)
# [ 216.04] Press start Shell#20(B1-U20)
# [ 216.35] Shell#53(B3-U11) graphite done
# [ 216.35] Shell#54(B3-U12) graphite done
# [ 216.35] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 216.56] Press done  Shell#20(B1-U20) → Finished
# [ 216.56] COMPLETED Shell#20(B1-U20) → OUTPUT_Q
# [ 217.91] IH done  Shell#21(B1-U21) → Press queue
# [ 217.91] IH start Shell#22(B1-U22)
# [ 217.91] Press start Shell#21(B1-U21)
# [ 218.04] Shell#55(B3-U13) graphite done
# [ 218.04] Shell#56(B3-U14) graphite done
# [ 218.04] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 218.42] Press done  Shell#21(B1-U21) → Finished
# [ 218.42] COMPLETED Shell#21(B1-U21) → OUTPUT_Q
# [ 219.73] Shell#57(B3-U15) graphite done
# [ 219.73] Shell#58(B3-U16) graphite done
# [ 219.73] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 219.77] IH done  Shell#22(B1-U22) → Press queue
# [ 219.77] IH start Shell#23(B1-U23)
# [ 219.77] Press start Shell#22(B1-U22)
# [ 220.29] Press done  Shell#22(B1-U22) → Finished
# [ 220.29] COMPLETED Shell#22(B1-U22) → OUTPUT_Q
# [ 221.42] Shell#59(B3-U17) graphite done
# [ 221.42] Shell#60(B3-U18) graphite done
# [ 221.42] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 221.64] IH done  Shell#23(B1-U23) → Press queue
# [ 221.64] IH start Shell#24(B1-U24)
# [ 221.64] Press start Shell#23(B1-U23)
# [ 222.16] Press done  Shell#23(B1-U23) → Finished
# [ 222.16] COMPLETED Shell#23(B1-U23) → OUTPUT_Q
# [ 223.11] Shell#61(B3-U19) graphite done
# [ 223.11] Shell#62(B3-U20) graphite done
# [ 223.11] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 223.51] IH done  Shell#24(B1-U24) → Press queue
# [ 223.51] IH start Shell#25(B1-U25)
# [ 223.51] Press start Shell#24(B1-U24)
# [ 224.02] Press done  Shell#24(B1-U24) → Finished
# [ 224.02] COMPLETED Shell#24(B1-U24) → OUTPUT_Q
# [ 224.80] Shell#63(B3-U21) graphite done
# [ 224.80] Shell#64(B3-U22) graphite done
# [ 224.80] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 225.37] IH done  Shell#25(B1-U25) → Press queue
# [ 225.37] IH start Shell#26(B1-U26)
# [ 225.37] Press start Shell#25(B1-U25)
# [ 225.89] Press done  Shell#25(B1-U25) → Finished
# [ 225.89] COMPLETED Shell#25(B1-U25) → OUTPUT_Q
# [ 226.49] Shell#65(B3-U23) graphite done
# [ 226.49] Shell#66(B3-U24) graphite done
# [ 226.49] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 227.24] IH done  Shell#26(B1-U26) → Press queue
# [ 227.24] IH start Shell#27(B1-U27)
# [ 227.24] Press start Shell#26(B1-U26)
# [ 227.76] Press done  Shell#26(B1-U26) → Finished
# [ 227.76] COMPLETED Shell#26(B1-U26) → OUTPUT_Q
# [ 228.19] Shell#67(B3-U25) graphite done
# [ 228.19] Shell#68(B3-U26) graphite done
# [ 228.19] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 229.11] IH done  Shell#27(B1-U27) → Press queue
# [ 229.11] IH start Shell#28(B1-U28)
# [ 229.11] Press start Shell#27(B1-U27)
# [ 229.62] Press done  Shell#27(B1-U27) → Finished
# [ 229.62] COMPLETED Shell#27(B1-U27) → OUTPUT_Q
# [ 229.88] Shell#69(B3-U27) graphite done
# [ 229.88] Shell#70(B3-U28) graphite done
# [ 229.88] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 230.97] IH done  Shell#28(B1-U28) → Press queue
# [ 230.97] IH start Shell#29(B1-U29)
# [ 230.97] Press start Shell#28(B1-U28)
# [ 231.49] Press done  Shell#28(B1-U28) → Finished
# [ 231.49] COMPLETED Shell#28(B1-U28) → OUTPUT_Q
# [ 231.57] Shell#71(B3-U29) graphite done
# [ 231.57] Shell#72(B3-U30) graphite done
# [ 231.57] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 232.84] IH done  Shell#29(B1-U29) → Press queue
# [ 232.84] IH start Shell#30(B1-U30)
# [ 232.84] Press start Shell#29(B1-U29)
# [ 233.26] Shell#73(B3-U31) graphite done
# [ 233.26] Shell#74(B3-U32) graphite done
# [ 233.26] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 233.36] Press done  Shell#29(B1-U29) → Finished
# [ 233.36] COMPLETED Shell#29(B1-U29) → OUTPUT_Q
# [ 234.71] IH done  Shell#30(B1-U30) → Press queue
# [ 234.71] IH start Shell#31(B1-U31)
# [ 234.71] Press start Shell#30(B1-U30)
# [ 234.95] Shell#75(B3-U33) graphite done
# [ 234.95] Shell#76(B3-U34) graphite done
# [ 234.95] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 235.22] Press done  Shell#30(B1-U30) → Finished
# [ 235.22] COMPLETED Shell#30(B1-U30) → OUTPUT_Q
# [ 236.57] IH done  Shell#31(B1-U31) → Press queue
# [ 236.57] IH start Shell#32(B1-U32)
# [ 236.57] Press start Shell#31(B1-U31)
# [ 236.64] Shell#77(B3-U35) graphite done
# [ 236.64] Shell#78(B3-U36) graphite done
# [ 236.64] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 237.09] Press done  Shell#31(B1-U31) → Finished
# [ 237.09] COMPLETED Shell#31(B1-U31) → OUTPUT_Q
# [ 238.33] Shell#79(B3-U37) graphite done
# [ 238.33] Shell#80(B3-U38) graphite done
# [ 238.33] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 238.44] IH done  Shell#32(B1-U32) → Press queue
# [ 238.44] IH start Shell#33(B1-U33)
# [ 238.44] Press start Shell#32(B1-U32)
# [ 238.96] Press done  Shell#32(B1-U32) → Finished
# [ 238.96] COMPLETED Shell#32(B1-U32) → OUTPUT_Q
# [ 240.03] Shell#81(B3-U39) graphite done
# [ 240.03] Shell#82(B3-U40) graphite done
# [ 240.03] Graphite wave start (2/2) on Pallet#4(n=42, tag=METAL_HEAT)
# [ 240.31] IH done  Shell#33(B1-U33) → Press queue
# [ 240.31] IH start Shell#34(B1-U34)
# [ 240.31] Press start Shell#33(B1-U33)
# [ 240.82] Press done  Shell#33(B1-U33) → Finished
# [ 240.82] COMPLETED Shell#33(B1-U33) → OUTPUT_Q
# [ 241.72] Shell#83(B3-U41) graphite done
# [ 241.72] Shell#84(B3-U42) graphite done
# [ 241.72] Graphite done  on Pallet#4(n=42, tag=METAL_HEAT)
# [ 242.17] IH done  Shell#34(B1-U34) → Press queue
# [ 242.17] IH start Shell#35(B1-U35)
# [ 242.17] Press start Shell#34(B1-U34)
# [ 242.69] Press done  Shell#34(B1-U34) → Finished
# [ 242.69] COMPLETED Shell#34(B1-U34) → OUTPUT_Q
# [ 244.04] IH done  Shell#35(B1-U35) → Press queue
# [ 244.04] IH start Shell#36(B1-U36)
# [ 244.04] Press start Shell#35(B1-U35)
# [ 244.56] Press done  Shell#35(B1-U35) → Finished
# [ 244.56] COMPLETED Shell#35(B1-U35) → OUTPUT_Q
# [ 245.91] IH done  Shell#36(B1-U36) → Press queue
# [ 245.91] IH start Shell#37(B1-U37)
# [ 245.91] Press start Shell#36(B1-U36)
# [ 246.42] Press done  Shell#36(B1-U36) → Finished
# [ 246.42] COMPLETED Shell#36(B1-U36) → OUTPUT_Q
# [ 247.77] IH done  Shell#37(B1-U37) → Press queue
# [ 247.77] IH start Shell#38(B1-U38)
# [ 247.77] Press start Shell#37(B1-U37)
# [ 248.29] Press done  Shell#37(B1-U37) → Finished
# [ 248.29] COMPLETED Shell#37(B1-U37) → OUTPUT_Q
# [ 249.64] IH done  Shell#38(B1-U38) → Press queue
# [ 249.64] IH start Shell#39(B1-U39)
# [ 249.64] Press start Shell#38(B1-U38)
# [ 250.16] Press done  Shell#38(B1-U38) → Finished
# [ 250.16] COMPLETED Shell#38(B1-U38) → OUTPUT_Q
# [ 251.51] IH done  Shell#39(B1-U39) → Press queue
# [ 251.51] IH start Shell#40(B1-U40)
# [ 251.51] Press start Shell#39(B1-U39)
# [ 252.02] Press done  Shell#39(B1-U39) → Finished
# [ 252.02] COMPLETED Shell#39(B1-U39) → OUTPUT_Q
# [ 253.37] IH done  Shell#40(B1-U40) → Press queue
# [ 253.37] IH start Shell#41(B1-U41)
# [ 253.37] Press start Shell#40(B1-U40)
# [ 253.89] Press done  Shell#40(B1-U40) → Finished
# [ 253.89] COMPLETED Shell#40(B1-U40) → OUTPUT_Q
# [ 255.24] IH done  Shell#41(B1-U41) → Press queue
# [ 255.24] IH start Shell#42(B1-U42)
# [ 255.24] Press start Shell#41(B1-U41)
# [ 255.76] Press done  Shell#41(B1-U41) → Finished
# [ 255.76] COMPLETED Shell#41(B1-U41) → OUTPUT_Q
# [ 257.11] IH done  Shell#42(B1-U42) → Press queue
# [ 257.11] Press start Shell#42(B1-U42)
# [ 257.62] Press done  Shell#42(B1-U42) → Finished
# [ 257.62] COMPLETED Shell#42(B1-U42) → OUTPUT_Q
# [ 280.00] Arrive Pallet#6(n=42, tag=WOOD_IN)
# [ 280.15] Shell#85(B6-U1) moved WOOD → METAL (to Pallet#7(n=1, tag=METAL_HEAT))
# [ 280.30] Shell#86(B6-U2) moved WOOD → METAL (to Pallet#7(n=2, tag=METAL_HEAT))
# [ 280.44] Shell#87(B6-U3) moved WOOD → METAL (to Pallet#7(n=3, tag=METAL_HEAT))
# [ 280.59] Shell#88(B6-U4) moved WOOD → METAL (to Pallet#7(n=4, tag=METAL_HEAT))
# [ 280.74] Shell#89(B6-U5) moved WOOD → METAL (to Pallet#7(n=5, tag=METAL_HEAT))
# [ 280.89] Shell#90(B6-U6) moved WOOD → METAL (to Pallet#7(n=6, tag=METAL_HEAT))
# [ 281.03] Shell#91(B6-U7) moved WOOD → METAL (to Pallet#7(n=7, tag=METAL_HEAT))
# [ 281.18] Shell#92(B6-U8) moved WOOD → METAL (to Pallet#7(n=8, tag=METAL_HEAT))
# [ 281.33] Shell#93(B6-U9) moved WOOD → METAL (to Pallet#7(n=9, tag=METAL_HEAT))
# [ 281.48] Shell#94(B6-U10) moved WOOD → METAL (to Pallet#7(n=10, tag=METAL_HEAT))
# [ 281.62] Shell#95(B6-U11) moved WOOD → METAL (to Pallet#7(n=11, tag=METAL_HEAT))
# [ 281.77] Shell#96(B6-U12) moved WOOD → METAL (to Pallet#7(n=12, tag=METAL_HEAT))
# [ 281.92] Shell#97(B6-U13) moved WOOD → METAL (to Pallet#7(n=13, tag=METAL_HEAT))
# [ 282.07] Shell#98(B6-U14) moved WOOD → METAL (to Pallet#7(n=14, tag=METAL_HEAT))
# [ 282.21] Shell#99(B6-U15) moved WOOD → METAL (to Pallet#7(n=15, tag=METAL_HEAT))
# [ 282.36] Shell#100(B6-U16) moved WOOD → METAL (to Pallet#7(n=16, tag=METAL_HEAT))
# [ 282.51] Shell#101(B6-U17) moved WOOD → METAL (to Pallet#7(n=17, tag=METAL_HEAT))
# [ 282.66] Shell#102(B6-U18) moved WOOD → METAL (to Pallet#7(n=18, tag=METAL_HEAT))
# [ 282.80] Shell#103(B6-U19) moved WOOD → METAL (to Pallet#7(n=19, tag=METAL_HEAT))
# [ 282.95] Shell#104(B6-U20) moved WOOD → METAL (to Pallet#7(n=20, tag=METAL_HEAT))
# [ 283.10] Shell#105(B6-U21) moved WOOD → METAL (to Pallet#7(n=21, tag=METAL_HEAT))
# [ 283.25] Shell#106(B6-U22) moved WOOD → METAL (to Pallet#7(n=22, tag=METAL_HEAT))
# [ 283.39] Shell#107(B6-U23) moved WOOD → METAL (to Pallet#7(n=23, tag=METAL_HEAT))
# [ 283.54] Shell#108(B6-U24) moved WOOD → METAL (to Pallet#7(n=24, tag=METAL_HEAT))
# [ 283.69] Shell#109(B6-U25) moved WOOD → METAL (to Pallet#7(n=25, tag=METAL_HEAT))
# [ 283.84] Shell#110(B6-U26) moved WOOD → METAL (to Pallet#7(n=26, tag=METAL_HEAT))
# [ 283.99] Shell#111(B6-U27) moved WOOD → METAL (to Pallet#7(n=27, tag=METAL_HEAT))
# [ 284.13] Shell#112(B6-U28) moved WOOD → METAL (to Pallet#7(n=28, tag=METAL_HEAT))
# [ 284.28] Shell#113(B6-U29) moved WOOD → METAL (to Pallet#7(n=29, tag=METAL_HEAT))
# [ 284.43] Shell#114(B6-U30) moved WOOD → METAL (to Pallet#7(n=30, tag=METAL_HEAT))
# [ 284.58] Shell#115(B6-U31) moved WOOD → METAL (to Pallet#7(n=31, tag=METAL_HEAT))
# [ 284.72] Shell#116(B6-U32) moved WOOD → METAL (to Pallet#7(n=32, tag=METAL_HEAT))
# [ 284.87] Shell#117(B6-U33) moved WOOD → METAL (to Pallet#7(n=33, tag=METAL_HEAT))
# [ 285.02] Shell#118(B6-U34) moved WOOD → METAL (to Pallet#7(n=34, tag=METAL_HEAT))
# [ 285.17] Shell#119(B6-U35) moved WOOD → METAL (to Pallet#7(n=35, tag=METAL_HEAT))
# [ 285.31] Shell#120(B6-U36) moved WOOD → METAL (to Pallet#7(n=36, tag=METAL_HEAT))
# [ 285.46] Shell#121(B6-U37) moved WOOD → METAL (to Pallet#7(n=37, tag=METAL_HEAT))
# [ 285.61] Shell#122(B6-U38) moved WOOD → METAL (to Pallet#7(n=38, tag=METAL_HEAT))
# [ 285.76] Shell#123(B6-U39) moved WOOD → METAL (to Pallet#7(n=39, tag=METAL_HEAT))
# [ 285.90] Shell#124(B6-U40) moved WOOD → METAL (to Pallet#7(n=40, tag=METAL_HEAT))
# [ 286.05] Shell#125(B6-U41) moved WOOD → METAL (to Pallet#7(n=41, tag=METAL_HEAT))
# [ 286.20] Shell#126(B6-U42) moved WOOD → METAL (to Pallet#7(n=42, tag=METAL_HEAT))
# [ 286.20] Transferred -> Pallet#7(n=42, tag=METAL_HEAT) (reserved heat slot)
# [ 286.20] Torch start Pallet#7(n=42, tag=METAL_HEAT)
# [ 298.89] Pallet cooled Pallet#4(n=42, tag=WOOD_COOL)
# [ 298.89] Weigh start  Pallet#4(n=42, tag=WOOD_COOL)
# [ 299.36] Shell#43(B3-U1) weighed/classified → staged (pallet assembly 1/42)
# [ 299.83] Shell#44(B3-U2) weighed/classified → staged (pallet assembly 2/42)
# [ 300.30] Shell#45(B3-U3) weighed/classified → staged (pallet assembly 3/42)
# [ 300.77] Shell#46(B3-U4) weighed/classified → staged (pallet assembly 4/42)
# [ 301.25] Shell#47(B3-U5) weighed/classified → staged (pallet assembly 5/42)
# [ 301.72] Shell#48(B3-U6) weighed/classified → staged (pallet assembly 6/42)
# [ 302.19] Shell#49(B3-U7) weighed/classified → staged (pallet assembly 7/42)
# [ 302.66] Shell#50(B3-U8) weighed/classified → staged (pallet assembly 8/42)
# [ 303.13] Shell#51(B3-U9) weighed/classified → staged (pallet assembly 9/42)
# [ 303.61] Shell#52(B3-U10) weighed/classified → staged (pallet assembly 10/42)
# [ 304.08] Shell#53(B3-U11) weighed/classified → staged (pallet assembly 11/42)
# [ 304.55] Shell#54(B3-U12) weighed/classified → staged (pallet assembly 12/42)
# [ 305.02] Shell#55(B3-U13) weighed/classified → staged (pallet assembly 13/42)
# [ 305.49] Shell#56(B3-U14) weighed/classified → staged (pallet assembly 14/42)
# [ 305.97] Shell#57(B3-U15) weighed/classified → staged (pallet assembly 15/42)
# [ 306.44] Shell#58(B3-U16) weighed/classified → staged (pallet assembly 16/42)
# [ 306.91] Shell#59(B3-U17) weighed/classified → staged (pallet assembly 17/42)
# [ 307.38] Shell#60(B3-U18) weighed/classified → staged (pallet assembly 18/42)
# [ 307.85] Shell#61(B3-U19) weighed/classified → staged (pallet assembly 19/42)
# [ 308.32] Shell#62(B3-U20) weighed/classified → staged (pallet assembly 20/42)
# [ 308.80] Shell#63(B3-U21) weighed/classified → staged (pallet assembly 21/42)
# [ 309.27] Shell#64(B3-U22) weighed/classified → staged (pallet assembly 22/42)
# [ 309.74] Shell#65(B3-U23) weighed/classified → staged (pallet assembly 23/42)
# [ 310.21] Shell#66(B3-U24) weighed/classified → staged (pallet assembly 24/42)
# [ 310.68] Shell#67(B3-U25) weighed/classified → staged (pallet assembly 25/42)
# [ 311.16] Shell#68(B3-U26) weighed/classified → staged (pallet assembly 26/42)
# [ 311.63] Shell#69(B3-U27) weighed/classified → staged (pallet assembly 27/42)
# [ 312.10] Shell#70(B3-U28) weighed/classified → staged (pallet assembly 28/42)
# [ 312.57] Shell#71(B3-U29) weighed/classified → staged (pallet assembly 29/42)
# [ 313.04] Shell#72(B3-U30) weighed/classified → staged (pallet assembly 30/42)
# [ 313.52] Shell#73(B3-U31) weighed/classified → staged (pallet assembly 31/42)
# [ 313.99] Shell#74(B3-U32) weighed/classified → staged (pallet assembly 32/42)
# [ 314.46] Shell#75(B3-U33) weighed/classified → staged (pallet assembly 33/42)
# [ 314.93] Shell#76(B3-U34) weighed/classified → staged (pallet assembly 34/42)
# [ 315.40] Shell#77(B3-U35) weighed/classified → staged (pallet assembly 35/42)
# [ 315.87] Shell#78(B3-U36) weighed/classified → staged (pallet assembly 36/42)
# [ 316.35] Shell#79(B3-U37) weighed/classified → staged (pallet assembly 37/42)
# [ 316.82] Shell#80(B3-U38) weighed/classified → staged (pallet assembly 38/42)
# [ 317.29] Shell#81(B3-U39) weighed/classified → staged (pallet assembly 39/42)
# [ 317.76] Shell#82(B3-U40) weighed/classified → staged (pallet assembly 40/42)
# [ 318.23] Shell#83(B3-U41) weighed/classified → staged (pallet assembly 41/42)
# [ 318.71] Shell#84(B3-U42) weighed/classified → staged (pallet assembly 42/42)
# [ 318.71] Assembled FULL pallet → Pallet#8(n=42, tag=WEIGHED_FULL) → READY_PALLETS
# [ 318.71] Weigh done   Pallet#4(n=42, tag=WOOD_COOL)
# [ 318.71] Feeder releasing from Pallet#8(n=42, tag=WEIGHED_FULL) → IH queue (one-by-one)
# [ 318.71] Shell#43(B3-U1) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] IH start Shell#43(B3-U1)
# [ 318.71] Shell#44(B3-U2) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#45(B3-U3) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#46(B3-U4) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#47(B3-U5) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#48(B3-U6) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#49(B3-U7) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#50(B3-U8) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#51(B3-U9) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#52(B3-U10) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#53(B3-U11) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#54(B3-U12) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#55(B3-U13) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#56(B3-U14) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#57(B3-U15) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#58(B3-U16) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#59(B3-U17) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#60(B3-U18) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#61(B3-U19) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#62(B3-U20) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#63(B3-U21) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#64(B3-U22) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#65(B3-U23) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#66(B3-U24) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#67(B3-U25) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#68(B3-U26) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#69(B3-U27) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#70(B3-U28) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#71(B3-U29) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#72(B3-U30) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#73(B3-U31) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#74(B3-U32) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#75(B3-U33) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#76(B3-U34) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#77(B3-U35) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#78(B3-U36) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#79(B3-U37) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#80(B3-U38) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#81(B3-U39) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#82(B3-U40) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#83(B3-U41) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 318.71] Shell#84(B3-U42) → IH queue (from Pallet#8(n=42, tag=WEIGHED_FULL))
# [ 320.57] IH done  Shell#43(B3-U1) → Press queue
# [ 320.57] IH start Shell#44(B3-U2)
# [ 320.57] Press start Shell#43(B3-U1)
# [ 321.09] Press done  Shell#43(B3-U1) → Finished
# [ 321.09] COMPLETED Shell#43(B3-U1) → OUTPUT_Q
# [ 322.44] IH done  Shell#44(B3-U2) → Press queue
# [ 322.44] IH start Shell#45(B3-U3)
# [ 322.44] Press start Shell#44(B3-U2)
# [ 322.96] Press done  Shell#44(B3-U2) → Finished
# [ 322.96] COMPLETED Shell#44(B3-U2) → OUTPUT_Q
# [ 324.31] IH done  Shell#45(B3-U3) → Press queue
# [ 324.31] IH start Shell#46(B3-U4)
# [ 324.31] Press start Shell#45(B3-U3)
# [ 324.82] Press done  Shell#45(B3-U3) → Finished
# [ 324.82] COMPLETED Shell#45(B3-U3) → OUTPUT_Q
# [ 326.17] IH done  Shell#46(B3-U4) → Press queue
# [ 326.17] IH start Shell#47(B3-U5)
# [ 326.17] Press start Shell#46(B3-U4)
# [ 326.69] Press done  Shell#46(B3-U4) → Finished
# [ 326.69] COMPLETED Shell#46(B3-U4) → OUTPUT_Q
# [ 328.04] IH done  Shell#47(B3-U5) → Press queue
# [ 328.04] IH start Shell#48(B3-U6)
# [ 328.04] Press start Shell#47(B3-U5)
# [ 328.56] Press done  Shell#47(B3-U5) → Finished
# [ 328.56] COMPLETED Shell#47(B3-U5) → OUTPUT_Q
# [ 329.91] IH done  Shell#48(B3-U6) → Press queue
# [ 329.91] IH start Shell#49(B3-U7)
# [ 329.91] Press start Shell#48(B3-U6)
# [ 330.42] Press done  Shell#48(B3-U6) → Finished
# [ 330.42] COMPLETED Shell#48(B3-U6) → OUTPUT_Q
# [ 331.77] IH done  Shell#49(B3-U7) → Press queue
# [ 331.77] IH start Shell#50(B3-U8)
# [ 331.77] Press start Shell#49(B3-U7)
# [ 332.29] Press done  Shell#49(B3-U7) → Finished
# [ 332.29] COMPLETED Shell#49(B3-U7) → OUTPUT_Q
# [ 333.64] IH done  Shell#50(B3-U8) → Press queue
# [ 333.64] IH start Shell#51(B3-U9)
# [ 333.64] Press start Shell#50(B3-U8)
# [ 334.16] Press done  Shell#50(B3-U8) → Finished
# [ 334.16] COMPLETED Shell#50(B3-U8) → OUTPUT_Q
# [ 335.51] IH done  Shell#51(B3-U9) → Press queue
# [ 335.51] IH start Shell#52(B3-U10)
# [ 335.51] Press start Shell#51(B3-U9)
# [ 336.02] Press done  Shell#51(B3-U9) → Finished
# [ 336.02] COMPLETED Shell#51(B3-U9) → OUTPUT_Q
# [ 337.37] IH done  Shell#52(B3-U10) → Press queue
# [ 337.37] IH start Shell#53(B3-U11)
# [ 337.37] Press start Shell#52(B3-U10)
# [ 337.89] Press done  Shell#52(B3-U10) → Finished
# [ 337.89] COMPLETED Shell#52(B3-U10) → OUTPUT_Q
# [ 339.24] IH done  Shell#53(B3-U11) → Press queue
# [ 339.24] IH start Shell#54(B3-U12)
# [ 339.24] Press start Shell#53(B3-U11)
# [ 339.76] Press done  Shell#53(B3-U11) → Finished
# [ 339.76] COMPLETED Shell#53(B3-U11) → OUTPUT_Q
# [ 341.11] IH done  Shell#54(B3-U12) → Press queue
# [ 341.11] IH start Shell#55(B3-U13)
# [ 341.11] Press start Shell#54(B3-U12)
# [ 341.62] Press done  Shell#54(B3-U12) → Finished
# [ 341.62] COMPLETED Shell#54(B3-U12) → OUTPUT_Q
# [ 342.97] IH done  Shell#55(B3-U13) → Press queue
# [ 342.97] IH start Shell#56(B3-U14)
# [ 342.97] Press start Shell#55(B3-U13)
# [ 343.49] Press done  Shell#55(B3-U13) → Finished
# [ 343.49] COMPLETED Shell#55(B3-U13) → OUTPUT_Q
# [ 344.84] IH done  Shell#56(B3-U14) → Press queue
# [ 344.84] IH start Shell#57(B3-U15)
# [ 344.84] Press start Shell#56(B3-U14)
# [ 345.36] Press done  Shell#56(B3-U14) → Finished
# [ 345.36] COMPLETED Shell#56(B3-U14) → OUTPUT_Q
# [ 346.20] Torch done  Pallet#7(n=42, tag=METAL_HEAT)
# [ 346.20] Graphite start on Pallet#7(n=42, tag=METAL_HEAT)
# [ 346.20] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 346.71] IH done  Shell#57(B3-U15) → Press queue
# [ 346.71] IH start Shell#58(B3-U16)
# [ 346.71] Press start Shell#57(B3-U15)
# [ 347.22] Press done  Shell#57(B3-U15) → Finished
# [ 347.22] COMPLETED Shell#57(B3-U15) → OUTPUT_Q
# [ 347.89] Shell#85(B6-U1) graphite done
# [ 347.89] Shell#86(B6-U2) graphite done
# [ 347.89] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 348.57] IH done  Shell#58(B3-U16) → Press queue
# [ 348.57] IH start Shell#59(B3-U17)
# [ 348.57] Press start Shell#58(B3-U16)
# [ 349.09] Press done  Shell#58(B3-U16) → Finished
# [ 349.09] COMPLETED Shell#58(B3-U16) → OUTPUT_Q
# [ 349.58] Shell#87(B6-U3) graphite done
# [ 349.58] Shell#88(B6-U4) graphite done
# [ 349.58] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 350.44] IH done  Shell#59(B3-U17) → Press queue
# [ 350.44] IH start Shell#60(B3-U18)
# [ 350.44] Press start Shell#59(B3-U17)
# [ 350.96] Press done  Shell#59(B3-U17) → Finished
# [ 350.96] COMPLETED Shell#59(B3-U17) → OUTPUT_Q
# [ 351.27] Shell#89(B6-U5) graphite done
# [ 351.27] Shell#90(B6-U6) graphite done
# [ 351.27] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 352.31] IH done  Shell#60(B3-U18) → Press queue
# [ 352.31] IH start Shell#61(B3-U19)
# [ 352.31] Press start Shell#60(B3-U18)
# [ 352.82] Press done  Shell#60(B3-U18) → Finished
# [ 352.82] COMPLETED Shell#60(B3-U18) → OUTPUT_Q
# [ 352.96] Shell#91(B6-U7) graphite done
# [ 352.96] Shell#92(B6-U8) graphite done
# [ 352.96] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 354.17] IH done  Shell#61(B3-U19) → Press queue
# [ 354.17] IH start Shell#62(B3-U20)
# [ 354.17] Press start Shell#61(B3-U19)
# [ 354.66] Shell#93(B6-U9) graphite done
# [ 354.66] Shell#94(B6-U10) graphite done
# [ 354.66] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 354.69] Press done  Shell#61(B3-U19) → Finished
# [ 354.69] COMPLETED Shell#61(B3-U19) → OUTPUT_Q
# [ 356.04] IH done  Shell#62(B3-U20) → Press queue
# [ 356.04] IH start Shell#63(B3-U21)
# [ 356.04] Press start Shell#62(B3-U20)
# [ 356.35] Shell#95(B6-U11) graphite done
# [ 356.35] Shell#96(B6-U12) graphite done
# [ 356.35] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 356.56] Press done  Shell#62(B3-U20) → Finished
# [ 356.56] COMPLETED Shell#62(B3-U20) → OUTPUT_Q
# [ 357.91] IH done  Shell#63(B3-U21) → Press queue
# [ 357.91] IH start Shell#64(B3-U22)
# [ 357.91] Press start Shell#63(B3-U21)
# [ 358.04] Shell#97(B6-U13) graphite done
# [ 358.04] Shell#98(B6-U14) graphite done
# [ 358.04] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 358.42] Press done  Shell#63(B3-U21) → Finished
# [ 358.42] COMPLETED Shell#63(B3-U21) → OUTPUT_Q
# [ 359.73] Shell#99(B6-U15) graphite done
# [ 359.73] Shell#100(B6-U16) graphite done
# [ 359.73] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 359.77] IH done  Shell#64(B3-U22) → Press queue
# [ 359.77] IH start Shell#65(B3-U23)
# [ 359.77] Press start Shell#64(B3-U22)
# [ 360.29] Press done  Shell#64(B3-U22) → Finished
# [ 360.29] COMPLETED Shell#64(B3-U22) → OUTPUT_Q
# [ 361.42] Shell#101(B6-U17) graphite done
# [ 361.42] Shell#102(B6-U18) graphite done
# [ 361.42] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 361.64] IH done  Shell#65(B3-U23) → Press queue
# [ 361.64] IH start Shell#66(B3-U24)
# [ 361.64] Press start Shell#65(B3-U23)
# [ 362.16] Press done  Shell#65(B3-U23) → Finished
# [ 362.16] COMPLETED Shell#65(B3-U23) → OUTPUT_Q
# [ 363.11] Shell#103(B6-U19) graphite done
# [ 363.11] Shell#104(B6-U20) graphite done
# [ 363.11] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 363.51] IH done  Shell#66(B3-U24) → Press queue
# [ 363.51] IH start Shell#67(B3-U25)
# [ 363.51] Press start Shell#66(B3-U24)
# [ 364.02] Press done  Shell#66(B3-U24) → Finished
# [ 364.02] COMPLETED Shell#66(B3-U24) → OUTPUT_Q
# [ 364.80] Shell#105(B6-U21) graphite done
# [ 364.80] Shell#106(B6-U22) graphite done
# [ 364.80] Graphite wave start (2/2) on Pallet#7(n=42, tag=METAL_HEAT)
# [ 365.37] IH done  Shell#67(B3-U25) → Press queue
# [ 365.37] IH start Shell#68(B3-U26)
# [ 365.37] Press start Shell#67(B3-U25)
# [ 365.89] Press done  Shell#67(B3-U25) → Finished
# [ 365.89] COMPLETED Shell#67(B3-U25) → OUTPUT_Q
# ...
# [ 591.63] Shell#153(B9-U27) weighed/classified → staged (pallet assembly 27/42)
# [ 592.10] Shell#154(B9-U28) weighed/classified → staged (pallet assembly 28/42)
# [ 592.57] Shell#155(B9-U29) weighed/classified → staged (pallet assembly 29/42)
# [ 593.04] Shell#156(B9-U30) weighed/classified → staged (pallet assembly 30/42)
# [ 593.52] Shell#157(B9-U31) weighed/classified → staged (pallet assembly 31/42)
# [ 593.99] Shell#158(B9-U32) weighed/classified → staged (pallet assembly 32/42)
# [ 594.46] Shell#159(B9-U33) weighed/classified → staged (pallet assembly 33/42)
# [ 594.93] Shell#160(B9-U34) weighed/classified → staged (pallet assembly 34/42)
# [ 595.40] Shell#161(B9-U35) weighed/classified → staged (pallet assembly 35/42)
# [ 595.87] Shell#162(B9-U36) weighed/classified → staged (pallet assembly 36/42)
# [ 596.35] Shell#163(B9-U37) weighed/classified → staged (pallet assembly 37/42)
# [ 596.82] Shell#164(B9-U38) weighed/classified → staged (pallet assembly 38/42)
# [ 597.29] Shell#165(B9-U39) weighed/classified → staged (pallet assembly 39/42)
# [ 597.76] Shell#166(B9-U40) weighed/classified → staged (pallet assembly 40/42)
# [ 598.23] Shell#167(B9-U41) weighed/classified → staged (pallet assembly 41/42)
# [ 598.71] Shell#168(B9-U42) weighed/classified → staged (pallet assembly 42/42)
# [ 598.71] Assembled FULL pallet → Pallet#14(n=42, tag=WEIGHED_FULL) → READY_PALLETS
# [ 598.71] Weigh done   Pallet#10(n=42, tag=WOOD_COOL)
# [ 598.71] Feeder releasing from Pallet#14(n=42, tag=WEIGHED_FULL) → IH queue (one-by-one)
# [ 598.71] Shell#127(B9-U1) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] IH start Shell#127(B9-U1)
# [ 598.71] Shell#128(B9-U2) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#129(B9-U3) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#130(B9-U4) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#131(B9-U5) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#132(B9-U6) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#133(B9-U7) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#134(B9-U8) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#135(B9-U9) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#136(B9-U10) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#137(B9-U11) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#138(B9-U12) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#139(B9-U13) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#140(B9-U14) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#141(B9-U15) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#142(B9-U16) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#143(B9-U17) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#144(B9-U18) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#145(B9-U19) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#146(B9-U20) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#147(B9-U21) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#148(B9-U22) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#149(B9-U23) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#150(B9-U24) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#151(B9-U25) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#152(B9-U26) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#153(B9-U27) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#154(B9-U28) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#155(B9-U29) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#156(B9-U30) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#157(B9-U31) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#158(B9-U32) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#159(B9-U33) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#160(B9-U34) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#161(B9-U35) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#162(B9-U36) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#163(B9-U37) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#164(B9-U38) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#165(B9-U39) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#166(B9-U40) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#167(B9-U41) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 598.71] Shell#168(B9-U42) → IH queue (from Pallet#14(n=42, tag=WEIGHED_FULL))
# [ 600.57] IH done  Shell#127(B9-U1) → Press queue
# [ 600.57] IH start Shell#128(B9-U2)
# [ 600.57] Press start Shell#127(B9-U1)
# [ 601.09] Press done  Shell#127(B9-U1) → Finished
# [ 601.09] COMPLETED Shell#127(B9-U1) → OUTPUT_Q
# [ 602.44] IH done  Shell#128(B9-U2) → Press queue
# [ 602.44] IH start Shell#129(B9-U3)
# [ 602.44] Press start Shell#128(B9-U2)
# [ 602.96] Press done  Shell#128(B9-U2) → Finished
# [ 602.96] COMPLETED Shell#128(B9-U2) → OUTPUT_Q
# [ 604.31] IH done  Shell#129(B9-U3) → Press queue
# [ 604.31] IH start Shell#130(B9-U4)
# [ 604.31] Press start Shell#129(B9-U3)
# [ 604.82] Press done  Shell#129(B9-U3) → Finished
# [ 604.82] COMPLETED Shell#129(B9-U3) → OUTPUT_Q
# [ 606.17] IH done  Shell#130(B9-U4) → Press queue
# [ 606.17] IH start Shell#131(B9-U5)
# [ 606.17] Press start Shell#130(B9-U4)
# [ 606.69] Press done  Shell#130(B9-U4) → Finished
# [ 606.69] COMPLETED Shell#130(B9-U4) → OUTPUT_Q
# [ 608.04] IH done  Shell#131(B9-U5) → Press queue
# [ 608.04] IH start Shell#132(B9-U6)
# [ 608.04] Press start Shell#131(B9-U5)
# [ 608.56] Press done  Shell#131(B9-U5) → Finished
# [ 608.56] COMPLETED Shell#131(B9-U5) → OUTPUT_Q
# [ 609.91] IH done  Shell#132(B9-U6) → Press queue
# [ 609.91] IH start Shell#133(B9-U7)
# [ 609.91] Press start Shell#132(B9-U6)
# [ 610.42] Press done  Shell#132(B9-U6) → Finished
# [ 610.42] COMPLETED Shell#132(B9-U6) → OUTPUT_Q
# [ 611.77] IH done  Shell#133(B9-U7) → Press queue
# [ 611.77] IH start Shell#134(B9-U8)
# [ 611.77] Press start Shell#133(B9-U7)
# [ 612.29] Press done  Shell#133(B9-U7) → Finished
# [ 612.29] COMPLETED Shell#133(B9-U7) → OUTPUT_Q
# [ 613.64] IH done  Shell#134(B9-U8) → Press queue
# [ 613.64] IH start Shell#135(B9-U9)
# [ 613.64] Press start Shell#134(B9-U8)
# [ 614.16] Press done  Shell#134(B9-U8) → Finished
# [ 614.16] COMPLETED Shell#134(B9-U8) → OUTPUT_Q
# [ 615.51] IH done  Shell#135(B9-U9) → Press queue
# [ 615.51] IH start Shell#136(B9-U10)
# [ 615.51] Press start Shell#135(B9-U9)
# [ 616.02] Press done  Shell#135(B9-U9) → Finished
# [ 616.02] COMPLETED Shell#135(B9-U9) → OUTPUT_Q
# [ 617.37] IH done  Shell#136(B9-U10) → Press queue
# [ 617.37] IH start Shell#137(B9-U11)
# [ 617.37] Press start Shell#136(B9-U10)
# [ 617.89] Press done  Shell#136(B9-U10) → Finished
# [ 617.89] COMPLETED Shell#136(B9-U10) → OUTPUT_Q
# [ 619.24] IH done  Shell#137(B9-U11) → Press queue
# [ 619.24] IH start Shell#138(B9-U12)
# [ 619.24] Press start Shell#137(B9-U11)
# [ 619.76] Press done  Shell#137(B9-U11) → Finished
# [ 619.76] COMPLETED Shell#137(B9-U11) → OUTPUT_Q
# [ 621.11] IH done  Shell#138(B9-U12) → Press queue
# [ 621.11] IH start Shell#139(B9-U13)
# [ 621.11] Press start Shell#138(B9-U12)
# [ 621.62] Press done  Shell#138(B9-U12) → Finished
# [ 621.62] COMPLETED Shell#138(B9-U12) → OUTPUT_Q
# [ 622.97] IH done  Shell#139(B9-U13) → Press queue
# [ 622.97] IH start Shell#140(B9-U14)
# [ 622.97] Press start Shell#139(B9-U13)
# [ 623.49] Press done  Shell#139(B9-U13) → Finished
# [ 623.49] COMPLETED Shell#139(B9-U13) → OUTPUT_Q
# [ 624.84] IH done  Shell#140(B9-U14) → Press queue
# [ 624.84] IH start Shell#141(B9-U15)
# [ 624.84] Press start Shell#140(B9-U14)
# [ 625.36] Press done  Shell#140(B9-U14) → Finished
# [ 625.36] COMPLETED Shell#140(B9-U14) → OUTPUT_Q
# [ 626.20] Torch done  Pallet#13(n=42, tag=METAL_HEAT)
# [ 626.20] Graphite start on Pallet#13(n=42, tag=METAL_HEAT)
# [ 626.20] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 626.71] IH done  Shell#141(B9-U15) → Press queue
# [ 626.71] IH start Shell#142(B9-U16)
# [ 626.71] Press start Shell#141(B9-U15)
# [ 627.22] Press done  Shell#141(B9-U15) → Finished
# [ 627.22] COMPLETED Shell#141(B9-U15) → OUTPUT_Q
# [ 627.89] Shell#169(B12-U1) graphite done
# [ 627.89] Shell#170(B12-U2) graphite done
# [ 627.89] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 628.57] IH done  Shell#142(B9-U16) → Press queue
# [ 628.57] IH start Shell#143(B9-U17)
# [ 628.57] Press start Shell#142(B9-U16)
# [ 629.09] Press done  Shell#142(B9-U16) → Finished
# [ 629.09] COMPLETED Shell#142(B9-U16) → OUTPUT_Q
# [ 629.58] Shell#171(B12-U3) graphite done
# [ 629.58] Shell#172(B12-U4) graphite done
# [ 629.58] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 630.44] IH done  Shell#143(B9-U17) → Press queue
# [ 630.44] IH start Shell#144(B9-U18)
# [ 630.44] Press start Shell#143(B9-U17)
# [ 630.96] Press done  Shell#143(B9-U17) → Finished
# [ 630.96] COMPLETED Shell#143(B9-U17) → OUTPUT_Q
# [ 631.27] Shell#173(B12-U5) graphite done
# [ 631.27] Shell#174(B12-U6) graphite done
# [ 631.27] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 632.31] IH done  Shell#144(B9-U18) → Press queue
# [ 632.31] IH start Shell#145(B9-U19)
# [ 632.31] Press start Shell#144(B9-U18)
# [ 632.82] Press done  Shell#144(B9-U18) → Finished
# [ 632.82] COMPLETED Shell#144(B9-U18) → OUTPUT_Q
# [ 632.96] Shell#175(B12-U7) graphite done
# [ 632.96] Shell#176(B12-U8) graphite done
# [ 632.96] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 634.17] IH done  Shell#145(B9-U19) → Press queue
# [ 634.17] IH start Shell#146(B9-U20)
# [ 634.17] Press start Shell#145(B9-U19)
# [ 634.66] Shell#177(B12-U9) graphite done
# [ 634.66] Shell#178(B12-U10) graphite done
# [ 634.66] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 634.69] Press done  Shell#145(B9-U19) → Finished
# [ 634.69] COMPLETED Shell#145(B9-U19) → OUTPUT_Q
# [ 636.04] IH done  Shell#146(B9-U20) → Press queue
# [ 636.04] IH start Shell#147(B9-U21)
# [ 636.04] Press start Shell#146(B9-U20)
# [ 636.35] Shell#179(B12-U11) graphite done
# [ 636.35] Shell#180(B12-U12) graphite done
# [ 636.35] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 636.56] Press done  Shell#146(B9-U20) → Finished
# [ 636.56] COMPLETED Shell#146(B9-U20) → OUTPUT_Q
# [ 637.91] IH done  Shell#147(B9-U21) → Press queue
# [ 637.91] IH start Shell#148(B9-U22)
# [ 637.91] Press start Shell#147(B9-U21)
# [ 638.04] Shell#181(B12-U13) graphite done
# [ 638.04] Shell#182(B12-U14) graphite done
# [ 638.04] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 638.42] Press done  Shell#147(B9-U21) → Finished
# [ 638.42] COMPLETED Shell#147(B9-U21) → OUTPUT_Q
# [ 639.73] Shell#183(B12-U15) graphite done
# [ 639.73] Shell#184(B12-U16) graphite done
# [ 639.73] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 639.77] IH done  Shell#148(B9-U22) → Press queue
# [ 639.77] IH start Shell#149(B9-U23)
# [ 639.77] Press start Shell#148(B9-U22)
# [ 640.29] Press done  Shell#148(B9-U22) → Finished
# [ 640.29] COMPLETED Shell#148(B9-U22) → OUTPUT_Q
# [ 641.42] Shell#185(B12-U17) graphite done
# [ 641.42] Shell#186(B12-U18) graphite done
# [ 641.42] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 641.64] IH done  Shell#149(B9-U23) → Press queue
# [ 641.64] IH start Shell#150(B9-U24)
# [ 641.64] Press start Shell#149(B9-U23)
# [ 642.16] Press done  Shell#149(B9-U23) → Finished
# [ 642.16] COMPLETED Shell#149(B9-U23) → OUTPUT_Q
# [ 643.11] Shell#187(B12-U19) graphite done
# [ 643.11] Shell#188(B12-U20) graphite done
# [ 643.11] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 643.51] IH done  Shell#150(B9-U24) → Press queue
# [ 643.51] IH start Shell#151(B9-U25)
# [ 643.51] Press start Shell#150(B9-U24)
# [ 644.02] Press done  Shell#150(B9-U24) → Finished
# [ 644.02] COMPLETED Shell#150(B9-U24) → OUTPUT_Q
# [ 644.80] Shell#189(B12-U21) graphite done
# [ 644.80] Shell#190(B12-U22) graphite done
# [ 644.80] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 645.37] IH done  Shell#151(B9-U25) → Press queue
# [ 645.37] IH start Shell#152(B9-U26)
# [ 645.37] Press start Shell#151(B9-U25)
# [ 645.89] Press done  Shell#151(B9-U25) → Finished
# [ 645.89] COMPLETED Shell#151(B9-U25) → OUTPUT_Q
# [ 646.49] Shell#191(B12-U23) graphite done
# [ 646.49] Shell#192(B12-U24) graphite done
# [ 646.49] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 647.24] IH done  Shell#152(B9-U26) → Press queue
# [ 647.24] IH start Shell#153(B9-U27)
# [ 647.24] Press start Shell#152(B9-U26)
# [ 647.76] Press done  Shell#152(B9-U26) → Finished
# [ 647.76] COMPLETED Shell#152(B9-U26) → OUTPUT_Q
# [ 648.19] Shell#193(B12-U25) graphite done
# [ 648.19] Shell#194(B12-U26) graphite done
# [ 648.19] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 649.11] IH done  Shell#153(B9-U27) → Press queue
# [ 649.11] IH start Shell#154(B9-U28)
# [ 649.11] Press start Shell#153(B9-U27)
# [ 649.62] Press done  Shell#153(B9-U27) → Finished
# [ 649.62] COMPLETED Shell#153(B9-U27) → OUTPUT_Q
# [ 649.88] Shell#195(B12-U27) graphite done
# [ 649.88] Shell#196(B12-U28) graphite done
# [ 649.88] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 650.97] IH done  Shell#154(B9-U28) → Press queue
# [ 650.97] IH start Shell#155(B9-U29)
# [ 650.97] Press start Shell#154(B9-U28)
# [ 651.49] Press done  Shell#154(B9-U28) → Finished
# [ 651.49] COMPLETED Shell#154(B9-U28) → OUTPUT_Q
# [ 651.57] Shell#197(B12-U29) graphite done
# [ 651.57] Shell#198(B12-U30) graphite done
# [ 651.57] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 652.84] IH done  Shell#155(B9-U29) → Press queue
# [ 652.84] IH start Shell#156(B9-U30)
# [ 652.84] Press start Shell#155(B9-U29)
# [ 653.26] Shell#199(B12-U31) graphite done
# [ 653.26] Shell#200(B12-U32) graphite done
# [ 653.26] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 653.36] Press done  Shell#155(B9-U29) → Finished
# [ 653.36] COMPLETED Shell#155(B9-U29) → OUTPUT_Q
# [ 654.71] IH done  Shell#156(B9-U30) → Press queue
# [ 654.71] IH start Shell#157(B9-U31)
# [ 654.71] Press start Shell#156(B9-U30)
# [ 654.95] Shell#201(B12-U33) graphite done
# [ 654.95] Shell#202(B12-U34) graphite done
# [ 654.95] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 655.22] Press done  Shell#156(B9-U30) → Finished
# [ 655.22] COMPLETED Shell#156(B9-U30) → OUTPUT_Q
# [ 656.57] IH done  Shell#157(B9-U31) → Press queue
# [ 656.57] IH start Shell#158(B9-U32)
# [ 656.57] Press start Shell#157(B9-U31)
# [ 656.64] Shell#203(B12-U35) graphite done
# [ 656.64] Shell#204(B12-U36) graphite done
# [ 656.64] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 657.09] Press done  Shell#157(B9-U31) → Finished
# [ 657.09] COMPLETED Shell#157(B9-U31) → OUTPUT_Q
# [ 658.33] Shell#205(B12-U37) graphite done
# [ 658.33] Shell#206(B12-U38) graphite done
# [ 658.33] Graphite wave start (2/2) on Pallet#13(n=42, tag=METAL_HEAT)
# [ 658.44] IH done  Shell#158(B9-U32) → Press queue
# [ 658.44] IH start Shell#159(B9-U33)
# [ 658.44] Press start Shell#158(B9-U32)
# [ 658.96] Press done  Shell#158(B9-U32) → Finished
# [ 658.96] COMPLETED Shell#158(B9-U32) → OUTPUT_Q
# Parameters: {'SIM_TIME': 660.0, 'BATCH_SIZE': 42, 'ARRIVAL_MEAN': 140.0, 't_transfer_per_shell': 0.1476, 't_heat_per_pallet': 60, 't_graphite_per_shell': 1.6913, 't_cool_pallet': 57.17, 't_weigh_per_shell': 0.4719, 't_induction_per_shell': 1.8667, 't_press_per_shell': 0.5167, 'HEAT_WAIT_CAP_PALLETS': 2, 'GRAPHITE_CAPACITY': 2}
#
# --- Throughputs / Counts ---
# arrived_pallets     : 5
# transferred_pallets : 5
# heated_pallets      : 5
# graphited_shells    : 206
# weighed_shells      : 168
# assembled_full_pallets: 4
# heated_shells       : 158
# forged_shells       : 158
# completed_shells    : 158
# output_buffer_len   : 158
#
# Finished shells in OUTPUT buffer: 158
